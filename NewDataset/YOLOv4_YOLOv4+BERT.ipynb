# %% [markdown]
# <a href="https://colab.research.google.com/github/mavillot/FUNSD-Information-Extraction/blob/main/NewDataset/YOLOv4_YOLOv4%2BBERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Darknet

# %%
# %%capture
# !git clone https://github.com/AlexeyAB/darknet

# %%
# %%capture
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile

# %%
# %%capture
# verify CUDA
# !/usr/local/cuda/bin/nvcc --version

# %%
# %%capture
# make darknet (builds darknet so that you can then use the darknet executable file to run or train object detectors)
# !make

# %%
# %%capture
# !apt-get install tree

# %% [markdown]
# ### Librerías y funciones

# %%
import numpy as np
import os,shutil,json
import xml.etree.ElementTree as ET
from pathlib import Path
import glob
import shutil
import operator
import sys
import argparse
import math
from matplotlib import pyplot as plt
import cv2
import json
import os
import re
from pathlib import Path
from imutils.contours import sort_contours
import numpy as np
import imutils
import sys
import statistics as stats
import pandas as pd
import torch
from sklearn.model_selection import train_test_split

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

def mostrarImagen(imagePath):
  image = cv2.imread(imagePath)
  if len(image.shape)==3:
    img2 = image[:,:,::-1]
    plt.figure(figsize=(20,15))
    plt.imshow(img2)
    plt.show()
  else:
    img2 = image
    plt.figure(figsize=(20,15))
    plt.imshow(img2,cmap='gray')
    plt.show()

def mostrarImagenConAnotacion(imagePath,annotationPath,classesPath):
    image = cv2.imread(imagePath)
    (H,W)=image.shape[:2]
    with open(annotationPath) as f:
        lines = f.readlines()
    with open(classesPath) as f:
        clases = f.readlines()
    for annot in lines:
        (c,x,y,w,h) = annot.split(' ')
        cv2.rectangle(image,(int((float(x)-float(w)/2)*W),int((float(y)-float(h)/2)*H)),(int((float(x)+float(w)/2)*W),int((float(y)+float(h)/2)*H)),(0,255,0),10)
        cv2.putText(image,clases[int(c)],(int((float(x)-float(w)/2)*W),int((float(y)-float(h)/2)*H-2)),cv2.FONT_HERSHEY_COMPLEX,0.5,(0,0,0),1)
    img2 = image[:,:,::-1]
    plt.imshow(img2)
    plt.show()

# %%
def unconvert(width, height, x, y, w, h):
    xmax = int((x*width) + (w * width)/2.0)
    xmin = int((x*width) - (w * width)/2.0)
    ymax = int((y*height) + (h * height)/2.0)
    ymin = int((y*height) - (h * height)/2.0)
    return ([xmin,ymin, xmax,  ymax])

# %%
def non_max_suppression_fast(boxes, overlapThresh=0.3):
  if len(boxes) == 0:
    return []
  if boxes.dtype.kind == "i":
    boxes = boxes.astype("float")
  pick = []
  x1 = boxes[:,0]
  y1 = boxes[:,1]
  x2 = boxes[:,2]
  y2 = boxes[:,3]
  area=(x2-x1)*(y2-y1)
  idxs = np.argsort(area)
  while len(idxs) > 0:
      i = idxs[0]
      xx1=x1[i]
      xx2=x2[i]
      yy1=y1[i]
      yy2=y2[i]
      x=xx2-xx1
      y=yy2-yy1
      aniadirBbox=True
      for k in idxs[1:]:
        if x1[k]<=xx1+overlapThresh*x and x2[k]>=xx2-overlapThresh*x and y1[k]<=yy1+overlapThresh*y and y2[k]>=yy2-overlapThresh*y:
          aniadirBbox=False
      if aniadirBbox:
        pick.append(i)
      idxs = np.delete(idxs, 0)
  return boxes[pick].astype("int")

# %%
def precision():
  txt=open('output/output.txt','r')
  txt.readline()
  txt.readline()
  l_prec=txt.readline()[13:-2].split()
  return float(l_prec[-1][1:-1])

# %%
def recall():
  txt=open('output/output.txt','r')
  txt.readline()
  txt.readline()
  txt.readline()
  l_prec=txt.readline()[10:-2].split()
  return float(l_prec[-1][1:-1])

# %%
def f1():
  return (2*precision()*recall())/(precision()+recall())

# %%
def abrirImagen(path):
  return cv2.imread(str(path))

# %% [markdown]
# #### mAP

# %%
MINOVERLAP = 0.5 # default value (defined in the PASCAL VOC2012 challenge)

parser = argparse.ArgumentParser()
parser.add_argument('-f')
parser.add_argument('-na', '--no-animation', help="no animation is shown.", action="store_true")
parser.add_argument('-np', '--no-plot', help="no plot is shown.", action="store_true")
parser.add_argument('-q', '--quiet', help="minimalistic console output.", action="store_true")
# argparse receiving list of classes to be ignored (e.g., python main.py --ignore person book)
parser.add_argument('-i', '--ignore', nargs='+', type=str, help="ignore a list of classes.")
# # argparse receiving list of classes with specific IoU (e.g., python main.py --set-class-iou person 0.7)
parser.add_argument('--set-class-iou', nargs='+', type=str, help="set IoU for a specific class.")

args = parser.parse_args()

# %%
def log_average_miss_rate(prec, rec, num_images):
    """
        log-average miss rate:
            Calculated by averaging miss rates at 9 evenly spaced FPPI points
            between 10e-2 and 10e0, in log-space.
        output:
                lamr | log-average miss rate
                mr | miss rate
                fppi | false positives per image
        references:
            [1] Dollar, Piotr, et al. "Pedestrian Detection: An Evaluation of the
               State of the Art." Pattern Analysis and Machine Intelligence, IEEE
               Transactions on 34.4 (2012): 743 - 761.
    """

    # if there were no detections of that class
    if prec.size == 0:
        lamr = 0
        mr = 1
        fppi = 0
        return lamr, mr, fppi

    fppi = (1 - prec)
    mr = (1 - rec)

    fppi_tmp = np.insert(fppi, 0, -1.0)
    mr_tmp = np.insert(mr, 0, 1.0)

    # Use 9 evenly spaced reference points in log-space
    ref = np.logspace(-2.0, 0.0, num = 9)
    for i, ref_i in enumerate(ref):
        # np.where() will always find at least 1 index, since min(ref) = 0.01 and min(fppi_tmp) = -1.0
        j = np.where(fppi_tmp <= ref_i)[-1][-1]
        ref[i] = mr_tmp[j]

    # log(0) is undefined, so we use the np.maximum(1e-10, ref)
    lamr = math.exp(np.mean(np.log(np.maximum(1e-10, ref))))

    return lamr, mr, fppi

"""
 throw error and exit
"""
def error(msg):
    print(msg)
    sys.exit(0)

"""
 check if the number is a float between 0.0 and 1.0
"""
def is_float_between_0_and_1(value):
    try:
        val = float(value)
        if val > 0.0 and val < 1.0:
            return True
        else:
            return False
    except ValueError:
        return False

"""
 Calculate the AP given the recall and precision array
    1st) We compute a version of the measured precision/recall curve with
         precision monotonically decreasing
    2nd) We compute the AP as the area under this curve by numerical integration.
"""
def voc_ap(rec, prec):
    """
    --- Official matlab code VOC2012---
    mrec=[0 ; rec ; 1];
    mpre=[0 ; prec ; 0];
    for i=numel(mpre)-1:-1:1
            mpre(i)=max(mpre(i),mpre(i+1));
    end
    i=find(mrec(2:end)~=mrec(1:end-1))+1;
    ap=sum((mrec(i)-mrec(i-1)).*mpre(i));
    """
    rec.insert(0, 0.0) # insert 0.0 at begining of list
    rec.append(1.0) # insert 1.0 at end of list
    mrec = rec[:]
    prec.insert(0, 0.0) # insert 0.0 at begining of list
    prec.append(0.0) # insert 0.0 at end of list
    mpre = prec[:]
    """
     This part makes the precision monotonically decreasing
        (goes from the end to the beginning)
        matlab: for i=numel(mpre)-1:-1:1
                    mpre(i)=max(mpre(i),mpre(i+1));
    """
    # matlab indexes start in 1 but python in 0, so I have to do:
    #     range(start=(len(mpre) - 2), end=0, step=-1)
    # also the python function range excludes the end, resulting in:
    #     range(start=(len(mpre) - 2), end=-1, step=-1)
    for i in range(len(mpre)-2, -1, -1):
        mpre[i] = max(mpre[i], mpre[i+1])
    """
     This part creates a list of indexes where the recall changes
        matlab: i=find(mrec(2:end)~=mrec(1:end-1))+1;
    """
    i_list = []
    for i in range(1, len(mrec)):
        if mrec[i] != mrec[i-1]:
            i_list.append(i) # if it was matlab would be i + 1
    """
     The Average Precision (AP) is the area under the curve
        (numerical integration)
        matlab: ap=sum((mrec(i)-mrec(i-1)).*mpre(i));
    """
    ap = 0.0
    for i in i_list:
        ap += ((mrec[i]-mrec[i-1])*mpre[i])
    return ap, mrec, mpre


"""
 Convert the lines of a file to a list
"""
def file_lines_to_list(path):
    # open txt file lines to a list
    with open(path) as f:
        content = f.readlines()
    # remove whitespace characters like `\n` at the end of each line
    content = [x.strip() for x in content]
    return content

"""
 Draws text in image
"""
def draw_text_in_image(img, text, pos, color, line_width):
    font = cv2.FONT_HERSHEY_PLAIN
    fontScale = 1
    lineType = 1
    bottomLeftCornerOfText = pos
    cv2.putText(img, text,
            bottomLeftCornerOfText,
            font,
            fontScale,
            color,
            lineType)
    text_width, _ = cv2.getTextSize(text, font, fontScale, lineType)[0]
    return img, (line_width + text_width)

"""
 Plot - adjust axes
"""
def adjust_axes(r, t, fig, axes):
    # get text width for re-scaling
    bb = t.get_window_extent(renderer=r)
    text_width_inches = bb.width / fig.dpi
    # get axis width in inches
    current_fig_width = fig.get_figwidth()
    new_fig_width = current_fig_width + text_width_inches
    propotion = new_fig_width / current_fig_width
    # get axis limit
    x_lim = axes.get_xlim()
    axes.set_xlim([x_lim[0], x_lim[1]*propotion])

"""
 Draw plot using Matplotlib
"""
def draw_plot_func(dictionary, n_classes, window_title, plot_title, x_label, output_path, to_show, plot_color, true_p_bar):
    # sort the dictionary by decreasing value, into a list of tuples
    sorted_dic_by_value = sorted(dictionary.items(), key=operator.itemgetter(1))
    # unpacking the list of tuples into two lists
    sorted_keys, sorted_values = zip(*sorted_dic_by_value)
    # 
    if true_p_bar != "":
        """
         Special case to draw in:
            - green -> TP: True Positives (object detected and matches ground-truth)
            - red -> FP: False Positives (object detected but does not match ground-truth)
            - pink -> FN: False Negatives (object not detected but present in the ground-truth)
        """
        fp_sorted = []
        tp_sorted = []
        for key in sorted_keys:
            fp_sorted.append(dictionary[key] - true_p_bar[key])
            tp_sorted.append(true_p_bar[key])
        plt.barh(range(n_classes), fp_sorted, align='center', color='crimson', label='False Positive')
        plt.barh(range(n_classes), tp_sorted, align='center', color='forestgreen', label='True Positive', left=fp_sorted)
        # add legend
        plt.legend(loc='lower right')
        """
         Write number on side of bar
        """
        fig = plt.gcf() # gcf - get current figure
        axes = plt.gca()
        r = fig.canvas.get_renderer()
        for i, val in enumerate(sorted_values):
            fp_val = fp_sorted[i]
            tp_val = tp_sorted[i]
            fp_str_val = " " + str(fp_val)
            tp_str_val = fp_str_val + " " + str(tp_val)
            # trick to paint multicolor with offset:
            # first paint everything and then repaint the first number
            t = plt.text(val, i, tp_str_val, color='forestgreen', va='center', fontweight='bold')
            plt.text(val, i, fp_str_val, color='crimson', va='center', fontweight='bold')
            if i == (len(sorted_values)-1): # largest bar
                adjust_axes(r, t, fig, axes)
    else:
        plt.barh(range(n_classes), sorted_values, color=plot_color)
        """
         Write number on side of bar
        """
        fig = plt.gcf() # gcf - get current figure
        axes = plt.gca()
        r = fig.canvas.get_renderer()
        for i, val in enumerate(sorted_values):
            str_val = " " + str(val) # add a space before
            if val < 1.0:
                str_val = " {0:.2f}".format(val)
            t = plt.text(val, i, str_val, color=plot_color, va='center', fontweight='bold')
            # re-set axes to show number inside the figure
            if i == (len(sorted_values)-1): # largest bar
                adjust_axes(r, t, fig, axes)
    # set window title
    fig.canvas.set_window_title(window_title)
    # write classes in y axis
    tick_font_size = 12
    plt.yticks(range(n_classes), sorted_keys, fontsize=tick_font_size)
    """
     Re-scale height accordingly
    """
    init_height = fig.get_figheight()
    # comput the matrix height in points and inches
    dpi = fig.dpi
    height_pt = n_classes * (tick_font_size * 1.4) # 1.4 (some spacing)
    height_in = height_pt / dpi
    # compute the required figure height 
    top_margin = 0.15 # in percentage of the figure height
    bottom_margin = 0.05 # in percentage of the figure height
    figure_height = height_in / (1 - top_margin - bottom_margin)
    # set new height
    if figure_height > init_height:
        fig.set_figheight(figure_height)

    # set plot title
    plt.title(plot_title, fontsize=14)
    # set axis titles
    # plt.xlabel('classes')
    plt.xlabel(x_label, fontsize='large')
    # adjust size of window
    fig.tight_layout()
    # save the plot
    fig.savefig(output_path)
    # show image
    if to_show:
        plt.show()
    # close the plot
    plt.close()

# %%
def mAP():
  # if there are no classes to ignore then replace None by empty list
  if args.ignore is None:
      args.ignore = []

  specific_iou_flagged = False
  if args.set_class_iou is not None:
      specific_iou_flagged = True

  # make sure that the cwd() is the location of the python script (so that every path makes sense)
  #os.chdir(os.path.dirname(os.path.abspath(__file__)))

  GT_PATH = os.path.join(os.getcwd(), 'input', 'ground-truth')
  DR_PATH = os.path.join(os.getcwd(), 'input', 'detection-results')
  # if there are no images then no animation can be shown
  IMG_PATH = os.path.join(os.getcwd(), 'input', 'images-optional')
  if os.path.exists(IMG_PATH): 
      for dirpath, dirnames, files in os.walk(IMG_PATH):
          if not files:
              # no image files found
              args.no_animation = True
  else:
      args.no_animation = True

  # try to import OpenCV if the user didn't choose the option --no-animation
  show_animation = False
  if not args.no_animation:
      try:
          import cv2
          show_animation = True
      except ImportError:
          print("\"opencv-python\" not found, please install to visualize the results.")
          args.no_animation = True

  # try to import Matplotlib if the user didn't choose the option --no-plot
  draw_plot = False
  if not args.no_plot:
      try:
          import matplotlib.pyplot as plt
          draw_plot = True
      except ImportError:
          print("\"matplotlib\" not found, please install it to get the resulting plots.")
          args.no_plot = True



  """
  Create a ".temp_files/" and "output/" directory
  """
  TEMP_FILES_PATH = ".temp_files"
  if not os.path.exists(TEMP_FILES_PATH): # if it doesn't exist already
      os.makedirs(TEMP_FILES_PATH)
  output_files_path = "output"
  if os.path.exists(output_files_path): # if it exist already
      # reset the output directory
      shutil.rmtree(output_files_path)

  os.makedirs(output_files_path)
  if draw_plot:
      os.makedirs(os.path.join(output_files_path, "classes"))
  if show_animation:
      os.makedirs(os.path.join(output_files_path, "images", "detections_one_by_one"))

  """
  ground-truth
      Load each of the ground-truth files into a temporary ".json" file.
      Create a list of all the class names present in the ground-truth (gt_classes).
  """
  # get a list with the ground-truth files
  ground_truth_files_list = glob.glob(GT_PATH + '/*.txt')
  if len(ground_truth_files_list) == 0:
      error("Error: No ground-truth files found!")
  ground_truth_files_list.sort()
  # dictionary with counter per class
  gt_counter_per_class = {}
  counter_images_per_class = {}

  gt_files = []
  for txt_file in ground_truth_files_list:
      #print(txt_file)
      file_id = txt_file.split(".txt", 1)[0]
      file_id = os.path.basename(os.path.normpath(file_id))
      # check if there is a correspondent detection-results file
      temp_path = os.path.join(DR_PATH, (file_id + ".txt"))
      if not os.path.exists(temp_path):
          error_msg = "Error. File not found: {}\n".format(temp_path)
          error_msg += "(You can avoid this error message by running extra/intersect-gt-and-dr.py)"
          error(error_msg)
      lines_list = file_lines_to_list(txt_file)
      # create ground-truth dictionary
      bounding_boxes = []
      is_difficult = False
      already_seen_classes = []
      for line in lines_list:
          try:
              if "difficult" in line:
                      class_name, left, top, right, bottom, _difficult = line.split()
                      is_difficult = True
              else:
                      class_name, left, top, right, bottom = line.split()
          except ValueError:
              error_msg = "Error: File " + txt_file + " in the wrong format.\n"
              error_msg += " Expected: <class_name> <left> <top> <right> <bottom> ['difficult']\n"
              error_msg += " Received: " + line
              error_msg += "\n\nIf you have a <class_name> with spaces between words you should remove them\n"
              error_msg += "by running the script \"remove_space.py\" or \"rename_class.py\" in the \"extra/\" folder."
              error(error_msg)
          # check if class is in the ignore list, if yes skip
          if class_name in args.ignore:
              continue
          bbox = left + " " + top + " " + right + " " +bottom
          if is_difficult:
              bounding_boxes.append({"class_name":class_name, "bbox":bbox, "used":False, "difficult":True})
              is_difficult = False
          else:
              bounding_boxes.append({"class_name":class_name, "bbox":bbox, "used":False})
              # count that object
              if class_name in gt_counter_per_class:
                  gt_counter_per_class[class_name] += 1
              else:
                  # if class didn't exist yet
                  gt_counter_per_class[class_name] = 1

              if class_name not in already_seen_classes:
                  if class_name in counter_images_per_class:
                      counter_images_per_class[class_name] += 1
                  else:
                      # if class didn't exist yet
                      counter_images_per_class[class_name] = 1
                  already_seen_classes.append(class_name)


      # dump bounding_boxes into a ".json" file
      new_temp_file = TEMP_FILES_PATH + "/" + file_id + "_ground_truth.json"
      gt_files.append(new_temp_file)
      with open(new_temp_file, 'w') as outfile:
          json.dump(bounding_boxes, outfile)

  gt_classes = list(gt_counter_per_class.keys())
  # let's sort the classes alphabetically
  gt_classes = sorted(gt_classes)
  n_classes = len(gt_classes)
  #print(gt_classes)
  #print(gt_counter_per_class)

  """
  Check format of the flag --set-class-iou (if used)
      e.g. check if class exists
  """
  if specific_iou_flagged:
      n_args = len(args.set_class_iou)
      error_msg = \
          '\n --set-class-iou [class_1] [IoU_1] [class_2] [IoU_2] [...]'
      if n_args % 2 != 0:
          error('Error, missing arguments. Flag usage:' + error_msg)
      # [class_1] [IoU_1] [class_2] [IoU_2]
      # specific_iou_classes = ['class_1', 'class_2']
      specific_iou_classes = args.set_class_iou[::2] # even
      # iou_list = ['IoU_1', 'IoU_2']
      iou_list = args.set_class_iou[1::2] # odd
      if len(specific_iou_classes) != len(iou_list):
          error('Error, missing arguments. Flag usage:' + error_msg)
      for tmp_class in specific_iou_classes:
          if tmp_class not in gt_classes:
                      error('Error, unknown class \"' + tmp_class + '\". Flag usage:' + error_msg)
      for num in iou_list:
          if not is_float_between_0_and_1(num):
              error('Error, IoU must be between 0.0 and 1.0. Flag usage:' + error_msg)

  """
  detection-results
      Load each of the detection-results files into a temporary ".json" file.
  """
  # get a list with the detection-results files
  dr_files_list = glob.glob(DR_PATH + '/*.txt')
  dr_files_list.sort()

  for class_index, class_name in enumerate(gt_classes):
      bounding_boxes = []
      for txt_file in dr_files_list:
          #print(txt_file)
          # the first time it checks if all the corresponding ground-truth files exist
          file_id = txt_file.split(".txt",1)[0]
          file_id = os.path.basename(os.path.normpath(file_id))
          temp_path = os.path.join(GT_PATH, (file_id + ".txt"))
          if class_index == 0:
              if not os.path.exists(temp_path):
                  error_msg = "Error. File not found: {}\n".format(temp_path)
                  error_msg += "(You can avoid this error message by running extra/intersect-gt-and-dr.py)"
                  error(error_msg)
          lines = file_lines_to_list(txt_file)
          for line in lines:
              try:
                  tmp_class_name, confidence, left, top, right, bottom = line.split()
              except ValueError:
                  error_msg = "Error: File " + txt_file + " in the wrong format.\n"
                  error_msg += " Expected: <class_name> <confidence> <left> <top> <right> <bottom>\n"
                  error_msg += " Received: " + line
                  error(error_msg)
              if tmp_class_name == class_name:
                  #print("match")
                  bbox = left + " " + top + " " + right + " " +bottom
                  bounding_boxes.append({"confidence":confidence, "file_id":file_id, "bbox":bbox})
                  #print(bounding_boxes)
      # sort detection-results by decreasing confidence
      bounding_boxes.sort(key=lambda x:float(x['confidence']), reverse=True)
      with open(TEMP_FILES_PATH + "/" + class_name + "_dr.json", 'w') as outfile:
          json.dump(bounding_boxes, outfile)

  """
  Calculate the AP for each class
  """
  sum_AP = 0.0
  ap_dictionary = {}
  lamr_dictionary = {}
  # open file to store the output
  with open(output_files_path + "/output.txt", 'w') as output_file:
      output_file.write("# AP and precision/recall per class\n")
      count_true_positives = {}
      for class_index, class_name in enumerate(gt_classes):
          count_true_positives[class_name] = 0
          """
          Load detection-results of that class
          """
          dr_file = TEMP_FILES_PATH + "/" + class_name + "_dr.json"
          dr_data = json.load(open(dr_file))

          """
          Assign detection-results to ground-truth objects
          """
          nd = len(dr_data)
          tp = [0] * nd # creates an array of zeros of size nd
          fp = [0] * nd
          for idx, detection in enumerate(dr_data):
              file_id = detection["file_id"]
              if show_animation:
                  # find ground truth image
                  ground_truth_img = glob.glob1(IMG_PATH, file_id + ".*")
                  #tifCounter = len(glob.glob1(myPath,"*.tif"))
                  if len(ground_truth_img) == 0:
                      error("Error. Image not found with id: " + file_id)
                  elif len(ground_truth_img) > 1:
                      error("Error. Multiple image with id: " + file_id)
                  else: # found image
                      #print(IMG_PATH + "/" + ground_truth_img[0])
                      # Load image
                      img = cv2.imread(IMG_PATH + "/" + ground_truth_img[0])
                      # load image with draws of multiple detections
                      img_cumulative_path = output_files_path + "/images/" + ground_truth_img[0]
                      if os.path.isfile(img_cumulative_path):
                          img_cumulative = cv2.imread(img_cumulative_path)
                      else:
                          img_cumulative = img.copy()
                      # Add bottom border to image
                      bottom_border = 60
                      BLACK = [0, 0, 0]
                      img = cv2.copyMakeBorder(img, 0, bottom_border, 0, 0, cv2.BORDER_CONSTANT, value=BLACK)
              # assign detection-results to ground truth object if any
              # open ground-truth with that file_id
              gt_file = TEMP_FILES_PATH + "/" + file_id + "_ground_truth.json"
              ground_truth_data = json.load(open(gt_file))
              ovmax = -1
              gt_match = -1
              # load detected object bounding-box
              bb = [ float(x) for x in detection["bbox"].split() ]
              for obj in ground_truth_data:
                  # look for a class_name match
                  if obj["class_name"] == class_name:
                      bbgt = [ float(x) for x in obj["bbox"].split() ]
                      bi = [max(bb[0],bbgt[0]), max(bb[1],bbgt[1]), min(bb[2],bbgt[2]), min(bb[3],bbgt[3])]
                      iw = bi[2] - bi[0] + 1
                      ih = bi[3] - bi[1] + 1
                      if iw > 0 and ih > 0:
                          # compute overlap (IoU) = area of intersection / area of union
                          ua = (bb[2] - bb[0] + 1) * (bb[3] - bb[1] + 1) + (bbgt[2] - bbgt[0]
                                          + 1) * (bbgt[3] - bbgt[1] + 1) - iw * ih
                          ov = iw * ih / ua
                          if ov > ovmax:
                              ovmax = ov
                              gt_match = obj

              # assign detection as true positive/don't care/false positive
              if show_animation:
                  status = "NO MATCH FOUND!" # status is only used in the animation
              # set minimum overlap
              min_overlap = MINOVERLAP
              if specific_iou_flagged:
                  if class_name in specific_iou_classes:
                      index = specific_iou_classes.index(class_name)
                      min_overlap = float(iou_list[index])
              if ovmax >= min_overlap:
                  if "difficult" not in gt_match:
                          if not bool(gt_match["used"]):
                              # true positive
                              tp[idx] = 1
                              gt_match["used"] = True
                              count_true_positives[class_name] += 1
                              # update the ".json" file
                              with open(gt_file, 'w') as f:
                                      f.write(json.dumps(ground_truth_data))
                              if show_animation:
                                  status = "MATCH!"
                          else:
                              # false positive (multiple detection)
                              fp[idx] = 1
                              if show_animation:
                                  status = "REPEATED MATCH!"
              else:
                  # false positive
                  fp[idx] = 1
                  if ovmax > 0:
                      status = "INSUFFICIENT OVERLAP"

              """
              Draw image to show animation
              """
              if show_animation:
                  height, widht = img.shape[:2]
                  # colors (OpenCV works with BGR)
                  white = (255,255,255)
                  light_blue = (255,200,100)
                  green = (0,255,0)
                  light_red = (30,30,255)
                  # 1st line
                  margin = 10
                  v_pos = int(height - margin - (bottom_border / 2.0))
                  text = "Image: " + ground_truth_img[0] + " "
                  img, line_width = draw_text_in_image(img, text, (margin, v_pos), white, 0)
                  text = "Class [" + str(class_index) + "/" + str(n_classes) + "]: " + class_name + " "
                  img, line_width = draw_text_in_image(img, text, (margin + line_width, v_pos), light_blue, line_width)
                  if ovmax != -1:
                      color = light_red
                      if status == "INSUFFICIENT OVERLAP":
                          text = "IoU: {0:.2f}% ".format(ovmax*100) + "< {0:.2f}% ".format(min_overlap*100)
                      else:
                          text = "IoU: {0:.2f}% ".format(ovmax*100) + ">= {0:.2f}% ".format(min_overlap*100)
                          color = green
                      img, _ = draw_text_in_image(img, text, (margin + line_width, v_pos), color, line_width)
                  # 2nd line
                  v_pos += int(bottom_border / 2.0)
                  rank_pos = str(idx+1) # rank position (idx starts at 0)
                  text = "Detection #rank: " + rank_pos + " confidence: {0:.2f}% ".format(float(detection["confidence"])*100)
                  img, line_width = draw_text_in_image(img, text, (margin, v_pos), white, 0)
                  color = light_red
                  if status == "MATCH!":
                      color = green
                  text = "Result: " + status + " "
                  img, line_width = draw_text_in_image(img, text, (margin + line_width, v_pos), color, line_width)

                  font = cv2.FONT_HERSHEY_SIMPLEX
                  if ovmax > 0: # if there is intersections between the bounding-boxes
                      bbgt = [ int(round(float(x))) for x in gt_match["bbox"].split() ]
                      cv2.rectangle(img,(bbgt[0],bbgt[1]),(bbgt[2],bbgt[3]),light_blue,2)
                      cv2.rectangle(img_cumulative,(bbgt[0],bbgt[1]),(bbgt[2],bbgt[3]),light_blue,2)
                      cv2.putText(img_cumulative, class_name, (bbgt[0],bbgt[1] - 5), font, 0.6, light_blue, 1, cv2.LINE_AA)
                  bb = [int(i) for i in bb]
                  cv2.rectangle(img,(bb[0],bb[1]),(bb[2],bb[3]),color,2)
                  cv2.rectangle(img_cumulative,(bb[0],bb[1]),(bb[2],bb[3]),color,2)
                  cv2.putText(img_cumulative, class_name, (bb[0],bb[1] - 5), font, 0.6, color, 1, cv2.LINE_AA)
                  # show image
                  cv2.imshow("Animation", img)
                  cv2.waitKey(20) # show for 20 ms
                  # save image to output
                  output_img_path = output_files_path + "/images/detections_one_by_one/" + class_name + "_detection" + str(idx) + ".jpg"
                  cv2.imwrite(output_img_path, img)
                  # save the image with all the objects drawn to it
                  cv2.imwrite(img_cumulative_path, img_cumulative)

          #print(tp)
          # compute precision/recall
          cumsum = 0
          for idx, val in enumerate(fp):
              fp[idx] += cumsum
              cumsum += val
          cumsum = 0
          for idx, val in enumerate(tp):
              tp[idx] += cumsum
              cumsum += val
          #print(tp)
          rec = tp[:]
          for idx, val in enumerate(tp):
              rec[idx] = float(tp[idx]) / gt_counter_per_class[class_name]
          #print(rec)
          prec = tp[:]
          for idx, val in enumerate(tp):
              prec[idx] = float(tp[idx]) / (fp[idx] + tp[idx])
          #print(prec)

          ap, mrec, mprec = voc_ap(rec[:], prec[:])
          sum_AP += ap
          text = "{0:.2f}%".format(ap*100) + " = " + class_name + " AP " #class_name + " AP = {0:.2f}%".format(ap*100)
          """
          Write to output.txt
          """
          rounded_prec = [ '%.2f' % elem for elem in prec ]
          rounded_rec = [ '%.2f' % elem for elem in rec ]
          output_file.write(text + "\n Precision: " + str(rounded_prec) + "\n Recall :" + str(rounded_rec) + "\n\n")
          if not args.quiet:
              print(text)
          ap_dictionary[class_name] = ap

          n_images = counter_images_per_class[class_name]
          lamr, mr, fppi = log_average_miss_rate(np.array(prec), np.array(rec), n_images)
          lamr_dictionary[class_name] = lamr

          """
          Draw plot
          """
          if draw_plot:
              plt.plot(rec, prec, '-o')
              # add a new penultimate point to the list (mrec[-2], 0.0)
              # since the last line segment (and respective area) do not affect the AP value
              area_under_curve_x = mrec[:-1] + [mrec[-2]] + [mrec[-1]]
              area_under_curve_y = mprec[:-1] + [0.0] + [mprec[-1]]
              plt.fill_between(area_under_curve_x, 0, area_under_curve_y, alpha=0.2, edgecolor='r')
              # set window title
              fig = plt.gcf() # gcf - get current figure
              fig.canvas.set_window_title('AP ' + class_name)
              # set plot title
              plt.title('class: ' + text)
              #plt.suptitle('This is a somewhat long figure title', fontsize=16)
              # set axis titles
              plt.xlabel('Recall')
              plt.ylabel('Precision')
              # optional - set axes
              axes = plt.gca() # gca - get current axes
              axes.set_xlim([0.0,1.0])
              axes.set_ylim([0.0,1.05]) # .05 to give some extra space
              # Alternative option -> wait for button to be pressed
              #while not plt.waitforbuttonpress(): pass # wait for key display
              # Alternative option -> normal display
              #plt.show()
              # save the plot
              fig.savefig(output_files_path + "/classes/" + class_name + ".png")
              plt.cla() # clear axes for next plot

      if show_animation:
          cv2.destroyAllWindows()

      output_file.write("\n# mAP of all classes\n")
      mAP = sum_AP / n_classes
      text = "mAP = {0:.2f}%".format(mAP*100)
      output_file.write(text + "\n")
      print(text)

  """
  Draw false negatives
  """
  if show_animation:
      pink = (203,192,255)
      for tmp_file in gt_files:
          ground_truth_data = json.load(open(tmp_file))
          #print(ground_truth_data)
          # get name of corresponding image
          start = TEMP_FILES_PATH + '/'
          img_id = tmp_file[tmp_file.find(start)+len(start):tmp_file.rfind('_ground_truth.json')]
          img_cumulative_path = output_files_path + "/images/" + img_id + ".jpg"
          img = cv2.imread(img_cumulative_path)
          if img is None:
              img_path = IMG_PATH + '/' + img_id + ".jpg"
              img = cv2.imread(img_path)
          # draw false negatives
          for obj in ground_truth_data:
              if not obj['used']:
                  bbgt = [ int(round(float(x))) for x in obj["bbox"].split() ]
                  cv2.rectangle(img,(bbgt[0],bbgt[1]),(bbgt[2],bbgt[3]),pink,2)
          cv2.imwrite(img_cumulative_path, img)

  # remove the temp_files directory
  shutil.rmtree(TEMP_FILES_PATH)

  """
  Count total of detection-results
  """
  # iterate through all the files
  det_counter_per_class = {}
  for txt_file in dr_files_list:
      # get lines to list
      lines_list = file_lines_to_list(txt_file)
      for line in lines_list:
          class_name = line.split()[0]
          # check if class is in the ignore list, if yes skip
          if class_name in args.ignore:
              continue
          # count that object
          if class_name in det_counter_per_class:
              det_counter_per_class[class_name] += 1
          else:
              # if class didn't exist yet
              det_counter_per_class[class_name] = 1
  #print(det_counter_per_class)
  dr_classes = list(det_counter_per_class.keys())


  """
  Plot the total number of occurences of each class in the ground-truth
  """
  if draw_plot:
      window_title = "ground-truth-info"
      plot_title = "ground-truth\n"
      plot_title += "(" + str(len(ground_truth_files_list)) + " files and " + str(n_classes) + " classes)"
      x_label = "Number of objects per class"
      output_path = output_files_path + "/ground-truth-info.png"
      to_show = False
      plot_color = 'forestgreen'
      draw_plot_func(
          gt_counter_per_class,
          n_classes,
          window_title,
          plot_title,
          x_label,
          output_path,
          to_show,
          plot_color,
          '',
          )

  """
  Write number of ground-truth objects per class to results.txt
  """
  with open(output_files_path + "/output.txt", 'a') as output_file:
      output_file.write("\n# Number of ground-truth objects per class\n")
      for class_name in sorted(gt_counter_per_class):
          output_file.write(class_name + ": " + str(gt_counter_per_class[class_name]) + "\n")

  """
  Finish counting true positives
  """
  for class_name in dr_classes:
      # if class exists in detection-result but not in ground-truth then there are no true positives in that class
      if class_name not in gt_classes:
          count_true_positives[class_name] = 0
  #print(count_true_positives)

  """
  Plot the total number of occurences of each class in the "detection-results" folder
  """
  if draw_plot:
      window_title = "detection-results-info"
      # Plot title
      plot_title = "detection-results\n"
      plot_title += "(" + str(len(dr_files_list)) + " files and "
      count_non_zero_values_in_dictionary = sum(int(x) > 0 for x in list(det_counter_per_class.values()))
      plot_title += str(count_non_zero_values_in_dictionary) + " detected classes)"
      # end Plot title
      x_label = "Number of objects per class"
      output_path = output_files_path + "/detection-results-info.png"
      to_show = False
      plot_color = 'forestgreen'
      true_p_bar = count_true_positives
      draw_plot_func(
          det_counter_per_class,
          len(det_counter_per_class),
          window_title,
          plot_title,
          x_label,
          output_path,
          to_show,
          plot_color,
          true_p_bar
          )

  """
  Write number of detected objects per class to output.txt
  """
  with open(output_files_path + "/output.txt", 'a') as output_file:
      output_file.write("\n# Number of detected objects per class\n")
      for class_name in sorted(dr_classes):
          n_det = det_counter_per_class[class_name]
          text = class_name + ": " + str(n_det)
          text += " (tp:" + str(count_true_positives[class_name]) + ""
          text += ", fp:" + str(n_det - count_true_positives[class_name]) + ")\n"
          output_file.write(text)

  """
  Draw log-average miss rate plot (Show lamr of all classes in decreasing order)
  """
  if draw_plot:
      window_title = "lamr"
      plot_title = "log-average miss rate"
      x_label = "log-average miss rate"
      output_path = output_files_path + "/lamr.png"
      to_show = False
      plot_color = 'royalblue'
      draw_plot_func(
          lamr_dictionary,
          n_classes,
          window_title,
          plot_title,
          x_label,
          output_path,
          to_show,
          plot_color,
          ""
          )

  """
  Draw mAP plot (Show AP's of all classes in decreasing order)
  """
  if draw_plot:
      window_title = "mAP"
      plot_title = "mAP = {0:.2f}%".format(mAP*100)
      x_label = "Average Precision"
      output_path = output_files_path + "/mAP.png"
      to_show = False
      plot_color = 'royalblue'
      draw_plot_func(
          ap_dictionary,
          n_classes,
          window_title,
          plot_title,
          x_label,
          output_path,
          to_show,
          plot_color,
          ""
          )

# %% [markdown]
# ## Descarga de archivos

# %%
# %%capture
# !wget https://www.dropbox.com/s/wxzrfb5wtdgdgi8/funsd_last.weights?dl=0 -O funsd_last.weights
# !wget https://www.dropbox.com/s/2hdgc14avqle31s/funsd.cfg?dl=0 -O funsd.cfg
# !wget https://www.dropbox.com/s/eaf1sp3k1xoig7h/funsd.data?dl=0 -O funsd.data
# !wget https://www.dropbox.com/s/vwxyeohq1amz369/funsd.names?dl=0 -O funsd.names

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/Athento/FacturasYOLO.zip
# Out:
# Archive:  /content/drive/MyDrive/Athento/FacturasYOLO.zip
#   inflating: FacturasYOLO/01.jpg
#   inflating: FacturasYOLO/01.txt
#   inflating: FacturasYOLO/02.jpg
#   inflating: FacturasYOLO/02.txt
#   inflating: FacturasYOLO/03.jpg
#   inflating: FacturasYOLO/03.txt
#   inflating: FacturasYOLO/04.jpg
#   inflating: FacturasYOLO/04.txt
#   inflating: FacturasYOLO/05.jpg
#   inflating: FacturasYOLO/05.txt
#   inflating: FacturasYOLO/06.jpg
#   inflating: FacturasYOLO/06.txt
#   inflating: FacturasYOLO/07.jpg
#   inflating: FacturasYOLO/07.txt
#   inflating: FacturasYOLO/08.jpg
#   inflating: FacturasYOLO/08.txt
#   inflating: FacturasYOLO/09.jpg
#   inflating: FacturasYOLO/09.txt
#   inflating: FacturasYOLO/10.jpg
#   inflating: FacturasYOLO/10.txt
#   inflating: FacturasYOLO/11.jpg
#   inflating: FacturasYOLO/11.txt
#   inflating: FacturasYOLO/12.jpg
#   inflating: FacturasYOLO/12.txt
#   inflating: FacturasYOLO/13.jpg
#   inflating: FacturasYOLO/13.txt
#   inflating: FacturasYOLO/14.jpg
#   inflating: FacturasYOLO/14.txt
#   inflating: FacturasYOLO/16.jpg
#   inflating: FacturasYOLO/16.txt
#   inflating: FacturasYOLO/17.jpg
#   inflating: FacturasYOLO/17.txt
#   inflating: FacturasYOLO/18.jpg
#   inflating: FacturasYOLO/18.txt
#   inflating: FacturasYOLO/19.jpg
#   inflating: FacturasYOLO/19.txt
#   inflating: FacturasYOLO/20.jpg
#   inflating: FacturasYOLO/20.txt
#   inflating: FacturasYOLO/22.jpg
#   inflating: FacturasYOLO/22.txt
#   inflating: FacturasYOLO/23.jpg
#   inflating: FacturasYOLO/23.txt
#   inflating: FacturasYOLO/24.jpg
#   inflating: FacturasYOLO/24.txt
#   inflating: FacturasYOLO/25.png
#   inflating: FacturasYOLO/25.txt
#   inflating: FacturasYOLO/26.png
#   inflating: FacturasYOLO/26.txt
#   inflating: FacturasYOLO/27.png
#   inflating: FacturasYOLO/27.txt
#   inflating: FacturasYOLO/28.png
#   inflating: FacturasYOLO/28.txt
#   inflating: FacturasYOLO/29.png
#   inflating: FacturasYOLO/29.txt
#   inflating: FacturasYOLO/classes.txt

# %%
path='FacturasYOLO'
files = [Path(str(path)+'/'+p) for p in os.listdir(path) if p[-1]=='g']

# %%
txt=open('test.txt','w')
for f in files:
  txt.write(str(f)+'\n')
txt.close()

# %%
txt=open('classes.data','w')
txt.write('classes = 4\n')
txt.write('train  = train.txt\n')
txt.write('valid  = test.txt\n')
txt.write('names = funsd.names\n')
txt.write('backup = FUNSDdataset/\n')
txt.close()

# %%
# !cp funsd.cfg ./cfg

# %% [markdown]
# ## **YOLOv4**

# %% [markdown]
# ### Detección

# %%
# !./darknet detector map classes.data cfg/funsd.cfg funsd_last.weights -iou_thresh 0.50 -points 101
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    640 x 640 x   3 ->  640 x 640 x  32 0.708 BF
#    1 conv     80       3 x 3/ 2    640 x 640 x  32 ->  320 x 320 x  80 4.719 BF
#    2 conv     40       1 x 1/ 1    320 x 320 x  80 ->  320 x 320 x  40 0.655 BF
#    3 conv     80       3 x 3/ 1    320 x 320 x  40 ->  320 x 320 x  80 5.898 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 320 x 320 x  80 0.008 BF
#    5 conv    160       3 x 3/ 2    320 x 320 x  80 ->  160 x 160 x 160 5.898 BF
#    6 conv     80       1 x 1/ 1    160 x 160 x 160 ->  160 x 160 x  80 0.655 BF
#    7 route  5 		                           ->  160 x 160 x 160
#    8 conv     80       1 x 1/ 1    160 x 160 x 160 ->  160 x 160 x  80 0.655 BF
#    9 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   10 conv     80       3 x 3/ 1    160 x 160 x  80 ->  160 x 160 x  80 2.949 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 160 x 160 x  80 0.002 BF
#   12 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   13 conv     80       3 x 3/ 1    160 x 160 x  80 ->  160 x 160 x  80 2.949 BF
#   14 Shortcut Layer: 11,  wt = 0, wn = 0, outputs: 160 x 160 x  80 0.002 BF
#   15 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   16 conv     80       3 x 3/ 1    160 x 160 x  80 ->  160 x 160 x  80 2.949 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 160 x 160 x  80 0.002 BF
#   18 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   19 route  18 6 	                           ->  160 x 160 x 160
#   20 conv    160       1 x 1/ 1    160 x 160 x 160 ->  160 x 160 x 160 1.311 BF
#   21 conv    320       3 x 3/ 2    160 x 160 x 160 ->   80 x  80 x 320 5.898 BF
#   22 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#   23 route  21 		                           ->   80 x  80 x 320
#   24 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#   25 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   26 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   28 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   29 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   31 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   32 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   34 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   35 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   37 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   38 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   40 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   41 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   43 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   44 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   46 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   47 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   49 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   50 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   52 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   53 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   54 Shortcut Layer: 51,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   55 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   56 route  55 22 	                           ->   80 x  80 x 320
#   57 conv    320       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 320 1.311 BF
#   58 conv    640       3 x 3/ 2     80 x  80 x 320 ->   40 x  40 x 640 5.898 BF
#   59 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#   60 route  58 		                           ->   40 x  40 x 640
#   61 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#   62 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   63 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   65 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   66 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   68 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   69 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   71 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   72 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   74 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   75 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   77 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   78 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   80 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   81 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   83 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   84 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   85 Shortcut Layer: 82,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   86 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   87 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   88 Shortcut Layer: 85,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   89 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   90 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   91 Shortcut Layer: 88,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   92 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   93 route  92 59 	                           ->   40 x  40 x 640
#   94 conv    640       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 640 1.311 BF
#   95 conv   1280       3 x 3/ 2     40 x  40 x 640 ->   20 x  20 x1280 5.898 BF
#   96 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#   97 route  95 		                           ->   20 x  20 x1280
#   98 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#   99 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  100 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  102 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  103 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  104 Shortcut Layer: 101,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  105 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  106 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  107 Shortcut Layer: 104,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  108 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  109 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  110 Shortcut Layer: 107,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  111 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  112 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  113 Shortcut Layer: 110,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  114 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  115 route  114 96 	                           ->   20 x  20 x1280
#  116 conv   1280       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x1280 1.311 BF
#  117 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  118 route  116 		                           ->   20 x  20 x1280
#  119 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  120 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  121 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  122 max                5x 5/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.006 BF
#  123 route  121 		                           ->   20 x  20 x 640
#  124 max                9x 9/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.021 BF
#  125 route  121 		                           ->   20 x  20 x 640
#  126 max               13x13/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.043 BF
#  127 route  126 124 122 121 	                   ->   20 x  20 x2560
#  128 conv    640       1 x 1/ 1     20 x  20 x2560 ->   20 x  20 x 640 1.311 BF
#  129 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  130 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  131 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  132 route  131 117 	                           ->   20 x  20 x1280
#  133 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  134 conv    320       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 320 0.164 BF
#  135 upsample                 2x    20 x  20 x 320 ->   40 x  40 x 320
#  136 route  94 		                           ->   40 x  40 x 640
#  137 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  138 route  137 135 	                           ->   40 x  40 x 640
#  139 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  140 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  141 route  139 		                           ->   40 x  40 x 320
#  142 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  143 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  144 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  145 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  146 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  147 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  148 route  147 140 	                           ->   40 x  40 x 640
#  149 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  150 conv    160       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 160 0.164 BF
#  151 upsample                 2x    40 x  40 x 160 ->   80 x  80 x 160
#  152 route  57 		                           ->   80 x  80 x 320
#  153 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#  154 route  153 151 	                           ->   80 x  80 x 320
#  155 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#  156 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  157 route  155 		                           ->   80 x  80 x 160
#  158 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  159 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#  160 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  161 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#  162 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  163 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#  164 route  163 156 	                           ->   80 x  80 x 320
#  165 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#  166 conv    320       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 320 5.898 BF
#  167 conv     27       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x  27 0.111 BF
#  168 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 4.00, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
#  169 route  165 		                           ->   80 x  80 x 160
#  170 conv    320       3 x 3/ 2     80 x  80 x 160 ->   40 x  40 x 320 1.475 BF
#  171 route  170 149 	                           ->   40 x  40 x 640
#  172 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  173 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  174 route  172 		                           ->   40 x  40 x 320
#  175 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  176 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  177 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  178 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  179 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  180 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  181 route  180 173 	                           ->   40 x  40 x 640
#  182 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  183 conv    640       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 640 5.898 BF
#  184 conv     27       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x  27 0.055 BF
#  185 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 1.00, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
#  186 route  182 		                           ->   40 x  40 x 320
#  187 conv    640       3 x 3/ 2     40 x  40 x 320 ->   20 x  20 x 640 1.475 BF
#  188 route  187 133 	                           ->   20 x  20 x1280
#  189 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  190 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  191 route  189 		                           ->   20 x  20 x 640
#  192 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  193 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  194 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  195 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  196 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  197 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  198 route  197 190 	                           ->   20 x  20 x1280
#  199 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  200 conv   1280       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x1280 5.898 BF
#  201 conv     27       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x  27 0.028 BF
#  202 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 0.40, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
# Total BFLOPS 220.352
# avg_outputs = 1000634
#  Allocate additional workspace_size = 81.93 MB
# Loading weights from funsd_last.weights...
#  seen 64, trained: 582 K-images (9 Kilo-batches_64)
# Done! Loaded 203 layers from weights-file
#
#  calculation mAP (mean average precision)...
#  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# 28
#  detections_count = 8507, unique_truth_count = 1704
# class_id = 0, name = answer, ap = 22.89%   	 (TP = 306, FP = 721)
# class_id = 1, name = question, ap = 30.00%   	 (TP = 262, FP = 366)
# class_id = 2, name = header, ap = 11.93%   	 (TP = 12, FP = 31)
# class_id = 3, name = other, ap = 1.58%   	 (TP = 3, FP = 184)
#
#  for conf_thresh = 0.25, precision = 0.31, recall = 0.34, F1-score = 0.32
#  for conf_thresh = 0.25, TP = 583, FP = 1302, FN = 1121, average IoU = 20.58 %
#
#  IoU threshold = 50 %, used 101 Recall-points
#  mean average precision (mAP@0.50) = 0.166030, or 16.60 %
# Total Detection Time: 4 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %% [markdown]
# mAP= 16.60 %
#
# precision = 0.31
#
# recall = 0.34
#
# F1-score = 0.32

# %%
# %cd cfg
# !sed -i 's/batch=64/batch=1/' funsd.cfg
# !sed -i 's/subdivisions=16/subdivisions=1/' funsd.cfg
# %cd ..
# Out:
# /content/darknet/cfg
# /content/darknet

# %%
# !./darknet detector test classes.data cfg/funsd.cfg funsd_last.weights FacturasYOLO/01.jpg -thresh 0.3
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    640 x 640 x   3 ->  640 x 640 x  32 0.708 BF
#    1 conv     80       3 x 3/ 2    640 x 640 x  32 ->  320 x 320 x  80 4.719 BF
#    2 conv     40       1 x 1/ 1    320 x 320 x  80 ->  320 x 320 x  40 0.655 BF
#    3 conv     80       3 x 3/ 1    320 x 320 x  40 ->  320 x 320 x  80 5.898 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 320 x 320 x  80 0.008 BF
#    5 conv    160       3 x 3/ 2    320 x 320 x  80 ->  160 x 160 x 160 5.898 BF
#    6 conv     80       1 x 1/ 1    160 x 160 x 160 ->  160 x 160 x  80 0.655 BF
#    7 route  5 		                           ->  160 x 160 x 160
#    8 conv     80       1 x 1/ 1    160 x 160 x 160 ->  160 x 160 x  80 0.655 BF
#    9 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   10 conv     80       3 x 3/ 1    160 x 160 x  80 ->  160 x 160 x  80 2.949 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 160 x 160 x  80 0.002 BF
#   12 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   13 conv     80       3 x 3/ 1    160 x 160 x  80 ->  160 x 160 x  80 2.949 BF
#   14 Shortcut Layer: 11,  wt = 0, wn = 0, outputs: 160 x 160 x  80 0.002 BF
#   15 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   16 conv     80       3 x 3/ 1    160 x 160 x  80 ->  160 x 160 x  80 2.949 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 160 x 160 x  80 0.002 BF
#   18 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   19 route  18 6 	                           ->  160 x 160 x 160
#   20 conv    160       1 x 1/ 1    160 x 160 x 160 ->  160 x 160 x 160 1.311 BF
#   21 conv    320       3 x 3/ 2    160 x 160 x 160 ->   80 x  80 x 320 5.898 BF
#   22 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#   23 route  21 		                           ->   80 x  80 x 320
#   24 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#   25 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   26 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   28 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   29 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   31 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   32 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   34 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   35 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   37 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   38 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   40 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   41 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   43 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   44 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   46 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   47 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   49 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   50 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   52 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   53 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   54 Shortcut Layer: 51,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   55 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   56 route  55 22 	                           ->   80 x  80 x 320
#   57 conv    320       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 320 1.311 BF
#   58 conv    640       3 x 3/ 2     80 x  80 x 320 ->   40 x  40 x 640 5.898 BF
#   59 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#   60 route  58 		                           ->   40 x  40 x 640
#   61 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#   62 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   63 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   65 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   66 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   68 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   69 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   71 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   72 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   74 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   75 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   77 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   78 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   80 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   81 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   83 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   84 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   85 Shortcut Layer: 82,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   86 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   87 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   88 Shortcut Layer: 85,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   89 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   90 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   91 Shortcut Layer: 88,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   92 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   93 route  92 59 	                           ->   40 x  40 x 640
#   94 conv    640       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 640 1.311 BF
#   95 conv   1280       3 x 3/ 2     40 x  40 x 640 ->   20 x  20 x1280 5.898 BF
#   96 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#   97 route  95 		                           ->   20 x  20 x1280
#   98 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#   99 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  100 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  102 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  103 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  104 Shortcut Layer: 101,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  105 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  106 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  107 Shortcut Layer: 104,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  108 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  109 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  110 Shortcut Layer: 107,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  111 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  112 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  113 Shortcut Layer: 110,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  114 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  115 route  114 96 	                           ->   20 x  20 x1280
#  116 conv   1280       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x1280 1.311 BF
#  117 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  118 route  116 		                           ->   20 x  20 x1280
#  119 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  120 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  121 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  122 max                5x 5/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.006 BF
#  123 route  121 		                           ->   20 x  20 x 640
#  124 max                9x 9/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.021 BF
#  125 route  121 		                           ->   20 x  20 x 640
#  126 max               13x13/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.043 BF
#  127 route  126 124 122 121 	                   ->   20 x  20 x2560
#  128 conv    640       1 x 1/ 1     20 x  20 x2560 ->   20 x  20 x 640 1.311 BF
#  129 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  130 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  131 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  132 route  131 117 	                           ->   20 x  20 x1280
#  133 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  134 conv    320       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 320 0.164 BF
#  135 upsample                 2x    20 x  20 x 320 ->   40 x  40 x 320
#  136 route  94 		                           ->   40 x  40 x 640
#  137 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  138 route  137 135 	                           ->   40 x  40 x 640
#  139 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  140 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  141 route  139 		                           ->   40 x  40 x 320
#  142 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  143 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  144 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  145 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  146 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  147 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  148 route  147 140 	                           ->   40 x  40 x 640
#  149 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  150 conv    160       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 160 0.164 BF
#  151 upsample                 2x    40 x  40 x 160 ->   80 x  80 x 160
#  152 route  57 		                           ->   80 x  80 x 320
#  153 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#  154 route  153 151 	                           ->   80 x  80 x 320
#  155 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#  156 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  157 route  155 		                           ->   80 x  80 x 160
#  158 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  159 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#  160 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  161 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#  162 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  163 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#  164 route  163 156 	                           ->   80 x  80 x 320
#  165 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#  166 conv    320       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 320 5.898 BF
#  167 conv     27       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x  27 0.111 BF
#  168 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 4.00, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
#  169 route  165 		                           ->   80 x  80 x 160
#  170 conv    320       3 x 3/ 2     80 x  80 x 160 ->   40 x  40 x 320 1.475 BF
#  171 route  170 149 	                           ->   40 x  40 x 640
#  172 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  173 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  174 route  172 		                           ->   40 x  40 x 320
#  175 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  176 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  177 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  178 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  179 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  180 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  181 route  180 173 	                           ->   40 x  40 x 640
#  182 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  183 conv    640       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 640 5.898 BF
#  184 conv     27       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x  27 0.055 BF
#  185 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 1.00, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
#  186 route  182 		                           ->   40 x  40 x 320
#  187 conv    640       3 x 3/ 2     40 x  40 x 320 ->   20 x  20 x 640 1.475 BF
#  188 route  187 133 	                           ->   20 x  20 x1280
#  189 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  190 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  191 route  189 		                           ->   20 x  20 x 640
#  192 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  193 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  194 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  195 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  196 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  197 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  198 route  197 190 	                           ->   20 x  20 x1280
#  199 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  200 conv   1280       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x1280 5.898 BF
#  201 conv     27       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x  27 0.028 BF
#  202 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 0.40, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
# Total BFLOPS 220.352
# avg_outputs = 1000634
#  Allocate additional workspace_size = 81.93 MB
# Loading weights from funsd_last.weights...
#  seen 64, trained: 582 K-images (9 Kilo-batches_64)
# Done! Loaded 203 layers from weights-file
#  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/01.jpg: Predicted in 80.584000 milli-seconds.
# other: 35%
# question: 75%
# answer: 31%
# answer: 93%
# question: 72%
# answer: 51%
# question: 97%
# answer: 41%
# other: 44%
# question: 60%
# answer: 54%
# other: 41%
# answer: 41%
# answer: 32%
# other: 83%
# question: 67%
# question: 91%
# answer: 97%
# question: 70%
# answer: 89%
# question: 47%
# question: 97%
# question: 91%
# answer: 95%
# answer: 95%
# question: 84%
# answer: 74%
# answer: 64%
# answer: 97%
# question: 97%
# answer: 93%
# answer: 98%
# question: 95%
# question: 67%
# answer: 35%
# question: 97%
# answer: 98%
# question: 97%
# answer: 98%
# answer: 97%
# answer: 73%
# answer: 94%
# Unable to init server: Could not connect: Connection refused
#
# (predictions:39459): Gtk-WARNING **: 17:59:19.790: cannot open display:

# %%
mostrarImagen(abrirImagen('predictions.jpg'))

# %% [markdown]
# #### Reescalamos las imagenes

# %%
import cv2
from shutil import copyfile
# %mkdir newFacturas
for f in files:
  image = cv2.imread(str(f))
  imageOut = cv2.resize(image,(754,1000), interpolation=cv2.INTER_CUBIC)
  cv2.imwrite(str(Path('newFacturas')/f.name),imageOut)
  name=f.stem+'.txt'
  copyfile(f.parent/name, Path('newFacturas')/name)

# %%
path='newFacturas'
files = [Path(str(path)+'/'+p) for p in os.listdir(path) if p[-1]=='g']

# %%
txt=open('test.txt','w')
for f in files:
  txt.write(str(f)+'\n')
txt.close()

# %%
# !./darknet detector map classes.data cfg/funsd.cfg funsd_last.weights -iou_thresh 0.50 -points 101
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    640 x 640 x   3 ->  640 x 640 x  32 0.708 BF
#    1 conv     80       3 x 3/ 2    640 x 640 x  32 ->  320 x 320 x  80 4.719 BF
#    2 conv     40       1 x 1/ 1    320 x 320 x  80 ->  320 x 320 x  40 0.655 BF
#    3 conv     80       3 x 3/ 1    320 x 320 x  40 ->  320 x 320 x  80 5.898 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 320 x 320 x  80 0.008 BF
#    5 conv    160       3 x 3/ 2    320 x 320 x  80 ->  160 x 160 x 160 5.898 BF
#    6 conv     80       1 x 1/ 1    160 x 160 x 160 ->  160 x 160 x  80 0.655 BF
#    7 route  5 		                           ->  160 x 160 x 160
#    8 conv     80       1 x 1/ 1    160 x 160 x 160 ->  160 x 160 x  80 0.655 BF
#    9 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   10 conv     80       3 x 3/ 1    160 x 160 x  80 ->  160 x 160 x  80 2.949 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 160 x 160 x  80 0.002 BF
#   12 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   13 conv     80       3 x 3/ 1    160 x 160 x  80 ->  160 x 160 x  80 2.949 BF
#   14 Shortcut Layer: 11,  wt = 0, wn = 0, outputs: 160 x 160 x  80 0.002 BF
#   15 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   16 conv     80       3 x 3/ 1    160 x 160 x  80 ->  160 x 160 x  80 2.949 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 160 x 160 x  80 0.002 BF
#   18 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   19 route  18 6 	                           ->  160 x 160 x 160
#   20 conv    160       1 x 1/ 1    160 x 160 x 160 ->  160 x 160 x 160 1.311 BF
#   21 conv    320       3 x 3/ 2    160 x 160 x 160 ->   80 x  80 x 320 5.898 BF
#   22 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#   23 route  21 		                           ->   80 x  80 x 320
#   24 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#   25 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   26 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   28 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   29 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   31 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   32 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   34 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   35 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   37 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   38 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   40 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   41 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   43 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   44 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   46 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   47 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   49 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   50 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   52 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   53 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   54 Shortcut Layer: 51,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   55 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   56 route  55 22 	                           ->   80 x  80 x 320
#   57 conv    320       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 320 1.311 BF
#   58 conv    640       3 x 3/ 2     80 x  80 x 320 ->   40 x  40 x 640 5.898 BF
#   59 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#   60 route  58 		                           ->   40 x  40 x 640
#   61 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#   62 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   63 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   65 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   66 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   68 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   69 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   71 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   72 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   74 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   75 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   77 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   78 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   80 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   81 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   83 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   84 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   85 Shortcut Layer: 82,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   86 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   87 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   88 Shortcut Layer: 85,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   89 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   90 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   91 Shortcut Layer: 88,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   92 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   93 route  92 59 	                           ->   40 x  40 x 640
#   94 conv    640       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 640 1.311 BF
#   95 conv   1280       3 x 3/ 2     40 x  40 x 640 ->   20 x  20 x1280 5.898 BF
#   96 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#   97 route  95 		                           ->   20 x  20 x1280
#   98 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#   99 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  100 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  102 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  103 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  104 Shortcut Layer: 101,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  105 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  106 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  107 Shortcut Layer: 104,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  108 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  109 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  110 Shortcut Layer: 107,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  111 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  112 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  113 Shortcut Layer: 110,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  114 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  115 route  114 96 	                           ->   20 x  20 x1280
#  116 conv   1280       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x1280 1.311 BF
#  117 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  118 route  116 		                           ->   20 x  20 x1280
#  119 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  120 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  121 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  122 max                5x 5/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.006 BF
#  123 route  121 		                           ->   20 x  20 x 640
#  124 max                9x 9/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.021 BF
#  125 route  121 		                           ->   20 x  20 x 640
#  126 max               13x13/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.043 BF
#  127 route  126 124 122 121 	                   ->   20 x  20 x2560
#  128 conv    640       1 x 1/ 1     20 x  20 x2560 ->   20 x  20 x 640 1.311 BF
#  129 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  130 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  131 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  132 route  131 117 	                           ->   20 x  20 x1280
#  133 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  134 conv    320       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 320 0.164 BF
#  135 upsample                 2x    20 x  20 x 320 ->   40 x  40 x 320
#  136 route  94 		                           ->   40 x  40 x 640
#  137 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  138 route  137 135 	                           ->   40 x  40 x 640
#  139 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  140 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  141 route  139 		                           ->   40 x  40 x 320
#  142 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  143 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  144 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  145 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  146 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  147 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  148 route  147 140 	                           ->   40 x  40 x 640
#  149 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  150 conv    160       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 160 0.164 BF
#  151 upsample                 2x    40 x  40 x 160 ->   80 x  80 x 160
#  152 route  57 		                           ->   80 x  80 x 320
#  153 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#  154 route  153 151 	                           ->   80 x  80 x 320
#  155 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#  156 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  157 route  155 		                           ->   80 x  80 x 160
#  158 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  159 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#  160 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  161 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#  162 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  163 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#  164 route  163 156 	                           ->   80 x  80 x 320
#  165 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#  166 conv    320       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 320 5.898 BF
#  167 conv     27       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x  27 0.111 BF
#  168 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 4.00, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
#  169 route  165 		                           ->   80 x  80 x 160
#  170 conv    320       3 x 3/ 2     80 x  80 x 160 ->   40 x  40 x 320 1.475 BF
#  171 route  170 149 	                           ->   40 x  40 x 640
#  172 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  173 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  174 route  172 		                           ->   40 x  40 x 320
#  175 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  176 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  177 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  178 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  179 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  180 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  181 route  180 173 	                           ->   40 x  40 x 640
#  182 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  183 conv    640       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 640 5.898 BF
#  184 conv     27       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x  27 0.055 BF
#  185 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 1.00, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
#  186 route  182 		                           ->   40 x  40 x 320
#  187 conv    640       3 x 3/ 2     40 x  40 x 320 ->   20 x  20 x 640 1.475 BF
#  188 route  187 133 	                           ->   20 x  20 x1280
#  189 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  190 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  191 route  189 		                           ->   20 x  20 x 640
#  192 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  193 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  194 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  195 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  196 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  197 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  198 route  197 190 	                           ->   20 x  20 x1280
#  199 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  200 conv   1280       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x1280 5.898 BF
#  201 conv     27       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x  27 0.028 BF
#  202 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 0.40, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
# Total BFLOPS 220.352
# avg_outputs = 1000634
#  Allocate additional workspace_size = 81.93 MB
# Loading weights from funsd_last.weights...
#  seen 64, trained: 582 K-images (9 Kilo-batches_64)
# Done! Loaded 203 layers from weights-file
#
#  calculation mAP (mean average precision)...
#  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# 28
#  detections_count = 8266, unique_truth_count = 1704
# class_id = 0, name = answer, ap = 19.56%   	 (TP = 291, FP = 785)
# class_id = 1, name = question, ap = 28.05%   	 (TP = 249, FP = 397)
# class_id = 2, name = header, ap = 11.70%   	 (TP = 13, FP = 24)
# class_id = 3, name = other, ap = 1.66%   	 (TP = 2, FP = 118)
#
#  for conf_thresh = 0.25, precision = 0.30, recall = 0.33, F1-score = 0.31
#  for conf_thresh = 0.25, TP = 555, FP = 1324, FN = 1149, average IoU = 19.53 %
#
#  IoU threshold = 50 %, used 101 Recall-points
#  mean average precision (mAP@0.50) = 0.152421, or 15.24 %
# Total Detection Time: 2 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %% [markdown]
# mAP= 15.24 %
#
# precision = 0.30
#
# recall = 0.33
#
# F1-score = 0.31

# %% [markdown]
# ### Localización

# %%
# !./darknet detector test classes.data cfg/funsd.cfg funsd_last.weights -ext_output -dont_show -out result.json < test.txt
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    640 x 640 x   3 ->  640 x 640 x  32 0.708 BF
#    1 conv     80       3 x 3/ 2    640 x 640 x  32 ->  320 x 320 x  80 4.719 BF
#    2 conv     40       1 x 1/ 1    320 x 320 x  80 ->  320 x 320 x  40 0.655 BF
#    3 conv     80       3 x 3/ 1    320 x 320 x  40 ->  320 x 320 x  80 5.898 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 320 x 320 x  80 0.008 BF
#    5 conv    160       3 x 3/ 2    320 x 320 x  80 ->  160 x 160 x 160 5.898 BF
#    6 conv     80       1 x 1/ 1    160 x 160 x 160 ->  160 x 160 x  80 0.655 BF
#    7 route  5 		                           ->  160 x 160 x 160
#    8 conv     80       1 x 1/ 1    160 x 160 x 160 ->  160 x 160 x  80 0.655 BF
#    9 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   10 conv     80       3 x 3/ 1    160 x 160 x  80 ->  160 x 160 x  80 2.949 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 160 x 160 x  80 0.002 BF
#   12 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   13 conv     80       3 x 3/ 1    160 x 160 x  80 ->  160 x 160 x  80 2.949 BF
#   14 Shortcut Layer: 11,  wt = 0, wn = 0, outputs: 160 x 160 x  80 0.002 BF
#   15 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   16 conv     80       3 x 3/ 1    160 x 160 x  80 ->  160 x 160 x  80 2.949 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 160 x 160 x  80 0.002 BF
#   18 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   19 route  18 6 	                           ->  160 x 160 x 160
#   20 conv    160       1 x 1/ 1    160 x 160 x 160 ->  160 x 160 x 160 1.311 BF
#   21 conv    320       3 x 3/ 2    160 x 160 x 160 ->   80 x  80 x 320 5.898 BF
#   22 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#   23 route  21 		                           ->   80 x  80 x 320
#   24 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#   25 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   26 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   28 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   29 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   31 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   32 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   34 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   35 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   37 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   38 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   40 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   41 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   43 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   44 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   46 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   47 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   49 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   50 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   52 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   53 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   54 Shortcut Layer: 51,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   55 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   56 route  55 22 	                           ->   80 x  80 x 320
#   57 conv    320       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 320 1.311 BF
#   58 conv    640       3 x 3/ 2     80 x  80 x 320 ->   40 x  40 x 640 5.898 BF
#   59 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#   60 route  58 		                           ->   40 x  40 x 640
#   61 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#   62 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   63 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   65 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   66 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   68 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   69 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   71 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   72 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   74 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   75 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   77 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   78 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   80 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   81 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   83 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   84 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   85 Shortcut Layer: 82,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   86 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   87 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   88 Shortcut Layer: 85,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   89 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   90 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   91 Shortcut Layer: 88,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   92 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   93 route  92 59 	                           ->   40 x  40 x 640
#   94 conv    640       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 640 1.311 BF
#   95 conv   1280       3 x 3/ 2     40 x  40 x 640 ->   20 x  20 x1280 5.898 BF
#   96 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#   97 route  95 		                           ->   20 x  20 x1280
#   98 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#   99 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  100 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  102 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  103 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  104 Shortcut Layer: 101,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  105 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  106 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  107 Shortcut Layer: 104,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  108 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  109 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  110 Shortcut Layer: 107,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  111 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  112 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  113 Shortcut Layer: 110,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  114 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  115 route  114 96 	                           ->   20 x  20 x1280
#  116 conv   1280       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x1280 1.311 BF
#  117 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  118 route  116 		                           ->   20 x  20 x1280
#  119 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  120 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  121 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  122 max                5x 5/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.006 BF
#  123 route  121 		                           ->   20 x  20 x 640
#  124 max                9x 9/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.021 BF
#  125 route  121 		                           ->   20 x  20 x 640
#  126 max               13x13/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.043 BF
#  127 route  126 124 122 121 	                   ->   20 x  20 x2560
#  128 conv    640       1 x 1/ 1     20 x  20 x2560 ->   20 x  20 x 640 1.311 BF
#  129 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  130 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  131 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  132 route  131 117 	                           ->   20 x  20 x1280
#  133 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  134 conv    320       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 320 0.164 BF
#  135 upsample                 2x    20 x  20 x 320 ->   40 x  40 x 320
#  136 route  94 		                           ->   40 x  40 x 640
#  137 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  138 route  137 135 	                           ->   40 x  40 x 640
#  139 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  140 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  141 route  139 		                           ->   40 x  40 x 320
#  142 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  143 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  144 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  145 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  146 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  147 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  148 route  147 140 	                           ->   40 x  40 x 640
#  149 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  150 conv    160       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 160 0.164 BF
#  151 upsample                 2x    40 x  40 x 160 ->   80 x  80 x 160
#  152 route  57 		                           ->   80 x  80 x 320
#  153 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#  154 route  153 151 	                           ->   80 x  80 x 320
#  155 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#  156 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  157 route  155 		                           ->   80 x  80 x 160
#  158 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  159 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#  160 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  161 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#  162 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  163 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#  164 route  163 156 	                           ->   80 x  80 x 320
#  165 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#  166 conv    320       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 320 5.898 BF
#  167 conv     27       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x  27 0.111 BF
#  168 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 4.00, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
#  169 route  165 		                           ->   80 x  80 x 160
#  170 conv    320       3 x 3/ 2     80 x  80 x 160 ->   40 x  40 x 320 1.475 BF
#  171 route  170 149 	                           ->   40 x  40 x 640
#  172 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  173 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  174 route  172 		                           ->   40 x  40 x 320
#  175 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  176 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  177 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  178 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  179 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  180 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  181 route  180 173 	                           ->   40 x  40 x 640
#  182 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  183 conv    640       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 640 5.898 BF
#  184 conv     27       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x  27 0.055 BF
#  185 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 1.00, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
#  186 route  182 		                           ->   40 x  40 x 320
#  187 conv    640       3 x 3/ 2     40 x  40 x 320 ->   20 x  20 x 640 1.475 BF
#  188 route  187 133 	                           ->   20 x  20 x1280
#  189 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  190 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  191 route  189 		                           ->   20 x  20 x 640
#  192 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  193 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  194 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  195 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  196 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  197 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  198 route  197 190 	                           ->   20 x  20 x1280
#  199 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  200 conv   1280       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x1280 5.898 BF
#  201 conv     27       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x  27 0.028 BF
#  202 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 0.40, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
# Total BFLOPS 220.352
# avg_outputs = 1000634
#  Allocate additional workspace_size = 81.93 MB
# Loading weights from funsd_last.weights...
#  seen 64, trained: 582 K-images (9 Kilo-batches_64)
# Done! Loaded 203 layers from weights-file
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/27.png: Predicted in 80.498000 milli-seconds.
# question: 90%	(left_x:   66   top_y:  180   width:   22   height:   30)
# question: 70%	(left_x:   69   top_y:  116   width:   97   height:   22)
# answer: 29%	(left_x:   69   top_y:  116   width:   97   height:   22)
# question: 92%	(left_x:   70   top_y:   93   width:   36   height:   20)
# question: 97%	(left_x:   72   top_y:  231   width:  108   height:   22)
# question: 89%	(left_x:   84   top_y:  340   width:   99   height:   20)
# question: 93%	(left_x:   85   top_y:  288   width:   96   height:   20)
# question: 98%	(left_x:   92   top_y:  261   width:   90   height:   19)
# question: 64%	(left_x:  117   top_y:  317   width:   65   height:   17)
# other: 69%	(left_x:  173   top_y:  599   width:  338   height:   62)
# other: 36%	(left_x:  185   top_y:  684   width:  295   height:   69)
# other: 70%	(left_x:  190   top_y: 1091   width:  243   height:   59)
# other: 79%	(left_x:  193   top_y: 1434   width:  245   height:   49)
# other: 79%	(left_x:  193   top_y:  810   width:  258   height:   66)
# answer: 60%	(left_x:  193   top_y:  603   width:  304   height:   51)
# answer: 88%	(left_x:  193   top_y:  673   width:  275   height:   28)
# other: 95%	(left_x:  194   top_y: 1317   width:  247   height:   36)
# other: 85%	(left_x:  195   top_y:  919   width:  251   height:   54)
# other: 99%	(left_x:  196   top_y: 1225   width:  238   height:   58)
# other: 73%	(left_x:  197   top_y:  392   width:  265   height:   57)
# answer: 40%	(left_x:  197   top_y:  392   width:  265   height:   57)
# other: 97%	(left_x:  197   top_y: 1148   width:  237   height:   43)
# other: 46%	(left_x:  197   top_y:  716   width:  241   height:   36)
# answer: 46%	(left_x:  197   top_y:  716   width:  241   height:   36)
# other: 96%	(left_x:  197   top_y: 1014   width:  245   height:   58)
# answer: 65%	(left_x:  198   top_y: 1091   width:  245   height:   51)
# answer: 95%	(left_x:  198   top_y:  495   width:  233   height:   24)
# answer: 82%	(left_x:  198   top_y:  224   width:  268   height:   43)
# answer: 50%	(left_x:  200   top_y:  812   width:  257   height:   58)
# answer: 76%	(left_x:  200   top_y:  430   width:  266   height:   20)
# answer: 96%	(left_x:  202   top_y:  283   width:  227   height:   40)
# answer: 98%	(left_x:  212   top_y:  166   width:  132   height:   26)
# header: 55%	(left_x:  261   top_y:   96   width:  273   height:   43)
# header: 25%	(left_x:  263   top_y:   94   width:  240   height:   20)
# answer: 39%	(left_x:  349   top_y: 1692   width:  559   height:   41)
# other: 69%	(left_x:  351   top_y: 1694   width:  556   height:   42)
# answer: 96%	(left_x:  483   top_y: 1403   width:   31   height:   21)
# answer: 96%	(left_x:  483   top_y: 1381   width:   30   height:   19)
# answer: 93%	(left_x:  484   top_y: 1335   width:   29   height:   20)
# answer: 99%	(left_x:  484   top_y:  921   width:   29   height:   18)
# question: 86%	(left_x:  484   top_y: 1252   width:   27   height:   24)
# answer: 99%	(left_x:  484   top_y:  945   width:   27   height:   17)
# answer: 91%	(left_x:  484   top_y: 1044   width:   29   height:   20)
# answer: 92%	(left_x:  484   top_y: 1357   width:   28   height:   20)
# answer: 96%	(left_x:  484   top_y:  553   width:   27   height:   19)
# other: 80%	(left_x:  484   top_y: 1193   width:   28   height:   21)
# answer: 95%	(left_x:  485   top_y:  530   width:   27   height:   18)
# answer: 97%	(left_x:  485   top_y:  509   width:   27   height:   17)
# answer: 99%	(left_x:  485   top_y:  967   width:   27   height:   17)
# answer: 81%	(left_x:  485   top_y:  897   width:   27   height:   20)
# other: 67%	(left_x:  485   top_y: 1173   width:   27   height:   20)
# answer: 31%	(left_x:  485   top_y: 1173   width:   27   height:   20)
# answer: 83%	(left_x:  485   top_y: 1312   width:   28   height:   20)
# answer: 91%	(left_x:  485   top_y:  575   width:   27   height:   18)
# answer: 87%	(left_x:  485   top_y: 1150   width:   26   height:   21)
# answer: 74%	(left_x:  486   top_y:  739   width:   24   height:   20)
# answer: 69%	(left_x:  486   top_y:  486   width:   27   height:   18)
# question: 35%	(left_x:  486   top_y:  486   width:   27   height:   18)
# answer: 96%	(left_x:  486   top_y:  760   width:   24   height:   17)
# answer: 64%	(left_x:  486   top_y:  322   width:   26   height:   16)
# question: 87%	(left_x:  486   top_y: 1461   width:   27   height:   20)
# answer: 98%	(left_x:  486   top_y:  988   width:   25   height:   17)
# answer: 85%	(left_x:  486   top_y:  690   width:   26   height:   20)
# answer: 92%	(left_x:  486   top_y: 1128   width:   26   height:   19)
# question: 75%	(left_x:  487   top_y:  274   width:   26   height:   18)
# answer: 26%	(left_x:  487   top_y:  274   width:   26   height:   18)
# answer: 96%	(left_x:  487   top_y:  345   width:   26   height:   17)
# answer: 88%	(left_x:  487   top_y:  298   width:   25   height:   18)
# answer: 98%	(left_x:  487   top_y:  424   width:   24   height:   20)
# answer: 98%	(left_x:  487   top_y:  838   width:   23   height:   21)
# answer: 82%	(left_x:  488   top_y: 1104   width:   26   height:   19)
# answer: 97%	(left_x:  488   top_y:  714   width:   23   height:   18)
# answer: 97%	(left_x:  488   top_y:  782   width:   22   height:   16)
# answer: 96%	(left_x:  488   top_y:  369   width:   24   height:   17)
# question: 93%	(left_x:  565   top_y:  233   width:  113   height:   18)
# answer: 97%	(left_x:  728   top_y:  423   width:   60   height:   24)
# answer: 95%	(left_x:  729   top_y:  365   width:   58   height:   24)
# answer: 27%	(left_x:  784   top_y:  625   width:   17   height:   30)
# question: 95%	(left_x:  795   top_y:  230   width:   55   height:   24)
# answer: 91%	(left_x:  812   top_y:  843   width:   23   height:   16)
# answer: 99%	(left_x:  815   top_y: 1195   width:   19   height:   18)
# answer: 99%	(left_x:  816   top_y: 1381   width:   20   height:   20)
# answer: 99%	(left_x:  816   top_y:  968   width:   20   height:   17)
# answer: 96%	(left_x:  816   top_y: 1175   width:   18   height:   18)
# answer: 98%	(left_x:  816   top_y:  368   width:   16   height:   17)
# answer: 99%	(left_x:  816   top_y:  923   width:   16   height:   17)
# answer: 99%	(left_x:  817   top_y: 1359   width:   16   height:   18)
# answer: 99%	(left_x:  817   top_y:  991   width:   18   height:   16)
# answer: 99%	(left_x:  817   top_y: 1405   width:   18   height:   19)
# answer: 99%	(left_x:  817   top_y:  946   width:   16   height:   17)
# answer: 99%	(left_x:  817   top_y:  783   width:   17   height:   18)
# answer: 99%	(left_x:  817   top_y: 1338   width:   15   height:   14)
# answer: 99%	(left_x:  817   top_y:  574   width:   17   height:   17)
# answer: 99%	(left_x:  818   top_y:  741   width:   15   height:   15)
# answer: 99%	(left_x:  818   top_y:  346   width:   17   height:   15)
# answer: 98%	(left_x:  818   top_y: 1151   width:   14   height:   17)
# answer: 99%	(left_x:  818   top_y:  323   width:   15   height:   16)
# answer: 97%	(left_x:  818   top_y:  900   width:   13   height:   19)
# answer: 99%	(left_x:  818   top_y: 1314   width:   14   height:   19)
# answer: 99%	(left_x:  818   top_y:  762   width:   17   height:   17)
# answer: 99%	(left_x:  818   top_y:  553   width:   16   height:   17)
# answer: 98%	(left_x:  818   top_y:  693   width:   14   height:   20)
# answer: 95%	(left_x:  818   top_y:  276   width:   14   height:   18)
# answer: 96%	(left_x:  819   top_y:  301   width:   14   height:   12)
# answer: 99%	(left_x:  819   top_y:  510   width:   14   height:   13)
# answer: 98%	(left_x:  819   top_y: 1130   width:   14   height:   14)
# answer: 98%	(left_x:  819   top_y:  719   width:   13   height:   13)
# answer: 99%	(left_x:  819   top_y: 1108   width:   14   height:   18)
# answer: 99%	(left_x:  819   top_y:  532   width:   13   height:   15)
# answer: 98%	(left_x:  820   top_y:  486   width:   12   height:   18)
# answer: 80%	(left_x:  868   top_y:  626   width:   36   height:   27)
# answer: 54%	(left_x:  871   top_y: 1458   width:   24   height:   24)
# answer: 97%	(left_x:  872   top_y:  895   width:   28   height:   22)
# answer: 99%	(left_x:  872   top_y: 1310   width:   28   height:   21)
# answer: 99%	(left_x:  872   top_y: 1334   width:   29   height:   19)
# answer: 99%	(left_x:  872   top_y:  942   width:   28   height:   21)
# answer: 93%	(left_x:  872   top_y:  688   width:   28   height:   22)
# answer: 99%	(left_x:  872   top_y:  918   width:   28   height:   21)
# answer: 88%	(left_x:  872   top_y:  529   width:   27   height:   19)
# answer: 88%	(left_x:  873   top_y:  737   width:   25   height:   17)
# answer: 98%	(left_x:  873   top_y: 1381   width:   28   height:   19)
# answer: 95%	(left_x:  873   top_y:  575   width:   28   height:   17)
# answer: 99%	(left_x:  873   top_y: 1357   width:   27   height:   20)
# answer: 97%	(left_x:  873   top_y:  713   width:   27   height:   18)
# answer: 98%	(left_x:  873   top_y: 1102   width:   27   height:   22)
# answer: 91%	(left_x:  873   top_y:  552   width:   26   height:   18)
# answer: 90%	(left_x:  873   top_y:  508   width:   27   height:   17)
# answer: 88%	(left_x:  873   top_y:  320   width:   27   height:   16)
# answer: 98%	(left_x:  873   top_y: 1149   width:   26   height:   21)
# answer: 98%	(left_x:  873   top_y:  759   width:   23   height:   18)
# answer: 97%	(left_x:  873   top_y: 1174   width:   26   height:   17)
# answer: 85%	(left_x:  873   top_y:  274   width:   27   height:   19)
# answer: 98%	(left_x:  873   top_y:  964   width:   27   height:   18)
# answer: 63%	(left_x:  874   top_y:  485   width:   26   height:   20)
# question: 44%	(left_x:  874   top_y:  485   width:   26   height:   20)
# answer: 98%	(left_x:  874   top_y: 1127   width:   26   height:   19)
# answer: 94%	(left_x:  874   top_y:  297   width:   26   height:   17)
# answer: 98%	(left_x:  874   top_y: 1043   width:   27   height:   24)
# answer: 97%	(left_x:  874   top_y:  345   width:   25   height:   17)
# answer: 98%	(left_x:  874   top_y: 1403   width:   26   height:   20)
# answer: 99%	(left_x:  874   top_y:  988   width:   26   height:   20)
# answer: 99%	(left_x:  875   top_y: 1194   width:   25   height:   19)
# answer: 98%	(left_x:  875   top_y:  836   width:   25   height:   25)
# answer: 99%	(left_x:  875   top_y: 1251   width:   24   height:   24)
# answer: 98%	(left_x:  875   top_y:  782   width:   23   height:   17)
# answer: 97%	(left_x:  875   top_y:  368   width:   24   height:   16)
# answer: 98%	(left_x:  876   top_y:  425   width:   23   height:   20)
# question: 77%	(left_x: 1011   top_y:  230   width:  120   height:   20)
# answer: 98%	(left_x: 1088   top_y:   95   width:   65   height:   27)
# answer: 77%	(left_x: 1126   top_y:  365   width:   51   height:   23)
# answer: 85%	(left_x: 1126   top_y:  423   width:   52   height:   24)
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/25.png: Predicted in 80.623000 milli-seconds.
# question: 95%	(left_x:  156   top_y:  641   width:  298   height:   26)
# answer: 76%	(left_x:  157   top_y:  341   width:   88   height:   27)
# question: 95%	(left_x:  158   top_y:  559   width:  126   height:   26)
# question: 36%	(left_x:  158   top_y:  342   width:   88   height:   27)
# question: 92%	(left_x:  159   top_y:  823   width:  129   height:   23)
# question: 85%	(left_x:  160   top_y:  384   width:  473   height:   32)
# question: 90%	(left_x:  161   top_y:  469   width:  255   height:   26)
# question: 96%	(left_x:  161   top_y:  603   width:  144   height:   23)
# question: 97%	(left_x:  162   top_y:  685   width:  119   height:   22)
# other: 56%	(left_x:  173   top_y:  105   width:  133   height:  120)
# answer: 88%	(left_x:  194   top_y:  857   width:  308   height:   30)
# question: 87%	(left_x:  195   top_y:  426   width:  308   height:   28)
# answer: 30%	(left_x:  199   top_y:  823   width:  304   height:   27)
# header: 73%	(left_x:  347   top_y:  118   width:  684   height:   82)
# other: 86%	(left_x:  357   top_y: 1693   width:  551   height:   47)
# answer: 99%	(left_x:  427   top_y:  466   width:  248   height:   30)
# answer: 97%	(left_x:  535   top_y:  597   width:  126   height:   27)
# question: 36%	(left_x:  537   top_y:  683   width:   68   height:   27)
# answer: 67%	(left_x:  537   top_y:  683   width:   68   height:   26)
# answer: 99%	(left_x:  541   top_y:  634   width:  309   height:   33)
# answer: 98%	(left_x:  570   top_y:  422   width:  220   height:   31)
# answer: 95%	(left_x:  820   top_y:  215   width:  188   height:   37)
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/20.jpg: Predicted in 80.613000 milli-seconds.
# other: 55%	(left_x:   64   top_y: 1163   width:   20   height:  278)
# other: 38%	(left_x:   64   top_y:  634   width:   27   height:  214)
# other: 26%	(left_x:   67   top_y:  582   width:   26   height:  155)
# other: 28%	(left_x:   71   top_y:  623   width:   30   height:  192)
# other: 46%	(left_x:  139   top_y:   62   width:  453   height:   96)
# question: 76%	(left_x:  150   top_y: 1068   width:   68   height:   30)
# question: 82%	(left_x:  151   top_y:  777   width:  146   height:   28)
# question: 92%	(left_x:  153   top_y:  977   width:   68   height:   34)
# question: 62%	(left_x:  155   top_y:  869   width:   68   height:   27)
# question: 84%	(left_x:  157   top_y:  154   width:  403   height:   36)
# question: 93%	(left_x:  157   top_y:  719   width:   83   height:   26)
# question: 68%	(left_x:  157   top_y:   74   width:  409   height:   73)
# question: 94%	(left_x:  157   top_y:  827   width:  106   height:   26)
# question: 87%	(left_x:  158   top_y:  546   width:  101   height:   29)
# question: 48%	(left_x:  160   top_y:  310   width:  254   height:   42)
# question: 93%	(left_x:  163   top_y:  513   width:  150   height:   31)
# question: 95%	(left_x:  163   top_y:  412   width:  176   height:   25)
# question: 41%	(left_x:  165   top_y:  440   width:  196   height:   26)
# other: 38%	(left_x:  173   top_y: 2031   width:  777   height:   36)
# header: 31%	(left_x:  184   top_y:  244   width: 1349   height:   83)
# question: 93%	(left_x:  188   top_y: 2078   width:  143   height:   27)
# answer: 48%	(left_x:  243   top_y:  363   width:  234   height:   37)
# answer: 47%	(left_x:  249   top_y:  415   width:  570   height:   82)
# question: 96%	(left_x:  254   top_y: 2117   width:   80   height:   27)
# answer: 96%	(left_x:  303   top_y:  720   width:   82   height:   28)
# answer: 81%	(left_x:  330   top_y:  513   width:  113   height:   33)
# answer: 91%	(left_x:  335   top_y:  545   width:   77   height:   27)
# answer: 96%	(left_x:  365   top_y:  779   width:   88   height:   27)
# answer: 81%	(left_x:  381   top_y:  428   width:  318   height:   65)
# answer: 58%	(left_x:  382   top_y: 2079   width:   79   height:   31)
# other: 46%	(left_x:  422   top_y: 1091   width: 1015   height:   97)
# answer: 50%	(left_x:  422   top_y: 1090   width:  973   height:   99)
# other: 40%	(left_x:  440   top_y:  901   width: 1051   height:   88)
# answer: 59%	(left_x:  458   top_y: 1014   width:  662   height:   41)
# answer: 89%	(left_x:  459   top_y:  987   width:  271   height:   29)
# question: 63%	(left_x:  482   top_y:  723   width:  131   height:   28)
# question: 95%	(left_x:  484   top_y:  832   width:  165   height:   25)
# answer: 43%	(left_x:  486   top_y:  722   width:  123   height:   29)
# question: 35%	(left_x:  502   top_y: 2081   width:  101   height:   28)
# answer: 35%	(left_x:  505   top_y:  365   width:   92   height:   37)
# question: 74%	(left_x:  528   top_y:  782   width:  252   height:   27)
# answer: 28%	(left_x:  528   top_y:  782   width:  252   height:   27)
# answer: 29%	(left_x:  637   top_y:  320   width:  112   height:   36)
# question: 88%	(left_x:  670   top_y:  833   width:  150   height:   26)
# question: 96%	(left_x:  688   top_y: 2083   width:  116   height:   29)
# answer: 93%	(left_x:  717   top_y: 2123   width:   63   height:   27)
# header: 42%	(left_x:  857   top_y:  425   width:  418   height:  117)
# question: 63%	(left_x:  861   top_y: 2084   width:  205   height:   31)
# answer: 62%	(left_x:  864   top_y:  426   width:  425   height:  113)
# answer: 94%	(left_x:  870   top_y: 2124   width:   62   height:   26)
# question: 96%	(left_x:  881   top_y:  680   width:  151   height:   24)
# answer: 57%	(left_x:  888   top_y:  837   width:   69   height:   23)
# question: 33%	(left_x:  889   top_y:  835   width:   61   height:   23)
# other: 36%	(left_x:  972   top_y:   66   width:  225   height:  116)
# answer: 93%	(left_x:  977   top_y:   68   width:  214   height:  123)
# answer: 95%	(left_x:  981   top_y: 2124   width:   56   height:   26)
# question: 98%	(left_x:  981   top_y:  191   width:  128   height:   22)
# header: 35%	(left_x:  981   top_y:   53   width:  120   height:   23)
# question: 37%	(left_x:  984   top_y:  173   width:  205   height:   21)
# answer: 38%	(left_x: 1082   top_y:  729   width:  100   height:   26)
# question: 54%	(left_x: 1082   top_y:  729   width:  100   height:   27)
# question: 96%	(left_x: 1092   top_y: 2083   width:  224   height:   35)
# answer: 95%	(left_x: 1105   top_y: 2126   width:   48   height:   25)
# answer: 99%	(left_x: 1160   top_y:  625   width:  352   height:   31)
# other: 57%	(left_x: 1162   top_y: 1079   width:   16   height:   28)
# answer: 64%	(left_x: 1162   top_y:  879   width:   18   height:   27)
# other: 32%	(left_x: 1162   top_y:  879   width:   18   height:   27)
# answer: 93%	(left_x: 1164   top_y:  991   width:   14   height:   30)
# answer: 98%	(left_x: 1224   top_y: 2126   width:   46   height:   29)
# question: 80%	(left_x: 1287   top_y:  729   width:  298   height:   31)
# question: 92%	(left_x: 1375   top_y: 2087   width:  182   height:   30)
# other: 75%	(left_x: 1416   top_y:   57   width:  167   height:  154)
# answer: 97%	(left_x: 1428   top_y: 2126   width:   88   height:   29)
# question: 36%	(left_x: 1503   top_y: 1081   width:   59   height:   32)
# other: 29%	(left_x: 1503   top_y: 1082   width:   59   height:   31)
# question: 93%	(left_x: 1504   top_y:  993   width:   60   height:   33)
# question: 57%	(left_x: 1505   top_y:  880   width:   60   height:   32)
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/14.jpg: Predicted in 80.587000 milli-seconds.
# other: 48%	(left_x:   95   top_y: 1959   width:  302   height:   31)
# question: 28%	(left_x:   97   top_y: 2001   width:  113   height:   26)
# question: 47%	(left_x:  101   top_y: 1959   width:  298   height:   32)
# question: 88%	(left_x:  112   top_y:  726   width:   91   height:   30)
# question: 79%	(left_x:  135   top_y:  834   width:   49   height:   34)
# other: 89%	(left_x:  136   top_y:  928   width:   48   height:   31)
# other: 74%	(left_x:  156   top_y:  105   width:  331   height:  135)
# answer: 36%	(left_x:  162   top_y:  109   width:  309   height:  113)
# question: 36%	(left_x:  166   top_y:  208   width:  299   height:   37)
# other: 30%	(left_x:  166   top_y:  208   width:  299   height:   37)
# answer: 46%	(left_x:  176   top_y:  332   width:  284   height:  116)
# answer: 34%	(left_x:  182   top_y:  476   width:  265   height:   35)
# answer: 57%	(left_x:  183   top_y:  558   width:  267   height:   28)
# answer: 26%	(left_x:  186   top_y:  511   width:  260   height:   44)
# answer: 37%	(left_x:  193   top_y:  928   width:  728   height:   41)
# other: 27%	(left_x:  193   top_y:  928   width:  728   height:   41)
# answer: 72%	(left_x:  205   top_y:  593   width:  221   height:   67)
# answer: 26%	(left_x:  217   top_y:  630   width:  201   height:   31)
# question: 57%	(left_x:  218   top_y: 1019   width:   98   height:   28)
# answer: 38%	(left_x:  219   top_y: 1019   width:   99   height:   28)
# other: 70%	(left_x:  220   top_y: 1066   width:  127   height:   30)
# answer: 30%	(left_x:  228   top_y:  837   width:  972   height:   74)
# answer: 79%	(left_x:  269   top_y: 2002   width:   28   height:   25)
# answer: 92%	(left_x:  294   top_y: 2039   width:  202   height:   31)
# question: 67%	(left_x:  345   top_y: 2001   width:  123   height:   29)
# other: 62%	(left_x:  594   top_y: 2075   width:   95   height:   30)
# answer: 90%	(left_x:  638   top_y:  733   width:  155   height:   34)
# answer: 53%	(left_x:  675   top_y:  101   width:  126   height:   25)
# answer: 37%	(left_x:  676   top_y:  126   width:  147   height:   37)
# answer: 72%	(left_x:  677   top_y:  156   width:  180   height:   32)
# answer: 68%	(left_x:  679   top_y:  192   width:  120   height:   27)
# answer: 46%	(left_x:  741   top_y:  629   width:  198   height:   32)
# question: 47%	(left_x:  751   top_y:  300   width:   90   height:   28)
# header: 49%	(left_x:  788   top_y:  405   width:  278   height:   34)
# answer: 96%	(left_x:  792   top_y:  556   width:   85   height:   30)
# answer: 87%	(left_x:  792   top_y:  518   width:   65   height:   26)
# answer: 58%	(left_x:  793   top_y:  444   width:  163   height:   26)
# answer: 92%	(left_x:  805   top_y: 1923   width:   93   height:   36)
# question: 92%	(left_x:  819   top_y: 1847   width:  110   height:   36)
# answer: 78%	(left_x:  842   top_y:  631   width:  107   height:   29)
# answer: 80%	(left_x:  886   top_y:  298   width:   92   height:   29)
# question: 30%	(left_x:  906   top_y:  520   width:  118   height:   25)
# question: 98%	(left_x:  971   top_y: 2021   width:  221   height:   43)
# question: 93%	(left_x: 1000   top_y: 1849   width:  117   height:   35)
# answer: 86%	(left_x: 1017   top_y:  559   width:   80   height:   27)
# answer: 84%	(left_x: 1025   top_y: 1921   width:   94   height:   39)
# question: 26%	(left_x: 1086   top_y:  294   width:  259   height:   35)
# other: 27%	(left_x: 1099   top_y:  294   width:  256   height:   33)
# question: 83%	(left_x: 1137   top_y:  140   width:  253   height:   58)
# other: 88%	(left_x: 1169   top_y: 2202   width:   90   height:   89)
# question: 97%	(left_x: 1178   top_y:  709   width:   94   height:   49)
# question: 92%	(left_x: 1209   top_y:  837   width:   88   height:   30)
# other: 74%	(left_x: 1239   top_y:  930   width:   58   height:   29)
# answer: 97%	(left_x: 1258   top_y: 1923   width:   53   height:   37)
# answer: 98%	(left_x: 1264   top_y: 1843   width:   29   height:   36)
# question: 95%	(left_x: 1268   top_y: 2111   width:  258   height:   38)
# question: 85%	(left_x: 1310   top_y:  730   width:   86   height:   28)
# answer: 84%	(left_x: 1320   top_y: 2025   width:  196   height:   44)
# answer: 33%	(left_x: 1327   top_y:  631   width:   90   height:   32)
# other: 80%	(left_x: 1328   top_y:  835   width:   59   height:   29)
# answer: 97%	(left_x: 1406   top_y: 1924   width:   75   height:   33)
# answer: 95%	(left_x: 1411   top_y: 1847   width:   63   height:   36)
# question: 93%	(left_x: 1424   top_y:  731   width:   67   height:   23)
# other: 91%	(left_x: 1438   top_y:  928   width:   61   height:   30)
# answer: 88%	(left_x: 1463   top_y:  634   width:   17   height:   30)
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/12.jpg: Predicted in 80.640000 milli-seconds.
# answer: 85%	(left_x:   91   top_y: 2213   width:  225   height:   38)
# answer: 94%	(left_x:  114   top_y:   85   width:  374   height:   86)
# question: 92%	(left_x:  182   top_y: 1202   width:  304   height:   28)
# other: 75%	(left_x:  184   top_y: 1753   width:  574   height:   45)
# question: 90%	(left_x:  184   top_y:  979   width:  301   height:   44)
# answer: 80%	(left_x:  199   top_y:  772   width:  136   height:   38)
# answer: 43%	(left_x:  242   top_y:  193   width:  152   height:   38)
# question: 50%	(left_x:  411   top_y: 2211   width:  197   height:   38)
# header: 31%	(left_x:  412   top_y: 2166   width:  112   height:   25)
# question: 32%	(left_x:  423   top_y: 2239   width:  152   height:   26)
# answer: 98%	(left_x:  550   top_y: 1455   width:  171   height:   24)
# question: 95%	(left_x:  550   top_y: 1283   width:  204   height:   24)
# answer: 38%	(left_x:  552   top_y: 1207   width:   78   height:   21)
# header: 37%	(left_x:  552   top_y: 1207   width:   78   height:   21)
# answer: 79%	(left_x:  553   top_y: 1530   width:  154   height:   25)
# answer: 98%	(left_x:  553   top_y: 1481   width:  157   height:   24)
# question: 94%	(left_x:  553   top_y: 1233   width:   79   height:   19)
# question: 95%	(left_x:  553   top_y: 1056   width:  206   height:   24)
# question: 87%	(left_x:  554   top_y:  981   width:   76   height:   21)
# question: 96%	(left_x:  555   top_y: 1257   width:  142   height:   21)
# question: 97%	(left_x:  555   top_y: 1306   width:   64   height:   20)
# question: 97%	(left_x:  555   top_y: 1333   width:  123   height:   22)
# question: 89%	(left_x:  555   top_y: 1007   width:   78   height:   19)
# question: 98%	(left_x:  556   top_y: 1080   width:   61   height:   22)
# question: 99%	(left_x:  557   top_y: 1030   width:  147   height:   22)
# answer: 66%	(left_x:  560   top_y: 1105   width:  296   height:   26)
# answer: 94%	(left_x:  638   top_y: 2215   width:  284   height:   39)
# answer: 99%	(left_x:  638   top_y: 2164   width:  181   height:   24)
# answer: 98%	(left_x:  642   top_y: 2190   width:  178   height:   22)
# answer: 54%	(left_x:  682   top_y: 1333   width:  183   height:   22)
# question: 97%	(left_x:  783   top_y:  202   width:  272   height:   28)
# answer: 91%	(left_x:  786   top_y:  101   width:  271   height:   26)
# question: 93%	(left_x:  792   top_y:  253   width:  179   height:   27)
# answer: 91%	(left_x:  802   top_y:  304   width:  113   height:   24)
# header: 93%	(left_x:  855   top_y:  456   width:  303   height:  122)
# answer: 80%	(left_x:  919   top_y:  151   width:  206   height:   30)
# other: 88%	(left_x:  951   top_y: 2163   width:  281   height:   87)
# question: 85%	(left_x:  956   top_y: 2239   width:  158   height:   24)
# answer: 29%	(left_x:  978   top_y: 2163   width:  270   height:   83)
# answer: 87%	(left_x:  994   top_y:   52   width:   82   height:   27)
# question: 96%	(left_x: 1035   top_y:  253   width:  154   height:   28)
# answer: 97%	(left_x: 1036   top_y:  302   width:  126   height:   27)
# question: 98%	(left_x: 1285   top_y:  251   width:  135   height:   32)
# question: 39%	(left_x: 1312   top_y:  767   width:  102   height:   40)
# answer: 59%	(left_x: 1314   top_y:  767   width:  101   height:   40)
# answer: 48%	(left_x: 1320   top_y: 1529   width:   92   height:   27)
# answer: 92%	(left_x: 1323   top_y: 1204   width:   88   height:   27)
# answer: 70%	(left_x: 1324   top_y: 1457   width:   85   height:   44)
# answer: 92%	(left_x: 1329   top_y: 1229   width:   82   height:   28)
# answer: 98%	(left_x: 1340   top_y:  302   width:   44   height:   29)
# answer: 86%	(left_x: 1343   top_y:  106   width:  109   height:   24)
# answer: 95%	(left_x: 1359   top_y:  152   width:  168   height:   29)
# answer: 98%	(left_x: 1428   top_y:   54   width:   54   height:   26)
# question: 95%	(left_x: 1500   top_y:  254   width:   79   height:   26)
# answer: 98%	(left_x: 1501   top_y:  303   width:   40   height:   25)
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/07.jpg: Predicted in 80.629000 milli-seconds.
# question: 81%	(left_x:   54   top_y: 1024   width:  172   height:   31)
# question: 87%	(left_x:   54   top_y:  977   width:  132   height:   30)
# question: 89%	(left_x:   56   top_y:  886   width:  129   height:   30)
# question: 94%	(left_x:   59   top_y:  933   width:  120   height:   30)
# question: 97%	(left_x:   60   top_y:  842   width:  129   height:   29)
# question: 76%	(left_x:   61   top_y:  752   width:  120   height:   27)
# question: 91%	(left_x:   62   top_y:  797   width:  145   height:   28)
# answer: 89%	(left_x:   77   top_y:  617   width:  135   height:   32)
# answer: 77%	(left_x:   86   top_y: 2033   width:  118   height:   31)
# answer: 73%	(left_x:   91   top_y: 2181   width:  117   height:   30)
# question: 80%	(left_x:  101   top_y:  568   width:   89   height:   30)
# answer: 96%	(left_x:  112   top_y: 2080   width:   80   height:   36)
# question: 93%	(left_x:  120   top_y:  659   width:  165   height:   34)
# question: 93%	(left_x:  131   top_y: 2128   width:  195   height:   32)
# answer: 36%	(left_x:  140   top_y:  213   width:  396   height:  193)
# question: 96%	(left_x:  247   top_y: 2036   width:  128   height:   29)
# question: 62%	(left_x:  280   top_y:  569   width:   79   height:   29)
# answer: 60%	(left_x:  281   top_y:  571   width:   78   height:   29)
# answer: 60%	(left_x:  326   top_y: 2179   width:   73   height:   33)
# other: 41%	(left_x:  326   top_y: 2179   width:   73   height:   33)
# question: 82%	(left_x:  348   top_y:  702   width:  315   height:   31)
# question: 74%	(left_x:  361   top_y: 1020   width:  276   height:   30)
# question: 56%	(left_x:  367   top_y:  791   width:  409   height:   33)
# question: 84%	(left_x:  369   top_y:  973   width:  407   height:   31)
# question: 85%	(left_x:  369   top_y:  836   width:  411   height:   31)
# question: 84%	(left_x:  380   top_y:  926   width:  411   height:   33)
# question: 58%	(left_x:  387   top_y:  881   width:  411   height:   31)
# question: 96%	(left_x:  410   top_y: 2035   width:  116   height:   29)
# question: 88%	(left_x:  441   top_y:  569   width:  105   height:   29)
# answer: 96%	(left_x:  444   top_y: 2081   width:   56   height:   32)
# question: 97%	(left_x:  590   top_y:  658   width:  171   height:   30)
# question: 95%	(left_x:  590   top_y: 2036   width:  131   height:   28)
# question: 96%	(left_x:  612   top_y:  569   width:  104   height:   29)
# answer: 95%	(left_x:  615   top_y: 2081   width:   86   height:   32)
# question: 94%	(left_x:  787   top_y: 2034   width:  104   height:   29)
# answer: 96%	(left_x:  810   top_y: 2079   width:   55   height:   30)
# answer: 63%	(left_x:  828   top_y:  249   width:  488   height:  123)
# other: 37%	(left_x:  834   top_y:  253   width:  481   height:  126)
# answer: 94%	(left_x:  904   top_y:  565   width:  216   height:   32)
# question: 70%	(left_x:  933   top_y: 2035   width:   68   height:   29)
# answer: 90%	(left_x:  936   top_y: 2081   width:   55   height:   32)
# answer: 95%	(left_x:  946   top_y:  611   width:  137   height:   34)
# question: 58%	(left_x: 1006   top_y:  658   width:  125   height:   33)
# question: 97%	(left_x: 1014   top_y:  473   width:  140   height:   31)
# question: 92%	(left_x: 1026   top_y: 2034   width:  126   height:   29)
# answer: 88%	(left_x: 1045   top_y: 2081   width:   69   height:   31)
# answer: 98%	(left_x: 1061   top_y:  520   width:   50   height:   32)
# question: 37%	(left_x: 1094   top_y:  748   width:   41   height:   28)
# other: 41%	(left_x: 1106   top_y:  885   width:   28   height:   27)
# other: 26%	(left_x: 1109   top_y:  932   width:   24   height:   25)
# answer: 66%	(left_x: 1117   top_y:  795   width:   17   height:   28)
# other: 30%	(left_x: 1117   top_y:  795   width:   17   height:   28)
# answer: 74%	(left_x: 1119   top_y:  978   width:   12   height:   25)
# other: 34%	(left_x: 1120   top_y:  841   width:   14   height:   26)
# answer: 47%	(left_x: 1121   top_y: 1024   width:   11   height:   27)
# question: 74%	(left_x: 1171   top_y: 2128   width:  247   height:   32)
# question: 86%	(left_x: 1172   top_y:  653   width:   96   height:   36)
# question: 79%	(left_x: 1182   top_y: 2034   width:  126   height:   29)
# question: 98%	(left_x: 1194   top_y:  470   width:  237   height:   31)
# answer: 95%	(left_x: 1212   top_y: 2080   width:   57   height:   32)
# ...
# answer: 90%	(left_x:  399   top_y:  966   width:   14   height:   27)
# answer: 59%	(left_x:  400   top_y: 1007   width:   13   height:   29)
# answer: 75%	(left_x:  401   top_y:  897   width:   13   height:   26)
# answer: 96%	(left_x:  438   top_y: 1877   width:   20   height:   27)
# answer: 89%	(left_x:  481   top_y:  961   width:  598   height:   76)
# answer: 86%	(left_x:  498   top_y:  892   width:  583   height:   38)
# answer: 31%	(left_x:  506   top_y:  765   width:  533   height:   89)
# answer: 71%	(left_x:  529   top_y:  808   width:  411   height:   65)
# answer: 96%	(left_x:  546   top_y: 2155   width:  120   height:   44)
# question: 97%	(left_x:  560   top_y: 1826   width:  178   height:   18)
# answer: 97%	(left_x:  670   top_y: 1874   width:   87   height:   30)
# answer: 78%	(left_x:  683   top_y:  692   width:  207   height:   32)
# question: 65%	(left_x:  698   top_y:  580   width:   75   height:   27)
# answer: 60%	(left_x:  714   top_y: 1924   width:  284   height:   27)
# header: 26%	(left_x:  714   top_y: 1924   width:  284   height:   27)
# answer: 91%	(left_x:  740   top_y: 2082   width:  225   height:   22)
# answer: 96%	(left_x:  778   top_y:  508   width:  185   height:   39)
# answer: 97%	(left_x:  852   top_y: 1874   width:   61   height:   29)
# question: 96%	(left_x:  874   top_y:  470   width:   99   height:   24)
# answer: 57%	(left_x:  892   top_y:  356   width:  232   height:   30)
# question: 90%	(left_x:  894   top_y: 1823   width:   48   height:   22)
# answer: 33%	(left_x:  896   top_y:  147   width:  421   height:  209)
# answer: 91%	(left_x:  908   top_y:  111   width:  103   height:   34)
# answer: 97%	(left_x:  959   top_y: 1873   width:   68   height:   30)
# question: 92%	(left_x: 1073   top_y: 1824   width:  156   height:   22)
# question: 97%	(left_x: 1111   top_y:  692   width:  159   height:   33)
# question: 96%	(left_x: 1145   top_y:  759   width:   72   height:   32)
# answer: 98%	(left_x: 1162   top_y: 1875   width:   71   height:   29)
# other: 86%	(left_x: 1189   top_y:  804   width:   85   height:   33)
# question: 26%	(left_x: 1207   top_y:  998   width:   68   height:   35)
# question: 90%	(left_x: 1217   top_y:  890   width:   58   height:   36)
# answer: 56%	(left_x: 1310   top_y:  694   width:   63   height:   28)
# question: 44%	(left_x: 1312   top_y:  694   width:   65   height:   28)
# question: 64%	(left_x: 1322   top_y:  469   width:   97   height:   21)
# answer: 98%	(left_x: 1360   top_y:  505   width:   92   height:   36)
# answer: 87%	(left_x: 1374   top_y:  573   width:   84   height:   27)
# answer: 55%	(left_x: 1396   top_y: 1819   width:   96   height:   26)
# question: 25%	(left_x: 1396   top_y: 1819   width:   96   height:   26)
# answer: 90%	(left_x: 1414   top_y:  611   width:  186   height:   38)
# question: 29%	(left_x: 1414   top_y:  608   width:  190   height:   43)
# answer: 97%	(left_x: 1434   top_y: 1870   width:   93   height:   35)
# question: 95%	(left_x: 1442   top_y:  692   width:  140   height:   29)
# other: 31%	(left_x: 1484   top_y:  803   width:   87   height:   35)
# answer: 42%	(left_x: 1487   top_y:  803   width:   86   height:   36)
# answer: 75%	(left_x: 1496   top_y:  889   width:   76   height:  138)
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/06.jpg: Predicted in 80.555000 milli-seconds.
# header: 43%	(left_x:   14   top_y: 1987   width:   22   height:  151)
# answer: 43%	(left_x:   36   top_y: 1752   width:  705   height:   29)
# question: 82%	(left_x:   40   top_y: 1866   width:  165   height:   23)
# question: 65%	(left_x:   42   top_y: 1967   width:  198   height:   24)
# answer: 94%	(left_x:   42   top_y: 2062   width:  134   height:   22)
# answer: 28%	(left_x:   43   top_y: 1866   width:  164   height:   22)
# answer: 43%	(left_x:   47   top_y: 1966   width:  196   height:   25)
# other: 57%	(left_x:   69   top_y: 1752   width:  687   height:   29)
# answer: 92%	(left_x:   79   top_y: 1903   width:   57   height:   21)
# answer: 98%	(left_x:   81   top_y: 2003   width:  148   height:   22)
# question: 59%	(left_x:   83   top_y: 1660   width:  228   height:   25)
# other: 67%	(left_x:   87   top_y:  692   width:  111   height:   29)
# question: 91%	(left_x:  169   top_y:  639   width:  106   height:   27)
# answer: 61%	(left_x:  216   top_y:  378   width:  355   height:  117)
# question: 51%	(left_x:  238   top_y:  362   width:  405   height:   28)
# question: 83%	(left_x:  371   top_y: 1664   width:  276   height:   24)
# other: 92%	(left_x:  434   top_y:  695   width:  376   height:   27)
# answer: 97%	(left_x:  483   top_y: 1702   width:   69   height:   25)
# other: 51%	(left_x:  527   top_y:  641   width:  178   height:   25)
# other: 84%	(left_x:  636   top_y:   66   width:  408   height:   81)
# question: 73%	(left_x:  734   top_y: 1663   width:  193   height:   23)
# answer: 35%	(left_x:  777   top_y: 2246   width:   90   height:   21)
# answer: 97%	(left_x:  828   top_y: 1702   width:   67   height:   25)
# other: 85%	(left_x:  972   top_y:  202   width:  644   height:   73)
# header: 47%	(left_x:  984   top_y:  311   width:  120   height:   28)
# question: 36%	(left_x: 1008   top_y: 1666   width:   72   height:   20)
# answer: 99%	(left_x: 1021   top_y:  398   width:  120   height:   29)
# answer: 97%	(left_x: 1024   top_y: 1702   width:   31   height:   25)
# question: 84%	(left_x: 1048   top_y:  360   width:   79   height:   22)
# question: 91%	(left_x: 1053   top_y:  534   width:  117   height:   23)
# question: 85%	(left_x: 1066   top_y:  643   width:   95   height:   25)
# question: 83%	(left_x: 1100   top_y: 1919   width:  174   height:   26)
# question: 73%	(left_x: 1108   top_y:  494   width:   61   height:   23)
# answer: 64%	(left_x: 1126   top_y:  698   width:   73   height:   26)
# answer: 55%	(left_x: 1132   top_y:  697   width:  141   height:   27)
# answer: 98%	(left_x: 1144   top_y: 1968   width:  124   height:   28)
# answer: 93%	(left_x: 1186   top_y: 1703   width:   70   height:   26)
# answer: 82%	(left_x: 1227   top_y:  698   width:   43   height:   26)
# answer: 96%	(left_x: 1260   top_y:  400   width:   65   height:   26)
# answer: 76%	(left_x: 1329   top_y: 1703   width:   44   height:   27)
# answer: 53%	(left_x: 1341   top_y: 1794   width:  225   height:   30)
# question: 32%	(left_x: 1341   top_y: 1794   width:  225   height:   30)
# question: 79%	(left_x: 1364   top_y:  533   width:  113   height:   25)
# answer: 93%	(left_x: 1393   top_y: 1919   width:  117   height:   25)
# question: 74%	(left_x: 1408   top_y:  493   width:   81   height:   22)
# question: 68%	(left_x: 1419   top_y:  638   width:  121   height:   30)
# question: 73%	(left_x: 1420   top_y:  399   width:  148   height:   25)
# question: 65%	(left_x: 1437   top_y:  358   width:  129   height:   23)
# answer: 88%	(left_x: 1464   top_y: 1835   width:  118   height:   27)
# answer: 73%	(left_x: 1483   top_y:  692   width:  111   height:   33)
# answer: 98%	(left_x: 1491   top_y: 1969   width:   83   height:   30)
# answer: 97%	(left_x: 1505   top_y: 1703   width:   54   height:   26)
# other: 53%	(left_x: 1518   top_y: 1597   width:   72   height:   32)
# answer: 51%	(left_x: 1518   top_y: 1597   width:   72   height:   32)
# other: 83%	(left_x: 1604   top_y: 1356   width:   29   height:  188)
# other: 70%	(left_x: 1607   top_y: 1583   width:   25   height:  180)
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/03.jpg: Predicted in 80.565000 milli-seconds.
# other: 28%	(left_x:   44   top_y: 2102   width:  641   height:   61)
# other: 34%	(left_x:   71   top_y: 1046   width:  286   height:   38)
# question: 95%	(left_x:   71   top_y:  728   width:   43   height:   22)
# question: 72%	(left_x:   72   top_y:  764   width:   40   height:   20)
# answer: 60%	(left_x:   72   top_y:  666   width:  101   height:   25)
# question: 97%	(left_x:   73   top_y:  594   width:   57   height:   31)
# answer: 93%	(left_x:   82   top_y:  402   width:  307   height:   36)
# answer: 83%	(left_x:   88   top_y:  492   width:  535   height:   72)
# answer: 32%	(left_x:   92   top_y:  434   width:  437   height:   37)
# question: 60%	(left_x:  109   top_y: 2209   width:  129   height:   20)
# other: 53%	(left_x:  148   top_y:  152   width:  413   height:  115)
# answer: 89%	(left_x:  156   top_y:  590   width:  528   height:   40)
# answer: 84%	(left_x:  179   top_y:  756   width:  198   height:   31)
# question: 35%	(left_x:  180   top_y:  733   width:  125   height:   23)
# answer: 30%	(left_x:  227   top_y:  433   width:  229   height:   33)
# answer: 59%	(left_x:  247   top_y:  239   width:  299   height:   31)
# question: 89%	(left_x:  522   top_y:  729   width:  187   height:   48)
# other: 27%	(left_x:  645   top_y:  164   width:  370   height:   95)
# answer: 89%	(left_x:  647   top_y:  162   width:  364   height:   99)
# answer: 86%	(left_x:  736   top_y:  410   width:  513   height:  145)
# answer: 73%	(left_x:  833   top_y:  240   width:  175   height:   24)
# other: 29%	(left_x: 1021   top_y:  664   width:  227   height:   27)
# answer: 52%	(left_x: 1022   top_y:  664   width:  229   height:   27)
# answer: 86%	(left_x: 1106   top_y:  860   width:  115   height:   22)
# question: 53%	(left_x: 1106   top_y:  827   width:   65   height:   21)
# answer: 40%	(left_x: 1106   top_y:  827   width:   65   height:   21)
# answer: 94%	(left_x: 1108   top_y:  889   width:  172   height:   25)
# answer: 58%	(left_x: 1109   top_y:  921   width:  126   height:   22)
# answer: 87%	(left_x: 1112   top_y:  954   width:  253   height:   27)
# answer: 64%	(left_x: 1112   top_y:  986   width:  152   height:   22)
# question: 37%	(left_x: 1118   top_y:  954   width:  246   height:   28)
# other: 91%	(left_x: 1126   top_y:   87   width:  329   height:  189)
# answer: 98%	(left_x: 1228   top_y:  762   width:   18   height:   21)
# answer: 97%	(left_x: 1230   top_y:  729   width:   16   height:   22)
# answer: 30%	(left_x: 1271   top_y: 2226   width:   92   height:   20)
# answer: 94%	(left_x: 1302   top_y:  728   width:   78   height:   25)
# question: 87%	(left_x: 1302   top_y:  665   width:   79   height:   22)
# answer: 98%	(left_x: 1303   top_y:  761   width:   77   height:   23)
# question: 91%	(left_x: 1365   top_y: 2242   width:  137   height:   19)
# question: 82%	(left_x: 1374   top_y: 2228   width:  133   height:   18)
# question: 90%	(left_x: 1429   top_y:  663   width:  152   height:   26)
# question: 86%	(left_x: 1437   top_y:  728   width:   75   height:   53)
# question: 90%	(left_x: 1438   top_y:  823   width:  132   height:   24)
# answer: 78%	(left_x: 1439   top_y:  983   width:  128   height:   25)
# question: 27%	(left_x: 1440   top_y:  755   width:  148   height:   27)
# answer: 61%	(left_x: 1442   top_y:  953   width:  146   height:   26)
# question: 30%	(left_x: 1445   top_y:  856   width:  139   height:   24)
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/18.jpg: Predicted in 80.619000 milli-seconds.
# other: 63%	(left_x:   62   top_y: 1020   width:   24   height:  321)
# answer: 97%	(left_x:  111   top_y:  379   width:   84   height:   31)
# question: 52%	(left_x:  112   top_y: 1802   width:  186   height:   31)
# answer: 74%	(left_x:  119   top_y: 1337   width:  534   height:  107)
# question: 98%	(left_x:  121   top_y:  330   width:  149   height:   32)
# question: 35%	(left_x:  131   top_y: 1143   width:  561   height:   43)
# answer: 86%	(left_x:  133   top_y:  780   width:  335   height:   36)
# question: 35%	(left_x:  135   top_y:  841   width:  646   height:   43)
# other: 43%	(left_x:  136   top_y:   26   width:  134   height:  145)
# question: 97%	(left_x:  138   top_y: 1216   width:  314   height:   34)
# other: 45%	(left_x:  139   top_y: 1481   width:  308   height:   35)
# question: 35%	(left_x:  139   top_y: 1481   width:  308   height:   35)
# question: 96%	(left_x:  141   top_y: 1015   width:  306   height:   39)
# answer: 84%	(left_x:  145   top_y:  842   width:  693   height:   41)
# answer: 45%	(left_x:  147   top_y: 1076   width:  691   height:   46)
# answer: 66%	(left_x:  148   top_y: 1143   width:  585   height:   45)
# answer: 88%	(left_x:  150   top_y:  711   width:  583   height:   42)
# question: 87%	(left_x:  151   top_y: 1275   width:  666   height:   43)
# answer: 88%	(left_x:  152   top_y:  914   width:  411   height:   75)
# question: 63%	(left_x:  155   top_y: 1075   width:  640   height:   47)
# answer: 81%	(left_x:  157   top_y:  644   width:  627   height:   42)
# answer: 93%	(left_x:  174   top_y: 1971   width:  326   height:   34)
# other: 62%	(left_x:  212   top_y:  219   width:  569   height:   59)
# other: 41%	(left_x:  280   top_y:  200   width:  409   height:   41)
# question: 33%	(left_x:  280   top_y:  200   width:  409   height:   41)
# answer: 98%	(left_x:  300   top_y:  379   width:  118   height:   33)
# header: 52%	(left_x:  339   top_y:   64   width:  412   height:   66)
# question: 95%	(left_x:  376   top_y:  332   width:   78   height:   30)
# answer: 96%	(left_x:  425   top_y:  544   width:  231   height:   38)
# question: 94%	(left_x:  558   top_y:  329   width:   97   height:   33)
# answer: 98%	(left_x:  566   top_y:  378   width:   39   height:   34)
# header: 60%	(left_x:  583   top_y: 1807   width:  190   height:   29)
# question: 94%	(left_x:  706   top_y:  328   width:   67   height:   32)
# answer: 95%	(left_x:  813   top_y: 1805   width:   25   height:   30)
# other: 47%	(left_x:  886   top_y:  248   width:  591   height:  158)
# question: 90%	(left_x:  904   top_y: 1976   width:  157   height:   25)
# answer: 97%	(left_x:  908   top_y: 1805   width:   62   height:   29)
# header: 55%	(left_x:  944   top_y:   54   width:  505   height:  120)
# other: 74%	(left_x:  947   top_y:   57   width:  496   height:  118)
# other: 37%	(left_x:  972   top_y: 1583   width:  142   height:   34)
# answer: 44%	(left_x:  994   top_y:   68   width:  495   height:  107)
# question: 96%	(left_x: 1004   top_y:  547   width:  123   height:   32)
# answer: 38%	(left_x: 1047   top_y:  912   width:   75   height:   40)
# answer: 86%	(left_x: 1050   top_y: 1808   width:   24   height:   27)
# answer: 29%	(left_x: 1058   top_y:  713   width:   67   height:   44)
# answer: 93%	(left_x: 1058   top_y: 1148   width:   64   height:   41)
# answer: 92%	(left_x: 1059   top_y: 1350   width:   61   height:   34)
# answer: 86%	(left_x: 1060   top_y: 1383   width:   62   height:   35)
# answer: 87%	(left_x: 1061   top_y: 1417   width:   59   height:   32)
# other: 94%	(left_x: 1121   top_y: 1805   width:  123   height:   32)
# answer: 68%	(left_x: 1171   top_y: 1978   width:   87   height:  125)
# question: 94%	(left_x: 1178   top_y:  547   width:   93   height:   31)
# answer: 91%	(left_x: 1197   top_y: 1353   width:  142   height:   90)
# answer: 66%	(left_x: 1199   top_y:  950   width:  142   height:   36)
# answer: 96%	(left_x: 1201   top_y: 1146   width:  140   height:   43)
# answer: 80%	(left_x: 1202   top_y:  711   width:  142   height:   45)
# answer: 89%	(left_x: 1208   top_y:  909   width:  124   height:   44)
# answer: 27%	(left_x: 1259   top_y: 1583   width:   64   height:   36)
# other: 76%	(left_x: 1259   top_y: 1582   width:   63   height:   37)
# question: 35%	(left_x: 1298   top_y: 1804   width:  212   height:   31)
# answer: 42%	(left_x: 1301   top_y: 1804   width:  212   height:   31)
# question: 90%	(left_x: 1306   top_y:  546   width:   50   height:   31)
# question: 75%	(left_x: 1418   top_y:  547   width:   71   height:   29)
# answer: 95%	(left_x: 1437   top_y: 1150   width:   86   height:   40)
# answer: 78%	(left_x: 1437   top_y: 1410   width:   82   height:   39)
# answer: 91%	(left_x: 1437   top_y: 1383   width:   81   height:   37)
# answer: 93%	(left_x: 1438   top_y: 1351   width:   76   height:   34)
# answer: 96%	(left_x: 1439   top_y:  915   width:   82   height:   36)
# answer: 76%	(left_x: 1439   top_y:  715   width:   85   height:   38)
# answer: 91%	(left_x: 1441   top_y:  949   width:   82   height:   37)
# Enter Image Path:

# %%
resultado=json.loads(open('result.json').read())

# %%
# %mkdir 'input'
# %mkdir 'input/ground-truth'
# %mkdir 'input/detection-results'

# %%
# !unzip Facturas.zip

# %%
path='Facturas'
for file in [xml for xml in os.listdir(path) if xml[-1]=='l']:
  txt=open('input/ground-truth/'+file[:-4]+'.txt','w')
  path_file=path+'/'+file
  objeto=ET.parse(path_file)
  objeto = objeto.getroot()
  for bbox in objeto.findall('object'):
    label=bbox.find('name').text
    coords = bbox.find('bndbox')
    xmin,ymin,xmax,ymax = coords.find('xmin').text,coords.find('ymin').text,coords.find('xmax').text,coords.find('ymax').text
    txt.write('0' + ' ' + xmin + ' ' + ymin + ' '+ xmax + ' '+ ymax +'\n')
  txt.close()

# %% [markdown]
# Non Max Supression

# %%
resultado=json.loads(open('result.json').read())
for res in resultado:
  txt=open('input/detection-results/'+Path(res['filename']).stem+'.txt','w')
  img=cv2.imread(res['filename'])
  height,width,_=img.shape
  conf=[]
  l=[]
  for objeto in res['objects']:
    conf.append(objeto['confidence'])
    coords=objeto['relative_coordinates']
    x,y,h,w=coords['center_x'],coords['center_y'],coords['height'],coords['width']
    l.append(unconvert(width, height, x, y, w, h))
  dic={str(l[i]):str(conf[i]) for i in range(0,len(l))}
  l=non_max_suppression_fast(np.array(l))
  for x in l:
    xmin,ymin,xmax,ymax=x
    confi=dic[str(list(x))]
    txt.write('0' + ' ' +str(int(float(confi)*100)) + ' '+ str(xmin) + ' ' + str(ymin) + ' '+ str(xmax) + ' '+ str(ymax) +'\n')
  txt.close()

# %% [markdown]
# #### Resultados

# %%
mAP()
# Out:
# 46.91% = 0 AP
# mAP = 46.91%

# %%
mostrarImagen(abrirImagen('output/ground-truth-info.png'),7,5)

# %%
mostrarImagen(abrirImagen('output/detection-results-info.png'),7,5)

# %%
precision()
# Out:
# 0.67

# %%
recall()
# Out:
# 0.62

# %%
f1()
# Out:
# 0.644031007751938

# %%
mostrarImagen(abrirImagen('output/lamr.png'),7,5)

# %%
mostrarImagen(abrirImagen('output/mAP.png'),7,5)

# %%
files=[path+'/'+jpg for jpg in os.listdir(path) if jpg[-1]=='g']

# %% [markdown]
# ## **YOLOv4 + BERT**

# %% [markdown]
# ##### Cargamos las librerías necesarias y los modelos necesarios

# %%
# !./darknet detector test classes.data cfg/funsd.cfg funsd_last.weights -ext_output -dont_show -out result.json < test.txt
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    640 x 640 x   3 ->  640 x 640 x  32 0.708 BF
#    1 conv     80       3 x 3/ 2    640 x 640 x  32 ->  320 x 320 x  80 4.719 BF
#    2 conv     40       1 x 1/ 1    320 x 320 x  80 ->  320 x 320 x  40 0.655 BF
#    3 conv     80       3 x 3/ 1    320 x 320 x  40 ->  320 x 320 x  80 5.898 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 320 x 320 x  80 0.008 BF
#    5 conv    160       3 x 3/ 2    320 x 320 x  80 ->  160 x 160 x 160 5.898 BF
#    6 conv     80       1 x 1/ 1    160 x 160 x 160 ->  160 x 160 x  80 0.655 BF
#    7 route  5 		                           ->  160 x 160 x 160
#    8 conv     80       1 x 1/ 1    160 x 160 x 160 ->  160 x 160 x  80 0.655 BF
#    9 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   10 conv     80       3 x 3/ 1    160 x 160 x  80 ->  160 x 160 x  80 2.949 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 160 x 160 x  80 0.002 BF
#   12 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   13 conv     80       3 x 3/ 1    160 x 160 x  80 ->  160 x 160 x  80 2.949 BF
#   14 Shortcut Layer: 11,  wt = 0, wn = 0, outputs: 160 x 160 x  80 0.002 BF
#   15 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   16 conv     80       3 x 3/ 1    160 x 160 x  80 ->  160 x 160 x  80 2.949 BF
#   17 Shortcut Layer: 14,  wt = 0, wn = 0, outputs: 160 x 160 x  80 0.002 BF
#   18 conv     80       1 x 1/ 1    160 x 160 x  80 ->  160 x 160 x  80 0.328 BF
#   19 route  18 6 	                           ->  160 x 160 x 160
#   20 conv    160       1 x 1/ 1    160 x 160 x 160 ->  160 x 160 x 160 1.311 BF
#   21 conv    320       3 x 3/ 2    160 x 160 x 160 ->   80 x  80 x 320 5.898 BF
#   22 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#   23 route  21 		                           ->   80 x  80 x 320
#   24 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#   25 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   26 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   28 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   29 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   31 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   32 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   34 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   35 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   37 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   38 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   39 Shortcut Layer: 36,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   40 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   41 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   42 Shortcut Layer: 39,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   43 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   44 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   45 Shortcut Layer: 42,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   46 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   47 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   48 Shortcut Layer: 45,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   49 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   50 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   51 Shortcut Layer: 48,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   52 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   53 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#   54 Shortcut Layer: 51,  wt = 0, wn = 0, outputs:  80 x  80 x 160 0.001 BF
#   55 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#   56 route  55 22 	                           ->   80 x  80 x 320
#   57 conv    320       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 320 1.311 BF
#   58 conv    640       3 x 3/ 2     80 x  80 x 320 ->   40 x  40 x 640 5.898 BF
#   59 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#   60 route  58 		                           ->   40 x  40 x 640
#   61 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#   62 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   63 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   64 Shortcut Layer: 61,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   65 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   66 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   67 Shortcut Layer: 64,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   68 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   69 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   70 Shortcut Layer: 67,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   71 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   72 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   73 Shortcut Layer: 70,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   74 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   75 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   76 Shortcut Layer: 73,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   77 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   78 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   79 Shortcut Layer: 76,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   80 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   81 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   82 Shortcut Layer: 79,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   83 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   84 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   85 Shortcut Layer: 82,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   86 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   87 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   88 Shortcut Layer: 85,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   89 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   90 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#   91 Shortcut Layer: 88,  wt = 0, wn = 0, outputs:  40 x  40 x 320 0.001 BF
#   92 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#   93 route  92 59 	                           ->   40 x  40 x 640
#   94 conv    640       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 640 1.311 BF
#   95 conv   1280       3 x 3/ 2     40 x  40 x 640 ->   20 x  20 x1280 5.898 BF
#   96 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#   97 route  95 		                           ->   20 x  20 x1280
#   98 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#   99 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  100 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  101 Shortcut Layer: 98,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  102 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  103 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  104 Shortcut Layer: 101,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  105 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  106 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  107 Shortcut Layer: 104,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  108 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  109 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  110 Shortcut Layer: 107,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  111 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  112 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  113 Shortcut Layer: 110,  wt = 0, wn = 0, outputs:  20 x  20 x 640 0.000 BF
#  114 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  115 route  114 96 	                           ->   20 x  20 x1280
#  116 conv   1280       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x1280 1.311 BF
#  117 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  118 route  116 		                           ->   20 x  20 x1280
#  119 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  120 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  121 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  122 max                5x 5/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.006 BF
#  123 route  121 		                           ->   20 x  20 x 640
#  124 max                9x 9/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.021 BF
#  125 route  121 		                           ->   20 x  20 x 640
#  126 max               13x13/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.043 BF
#  127 route  126 124 122 121 	                   ->   20 x  20 x2560
#  128 conv    640       1 x 1/ 1     20 x  20 x2560 ->   20 x  20 x 640 1.311 BF
#  129 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  130 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  131 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  132 route  131 117 	                           ->   20 x  20 x1280
#  133 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  134 conv    320       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 320 0.164 BF
#  135 upsample                 2x    20 x  20 x 320 ->   40 x  40 x 320
#  136 route  94 		                           ->   40 x  40 x 640
#  137 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  138 route  137 135 	                           ->   40 x  40 x 640
#  139 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  140 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  141 route  139 		                           ->   40 x  40 x 320
#  142 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  143 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  144 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  145 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  146 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  147 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  148 route  147 140 	                           ->   40 x  40 x 640
#  149 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  150 conv    160       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 160 0.164 BF
#  151 upsample                 2x    40 x  40 x 160 ->   80 x  80 x 160
#  152 route  57 		                           ->   80 x  80 x 320
#  153 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#  154 route  153 151 	                           ->   80 x  80 x 320
#  155 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#  156 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  157 route  155 		                           ->   80 x  80 x 160
#  158 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  159 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#  160 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  161 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#  162 conv    160       1 x 1/ 1     80 x  80 x 160 ->   80 x  80 x 160 0.328 BF
#  163 conv    160       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 160 2.949 BF
#  164 route  163 156 	                           ->   80 x  80 x 320
#  165 conv    160       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x 160 0.655 BF
#  166 conv    320       3 x 3/ 1     80 x  80 x 160 ->   80 x  80 x 320 5.898 BF
#  167 conv     27       1 x 1/ 1     80 x  80 x 320 ->   80 x  80 x  27 0.111 BF
#  168 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 4.00, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
#  169 route  165 		                           ->   80 x  80 x 160
#  170 conv    320       3 x 3/ 2     80 x  80 x 160 ->   40 x  40 x 320 1.475 BF
#  171 route  170 149 	                           ->   40 x  40 x 640
#  172 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  173 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  174 route  172 		                           ->   40 x  40 x 320
#  175 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  176 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  177 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  178 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  179 conv    320       1 x 1/ 1     40 x  40 x 320 ->   40 x  40 x 320 0.328 BF
#  180 conv    320       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 320 2.949 BF
#  181 route  180 173 	                           ->   40 x  40 x 640
#  182 conv    320       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x 320 0.655 BF
#  183 conv    640       3 x 3/ 1     40 x  40 x 320 ->   40 x  40 x 640 5.898 BF
#  184 conv     27       1 x 1/ 1     40 x  40 x 640 ->   40 x  40 x  27 0.055 BF
#  185 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 1.00, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
#  186 route  182 		                           ->   40 x  40 x 320
#  187 conv    640       3 x 3/ 2     40 x  40 x 320 ->   20 x  20 x 640 1.475 BF
#  188 route  187 133 	                           ->   20 x  20 x1280
#  189 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  190 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  191 route  189 		                           ->   20 x  20 x 640
#  192 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  193 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  194 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  195 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  196 conv    640       1 x 1/ 1     20 x  20 x 640 ->   20 x  20 x 640 0.328 BF
#  197 conv    640       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x 640 2.949 BF
#  198 route  197 190 	                           ->   20 x  20 x1280
#  199 conv    640       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x 640 0.655 BF
#  200 conv   1280       3 x 3/ 1     20 x  20 x 640 ->   20 x  20 x1280 5.898 BF
#  201 conv     27       1 x 1/ 1     20 x  20 x1280 ->   20 x  20 x  27 0.028 BF
#  202 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.05, obj_norm: 0.40, cls_norm: 0.50, delta_norm: 1.00, scale_x_y: 2.00
# nms_kind: diounms (2), beta = 0.600000
# Total BFLOPS 220.352
# avg_outputs = 1000634
#  Allocate additional workspace_size = 81.93 MB
# Loading weights from funsd_last.weights...
#  seen 64, trained: 582 K-images (9 Kilo-batches_64)
# Done! Loaded 203 layers from weights-file
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/27.png: Predicted in 80.498000 milli-seconds.
# question: 90%	(left_x:   66   top_y:  180   width:   22   height:   30)
# question: 70%	(left_x:   69   top_y:  116   width:   97   height:   22)
# answer: 29%	(left_x:   69   top_y:  116   width:   97   height:   22)
# question: 92%	(left_x:   70   top_y:   93   width:   36   height:   20)
# question: 97%	(left_x:   72   top_y:  231   width:  108   height:   22)
# question: 89%	(left_x:   84   top_y:  340   width:   99   height:   20)
# question: 93%	(left_x:   85   top_y:  288   width:   96   height:   20)
# question: 98%	(left_x:   92   top_y:  261   width:   90   height:   19)
# question: 64%	(left_x:  117   top_y:  317   width:   65   height:   17)
# other: 69%	(left_x:  173   top_y:  599   width:  338   height:   62)
# other: 36%	(left_x:  185   top_y:  684   width:  295   height:   69)
# other: 70%	(left_x:  190   top_y: 1091   width:  243   height:   59)
# other: 79%	(left_x:  193   top_y: 1434   width:  245   height:   49)
# other: 79%	(left_x:  193   top_y:  810   width:  258   height:   66)
# answer: 60%	(left_x:  193   top_y:  603   width:  304   height:   51)
# answer: 88%	(left_x:  193   top_y:  673   width:  275   height:   28)
# other: 95%	(left_x:  194   top_y: 1317   width:  247   height:   36)
# other: 85%	(left_x:  195   top_y:  919   width:  251   height:   54)
# other: 99%	(left_x:  196   top_y: 1225   width:  238   height:   58)
# other: 73%	(left_x:  197   top_y:  392   width:  265   height:   57)
# answer: 40%	(left_x:  197   top_y:  392   width:  265   height:   57)
# other: 97%	(left_x:  197   top_y: 1148   width:  237   height:   43)
# other: 46%	(left_x:  197   top_y:  716   width:  241   height:   36)
# answer: 46%	(left_x:  197   top_y:  716   width:  241   height:   36)
# other: 96%	(left_x:  197   top_y: 1014   width:  245   height:   58)
# answer: 65%	(left_x:  198   top_y: 1091   width:  245   height:   51)
# answer: 95%	(left_x:  198   top_y:  495   width:  233   height:   24)
# answer: 82%	(left_x:  198   top_y:  224   width:  268   height:   43)
# answer: 50%	(left_x:  200   top_y:  812   width:  257   height:   58)
# answer: 76%	(left_x:  200   top_y:  430   width:  266   height:   20)
# answer: 96%	(left_x:  202   top_y:  283   width:  227   height:   40)
# answer: 98%	(left_x:  212   top_y:  166   width:  132   height:   26)
# header: 55%	(left_x:  261   top_y:   96   width:  273   height:   43)
# header: 25%	(left_x:  263   top_y:   94   width:  240   height:   20)
# answer: 39%	(left_x:  349   top_y: 1692   width:  559   height:   41)
# other: 69%	(left_x:  351   top_y: 1694   width:  556   height:   42)
# answer: 96%	(left_x:  483   top_y: 1403   width:   31   height:   21)
# answer: 96%	(left_x:  483   top_y: 1381   width:   30   height:   19)
# answer: 93%	(left_x:  484   top_y: 1335   width:   29   height:   20)
# answer: 99%	(left_x:  484   top_y:  921   width:   29   height:   18)
# question: 86%	(left_x:  484   top_y: 1252   width:   27   height:   24)
# answer: 99%	(left_x:  484   top_y:  945   width:   27   height:   17)
# answer: 91%	(left_x:  484   top_y: 1044   width:   29   height:   20)
# answer: 92%	(left_x:  484   top_y: 1357   width:   28   height:   20)
# answer: 96%	(left_x:  484   top_y:  553   width:   27   height:   19)
# other: 80%	(left_x:  484   top_y: 1193   width:   28   height:   21)
# answer: 95%	(left_x:  485   top_y:  530   width:   27   height:   18)
# answer: 97%	(left_x:  485   top_y:  509   width:   27   height:   17)
# answer: 99%	(left_x:  485   top_y:  967   width:   27   height:   17)
# answer: 81%	(left_x:  485   top_y:  897   width:   27   height:   20)
# other: 67%	(left_x:  485   top_y: 1173   width:   27   height:   20)
# answer: 31%	(left_x:  485   top_y: 1173   width:   27   height:   20)
# answer: 83%	(left_x:  485   top_y: 1312   width:   28   height:   20)
# answer: 91%	(left_x:  485   top_y:  575   width:   27   height:   18)
# answer: 87%	(left_x:  485   top_y: 1150   width:   26   height:   21)
# answer: 74%	(left_x:  486   top_y:  739   width:   24   height:   20)
# answer: 69%	(left_x:  486   top_y:  486   width:   27   height:   18)
# question: 35%	(left_x:  486   top_y:  486   width:   27   height:   18)
# answer: 96%	(left_x:  486   top_y:  760   width:   24   height:   17)
# answer: 64%	(left_x:  486   top_y:  322   width:   26   height:   16)
# question: 87%	(left_x:  486   top_y: 1461   width:   27   height:   20)
# answer: 98%	(left_x:  486   top_y:  988   width:   25   height:   17)
# answer: 85%	(left_x:  486   top_y:  690   width:   26   height:   20)
# answer: 92%	(left_x:  486   top_y: 1128   width:   26   height:   19)
# question: 75%	(left_x:  487   top_y:  274   width:   26   height:   18)
# answer: 26%	(left_x:  487   top_y:  274   width:   26   height:   18)
# answer: 96%	(left_x:  487   top_y:  345   width:   26   height:   17)
# answer: 88%	(left_x:  487   top_y:  298   width:   25   height:   18)
# answer: 98%	(left_x:  487   top_y:  424   width:   24   height:   20)
# answer: 98%	(left_x:  487   top_y:  838   width:   23   height:   21)
# answer: 82%	(left_x:  488   top_y: 1104   width:   26   height:   19)
# answer: 97%	(left_x:  488   top_y:  714   width:   23   height:   18)
# answer: 97%	(left_x:  488   top_y:  782   width:   22   height:   16)
# answer: 96%	(left_x:  488   top_y:  369   width:   24   height:   17)
# question: 93%	(left_x:  565   top_y:  233   width:  113   height:   18)
# answer: 97%	(left_x:  728   top_y:  423   width:   60   height:   24)
# answer: 95%	(left_x:  729   top_y:  365   width:   58   height:   24)
# answer: 27%	(left_x:  784   top_y:  625   width:   17   height:   30)
# question: 95%	(left_x:  795   top_y:  230   width:   55   height:   24)
# answer: 91%	(left_x:  812   top_y:  843   width:   23   height:   16)
# answer: 99%	(left_x:  815   top_y: 1195   width:   19   height:   18)
# answer: 99%	(left_x:  816   top_y: 1381   width:   20   height:   20)
# answer: 99%	(left_x:  816   top_y:  968   width:   20   height:   17)
# answer: 96%	(left_x:  816   top_y: 1175   width:   18   height:   18)
# answer: 98%	(left_x:  816   top_y:  368   width:   16   height:   17)
# answer: 99%	(left_x:  816   top_y:  923   width:   16   height:   17)
# answer: 99%	(left_x:  817   top_y: 1359   width:   16   height:   18)
# answer: 99%	(left_x:  817   top_y:  991   width:   18   height:   16)
# answer: 99%	(left_x:  817   top_y: 1405   width:   18   height:   19)
# answer: 99%	(left_x:  817   top_y:  946   width:   16   height:   17)
# answer: 99%	(left_x:  817   top_y:  783   width:   17   height:   18)
# answer: 99%	(left_x:  817   top_y: 1338   width:   15   height:   14)
# answer: 99%	(left_x:  817   top_y:  574   width:   17   height:   17)
# answer: 99%	(left_x:  818   top_y:  741   width:   15   height:   15)
# answer: 99%	(left_x:  818   top_y:  346   width:   17   height:   15)
# answer: 98%	(left_x:  818   top_y: 1151   width:   14   height:   17)
# answer: 99%	(left_x:  818   top_y:  323   width:   15   height:   16)
# answer: 97%	(left_x:  818   top_y:  900   width:   13   height:   19)
# answer: 99%	(left_x:  818   top_y: 1314   width:   14   height:   19)
# answer: 99%	(left_x:  818   top_y:  762   width:   17   height:   17)
# answer: 99%	(left_x:  818   top_y:  553   width:   16   height:   17)
# answer: 98%	(left_x:  818   top_y:  693   width:   14   height:   20)
# answer: 95%	(left_x:  818   top_y:  276   width:   14   height:   18)
# answer: 96%	(left_x:  819   top_y:  301   width:   14   height:   12)
# answer: 99%	(left_x:  819   top_y:  510   width:   14   height:   13)
# answer: 98%	(left_x:  819   top_y: 1130   width:   14   height:   14)
# answer: 98%	(left_x:  819   top_y:  719   width:   13   height:   13)
# answer: 99%	(left_x:  819   top_y: 1108   width:   14   height:   18)
# answer: 99%	(left_x:  819   top_y:  532   width:   13   height:   15)
# answer: 98%	(left_x:  820   top_y:  486   width:   12   height:   18)
# answer: 80%	(left_x:  868   top_y:  626   width:   36   height:   27)
# answer: 54%	(left_x:  871   top_y: 1458   width:   24   height:   24)
# answer: 97%	(left_x:  872   top_y:  895   width:   28   height:   22)
# answer: 99%	(left_x:  872   top_y: 1310   width:   28   height:   21)
# answer: 99%	(left_x:  872   top_y: 1334   width:   29   height:   19)
# answer: 99%	(left_x:  872   top_y:  942   width:   28   height:   21)
# answer: 93%	(left_x:  872   top_y:  688   width:   28   height:   22)
# answer: 99%	(left_x:  872   top_y:  918   width:   28   height:   21)
# answer: 88%	(left_x:  872   top_y:  529   width:   27   height:   19)
# answer: 88%	(left_x:  873   top_y:  737   width:   25   height:   17)
# answer: 98%	(left_x:  873   top_y: 1381   width:   28   height:   19)
# answer: 95%	(left_x:  873   top_y:  575   width:   28   height:   17)
# answer: 99%	(left_x:  873   top_y: 1357   width:   27   height:   20)
# answer: 97%	(left_x:  873   top_y:  713   width:   27   height:   18)
# answer: 98%	(left_x:  873   top_y: 1102   width:   27   height:   22)
# answer: 91%	(left_x:  873   top_y:  552   width:   26   height:   18)
# answer: 90%	(left_x:  873   top_y:  508   width:   27   height:   17)
# answer: 88%	(left_x:  873   top_y:  320   width:   27   height:   16)
# answer: 98%	(left_x:  873   top_y: 1149   width:   26   height:   21)
# answer: 98%	(left_x:  873   top_y:  759   width:   23   height:   18)
# answer: 97%	(left_x:  873   top_y: 1174   width:   26   height:   17)
# answer: 85%	(left_x:  873   top_y:  274   width:   27   height:   19)
# answer: 98%	(left_x:  873   top_y:  964   width:   27   height:   18)
# answer: 63%	(left_x:  874   top_y:  485   width:   26   height:   20)
# question: 44%	(left_x:  874   top_y:  485   width:   26   height:   20)
# answer: 98%	(left_x:  874   top_y: 1127   width:   26   height:   19)
# answer: 94%	(left_x:  874   top_y:  297   width:   26   height:   17)
# answer: 98%	(left_x:  874   top_y: 1043   width:   27   height:   24)
# answer: 97%	(left_x:  874   top_y:  345   width:   25   height:   17)
# answer: 98%	(left_x:  874   top_y: 1403   width:   26   height:   20)
# answer: 99%	(left_x:  874   top_y:  988   width:   26   height:   20)
# answer: 99%	(left_x:  875   top_y: 1194   width:   25   height:   19)
# answer: 98%	(left_x:  875   top_y:  836   width:   25   height:   25)
# answer: 99%	(left_x:  875   top_y: 1251   width:   24   height:   24)
# answer: 98%	(left_x:  875   top_y:  782   width:   23   height:   17)
# answer: 97%	(left_x:  875   top_y:  368   width:   24   height:   16)
# answer: 98%	(left_x:  876   top_y:  425   width:   23   height:   20)
# question: 77%	(left_x: 1011   top_y:  230   width:  120   height:   20)
# answer: 98%	(left_x: 1088   top_y:   95   width:   65   height:   27)
# answer: 77%	(left_x: 1126   top_y:  365   width:   51   height:   23)
# answer: 85%	(left_x: 1126   top_y:  423   width:   52   height:   24)
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/25.png: Predicted in 80.623000 milli-seconds.
# question: 95%	(left_x:  156   top_y:  641   width:  298   height:   26)
# answer: 76%	(left_x:  157   top_y:  341   width:   88   height:   27)
# question: 95%	(left_x:  158   top_y:  559   width:  126   height:   26)
# question: 36%	(left_x:  158   top_y:  342   width:   88   height:   27)
# question: 92%	(left_x:  159   top_y:  823   width:  129   height:   23)
# question: 85%	(left_x:  160   top_y:  384   width:  473   height:   32)
# question: 90%	(left_x:  161   top_y:  469   width:  255   height:   26)
# question: 96%	(left_x:  161   top_y:  603   width:  144   height:   23)
# question: 97%	(left_x:  162   top_y:  685   width:  119   height:   22)
# other: 56%	(left_x:  173   top_y:  105   width:  133   height:  120)
# answer: 88%	(left_x:  194   top_y:  857   width:  308   height:   30)
# question: 87%	(left_x:  195   top_y:  426   width:  308   height:   28)
# answer: 30%	(left_x:  199   top_y:  823   width:  304   height:   27)
# header: 73%	(left_x:  347   top_y:  118   width:  684   height:   82)
# other: 86%	(left_x:  357   top_y: 1693   width:  551   height:   47)
# answer: 99%	(left_x:  427   top_y:  466   width:  248   height:   30)
# answer: 97%	(left_x:  535   top_y:  597   width:  126   height:   27)
# question: 36%	(left_x:  537   top_y:  683   width:   68   height:   27)
# answer: 67%	(left_x:  537   top_y:  683   width:   68   height:   26)
# answer: 99%	(left_x:  541   top_y:  634   width:  309   height:   33)
# answer: 98%	(left_x:  570   top_y:  422   width:  220   height:   31)
# answer: 95%	(left_x:  820   top_y:  215   width:  188   height:   37)
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/20.jpg: Predicted in 80.613000 milli-seconds.
# other: 55%	(left_x:   64   top_y: 1163   width:   20   height:  278)
# other: 38%	(left_x:   64   top_y:  634   width:   27   height:  214)
# other: 26%	(left_x:   67   top_y:  582   width:   26   height:  155)
# other: 28%	(left_x:   71   top_y:  623   width:   30   height:  192)
# other: 46%	(left_x:  139   top_y:   62   width:  453   height:   96)
# question: 76%	(left_x:  150   top_y: 1068   width:   68   height:   30)
# question: 82%	(left_x:  151   top_y:  777   width:  146   height:   28)
# question: 92%	(left_x:  153   top_y:  977   width:   68   height:   34)
# question: 62%	(left_x:  155   top_y:  869   width:   68   height:   27)
# question: 84%	(left_x:  157   top_y:  154   width:  403   height:   36)
# question: 93%	(left_x:  157   top_y:  719   width:   83   height:   26)
# question: 68%	(left_x:  157   top_y:   74   width:  409   height:   73)
# question: 94%	(left_x:  157   top_y:  827   width:  106   height:   26)
# question: 87%	(left_x:  158   top_y:  546   width:  101   height:   29)
# question: 48%	(left_x:  160   top_y:  310   width:  254   height:   42)
# question: 93%	(left_x:  163   top_y:  513   width:  150   height:   31)
# question: 95%	(left_x:  163   top_y:  412   width:  176   height:   25)
# question: 41%	(left_x:  165   top_y:  440   width:  196   height:   26)
# other: 38%	(left_x:  173   top_y: 2031   width:  777   height:   36)
# header: 31%	(left_x:  184   top_y:  244   width: 1349   height:   83)
# question: 93%	(left_x:  188   top_y: 2078   width:  143   height:   27)
# answer: 48%	(left_x:  243   top_y:  363   width:  234   height:   37)
# answer: 47%	(left_x:  249   top_y:  415   width:  570   height:   82)
# question: 96%	(left_x:  254   top_y: 2117   width:   80   height:   27)
# answer: 96%	(left_x:  303   top_y:  720   width:   82   height:   28)
# answer: 81%	(left_x:  330   top_y:  513   width:  113   height:   33)
# answer: 91%	(left_x:  335   top_y:  545   width:   77   height:   27)
# answer: 96%	(left_x:  365   top_y:  779   width:   88   height:   27)
# answer: 81%	(left_x:  381   top_y:  428   width:  318   height:   65)
# answer: 58%	(left_x:  382   top_y: 2079   width:   79   height:   31)
# other: 46%	(left_x:  422   top_y: 1091   width: 1015   height:   97)
# answer: 50%	(left_x:  422   top_y: 1090   width:  973   height:   99)
# other: 40%	(left_x:  440   top_y:  901   width: 1051   height:   88)
# answer: 59%	(left_x:  458   top_y: 1014   width:  662   height:   41)
# answer: 89%	(left_x:  459   top_y:  987   width:  271   height:   29)
# question: 63%	(left_x:  482   top_y:  723   width:  131   height:   28)
# question: 95%	(left_x:  484   top_y:  832   width:  165   height:   25)
# answer: 43%	(left_x:  486   top_y:  722   width:  123   height:   29)
# question: 35%	(left_x:  502   top_y: 2081   width:  101   height:   28)
# answer: 35%	(left_x:  505   top_y:  365   width:   92   height:   37)
# question: 74%	(left_x:  528   top_y:  782   width:  252   height:   27)
# answer: 28%	(left_x:  528   top_y:  782   width:  252   height:   27)
# answer: 29%	(left_x:  637   top_y:  320   width:  112   height:   36)
# question: 88%	(left_x:  670   top_y:  833   width:  150   height:   26)
# question: 96%	(left_x:  688   top_y: 2083   width:  116   height:   29)
# answer: 93%	(left_x:  717   top_y: 2123   width:   63   height:   27)
# header: 42%	(left_x:  857   top_y:  425   width:  418   height:  117)
# question: 63%	(left_x:  861   top_y: 2084   width:  205   height:   31)
# answer: 62%	(left_x:  864   top_y:  426   width:  425   height:  113)
# answer: 94%	(left_x:  870   top_y: 2124   width:   62   height:   26)
# question: 96%	(left_x:  881   top_y:  680   width:  151   height:   24)
# answer: 57%	(left_x:  888   top_y:  837   width:   69   height:   23)
# question: 33%	(left_x:  889   top_y:  835   width:   61   height:   23)
# other: 36%	(left_x:  972   top_y:   66   width:  225   height:  116)
# answer: 93%	(left_x:  977   top_y:   68   width:  214   height:  123)
# answer: 95%	(left_x:  981   top_y: 2124   width:   56   height:   26)
# question: 98%	(left_x:  981   top_y:  191   width:  128   height:   22)
# header: 35%	(left_x:  981   top_y:   53   width:  120   height:   23)
# question: 37%	(left_x:  984   top_y:  173   width:  205   height:   21)
# answer: 38%	(left_x: 1082   top_y:  729   width:  100   height:   26)
# question: 54%	(left_x: 1082   top_y:  729   width:  100   height:   27)
# question: 96%	(left_x: 1092   top_y: 2083   width:  224   height:   35)
# answer: 95%	(left_x: 1105   top_y: 2126   width:   48   height:   25)
# answer: 99%	(left_x: 1160   top_y:  625   width:  352   height:   31)
# other: 57%	(left_x: 1162   top_y: 1079   width:   16   height:   28)
# answer: 64%	(left_x: 1162   top_y:  879   width:   18   height:   27)
# other: 32%	(left_x: 1162   top_y:  879   width:   18   height:   27)
# answer: 93%	(left_x: 1164   top_y:  991   width:   14   height:   30)
# answer: 98%	(left_x: 1224   top_y: 2126   width:   46   height:   29)
# question: 80%	(left_x: 1287   top_y:  729   width:  298   height:   31)
# question: 92%	(left_x: 1375   top_y: 2087   width:  182   height:   30)
# other: 75%	(left_x: 1416   top_y:   57   width:  167   height:  154)
# answer: 97%	(left_x: 1428   top_y: 2126   width:   88   height:   29)
# question: 36%	(left_x: 1503   top_y: 1081   width:   59   height:   32)
# other: 29%	(left_x: 1503   top_y: 1082   width:   59   height:   31)
# question: 93%	(left_x: 1504   top_y:  993   width:   60   height:   33)
# question: 57%	(left_x: 1505   top_y:  880   width:   60   height:   32)
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/14.jpg: Predicted in 80.587000 milli-seconds.
# other: 48%	(left_x:   95   top_y: 1959   width:  302   height:   31)
# question: 28%	(left_x:   97   top_y: 2001   width:  113   height:   26)
# question: 47%	(left_x:  101   top_y: 1959   width:  298   height:   32)
# question: 88%	(left_x:  112   top_y:  726   width:   91   height:   30)
# question: 79%	(left_x:  135   top_y:  834   width:   49   height:   34)
# other: 89%	(left_x:  136   top_y:  928   width:   48   height:   31)
# other: 74%	(left_x:  156   top_y:  105   width:  331   height:  135)
# answer: 36%	(left_x:  162   top_y:  109   width:  309   height:  113)
# question: 36%	(left_x:  166   top_y:  208   width:  299   height:   37)
# other: 30%	(left_x:  166   top_y:  208   width:  299   height:   37)
# answer: 46%	(left_x:  176   top_y:  332   width:  284   height:  116)
# answer: 34%	(left_x:  182   top_y:  476   width:  265   height:   35)
# answer: 57%	(left_x:  183   top_y:  558   width:  267   height:   28)
# answer: 26%	(left_x:  186   top_y:  511   width:  260   height:   44)
# answer: 37%	(left_x:  193   top_y:  928   width:  728   height:   41)
# other: 27%	(left_x:  193   top_y:  928   width:  728   height:   41)
# answer: 72%	(left_x:  205   top_y:  593   width:  221   height:   67)
# answer: 26%	(left_x:  217   top_y:  630   width:  201   height:   31)
# question: 57%	(left_x:  218   top_y: 1019   width:   98   height:   28)
# answer: 38%	(left_x:  219   top_y: 1019   width:   99   height:   28)
# other: 70%	(left_x:  220   top_y: 1066   width:  127   height:   30)
# answer: 30%	(left_x:  228   top_y:  837   width:  972   height:   74)
# answer: 79%	(left_x:  269   top_y: 2002   width:   28   height:   25)
# answer: 92%	(left_x:  294   top_y: 2039   width:  202   height:   31)
# question: 67%	(left_x:  345   top_y: 2001   width:  123   height:   29)
# other: 62%	(left_x:  594   top_y: 2075   width:   95   height:   30)
# answer: 90%	(left_x:  638   top_y:  733   width:  155   height:   34)
# answer: 53%	(left_x:  675   top_y:  101   width:  126   height:   25)
# answer: 37%	(left_x:  676   top_y:  126   width:  147   height:   37)
# answer: 72%	(left_x:  677   top_y:  156   width:  180   height:   32)
# answer: 68%	(left_x:  679   top_y:  192   width:  120   height:   27)
# answer: 46%	(left_x:  741   top_y:  629   width:  198   height:   32)
# question: 47%	(left_x:  751   top_y:  300   width:   90   height:   28)
# header: 49%	(left_x:  788   top_y:  405   width:  278   height:   34)
# answer: 96%	(left_x:  792   top_y:  556   width:   85   height:   30)
# answer: 87%	(left_x:  792   top_y:  518   width:   65   height:   26)
# answer: 58%	(left_x:  793   top_y:  444   width:  163   height:   26)
# answer: 92%	(left_x:  805   top_y: 1923   width:   93   height:   36)
# question: 92%	(left_x:  819   top_y: 1847   width:  110   height:   36)
# answer: 78%	(left_x:  842   top_y:  631   width:  107   height:   29)
# answer: 80%	(left_x:  886   top_y:  298   width:   92   height:   29)
# question: 30%	(left_x:  906   top_y:  520   width:  118   height:   25)
# question: 98%	(left_x:  971   top_y: 2021   width:  221   height:   43)
# question: 93%	(left_x: 1000   top_y: 1849   width:  117   height:   35)
# answer: 86%	(left_x: 1017   top_y:  559   width:   80   height:   27)
# answer: 84%	(left_x: 1025   top_y: 1921   width:   94   height:   39)
# question: 26%	(left_x: 1086   top_y:  294   width:  259   height:   35)
# other: 27%	(left_x: 1099   top_y:  294   width:  256   height:   33)
# question: 83%	(left_x: 1137   top_y:  140   width:  253   height:   58)
# other: 88%	(left_x: 1169   top_y: 2202   width:   90   height:   89)
# question: 97%	(left_x: 1178   top_y:  709   width:   94   height:   49)
# question: 92%	(left_x: 1209   top_y:  837   width:   88   height:   30)
# other: 74%	(left_x: 1239   top_y:  930   width:   58   height:   29)
# answer: 97%	(left_x: 1258   top_y: 1923   width:   53   height:   37)
# answer: 98%	(left_x: 1264   top_y: 1843   width:   29   height:   36)
# question: 95%	(left_x: 1268   top_y: 2111   width:  258   height:   38)
# question: 85%	(left_x: 1310   top_y:  730   width:   86   height:   28)
# answer: 84%	(left_x: 1320   top_y: 2025   width:  196   height:   44)
# answer: 33%	(left_x: 1327   top_y:  631   width:   90   height:   32)
# other: 80%	(left_x: 1328   top_y:  835   width:   59   height:   29)
# answer: 97%	(left_x: 1406   top_y: 1924   width:   75   height:   33)
# answer: 95%	(left_x: 1411   top_y: 1847   width:   63   height:   36)
# question: 93%	(left_x: 1424   top_y:  731   width:   67   height:   23)
# other: 91%	(left_x: 1438   top_y:  928   width:   61   height:   30)
# answer: 88%	(left_x: 1463   top_y:  634   width:   17   height:   30)
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/12.jpg: Predicted in 80.640000 milli-seconds.
# answer: 85%	(left_x:   91   top_y: 2213   width:  225   height:   38)
# answer: 94%	(left_x:  114   top_y:   85   width:  374   height:   86)
# question: 92%	(left_x:  182   top_y: 1202   width:  304   height:   28)
# other: 75%	(left_x:  184   top_y: 1753   width:  574   height:   45)
# question: 90%	(left_x:  184   top_y:  979   width:  301   height:   44)
# answer: 80%	(left_x:  199   top_y:  772   width:  136   height:   38)
# answer: 43%	(left_x:  242   top_y:  193   width:  152   height:   38)
# question: 50%	(left_x:  411   top_y: 2211   width:  197   height:   38)
# header: 31%	(left_x:  412   top_y: 2166   width:  112   height:   25)
# question: 32%	(left_x:  423   top_y: 2239   width:  152   height:   26)
# answer: 98%	(left_x:  550   top_y: 1455   width:  171   height:   24)
# question: 95%	(left_x:  550   top_y: 1283   width:  204   height:   24)
# answer: 38%	(left_x:  552   top_y: 1207   width:   78   height:   21)
# header: 37%	(left_x:  552   top_y: 1207   width:   78   height:   21)
# answer: 79%	(left_x:  553   top_y: 1530   width:  154   height:   25)
# answer: 98%	(left_x:  553   top_y: 1481   width:  157   height:   24)
# question: 94%	(left_x:  553   top_y: 1233   width:   79   height:   19)
# question: 95%	(left_x:  553   top_y: 1056   width:  206   height:   24)
# question: 87%	(left_x:  554   top_y:  981   width:   76   height:   21)
# question: 96%	(left_x:  555   top_y: 1257   width:  142   height:   21)
# question: 97%	(left_x:  555   top_y: 1306   width:   64   height:   20)
# question: 97%	(left_x:  555   top_y: 1333   width:  123   height:   22)
# question: 89%	(left_x:  555   top_y: 1007   width:   78   height:   19)
# question: 98%	(left_x:  556   top_y: 1080   width:   61   height:   22)
# question: 99%	(left_x:  557   top_y: 1030   width:  147   height:   22)
# answer: 66%	(left_x:  560   top_y: 1105   width:  296   height:   26)
# answer: 94%	(left_x:  638   top_y: 2215   width:  284   height:   39)
# answer: 99%	(left_x:  638   top_y: 2164   width:  181   height:   24)
# answer: 98%	(left_x:  642   top_y: 2190   width:  178   height:   22)
# answer: 54%	(left_x:  682   top_y: 1333   width:  183   height:   22)
# question: 97%	(left_x:  783   top_y:  202   width:  272   height:   28)
# answer: 91%	(left_x:  786   top_y:  101   width:  271   height:   26)
# question: 93%	(left_x:  792   top_y:  253   width:  179   height:   27)
# answer: 91%	(left_x:  802   top_y:  304   width:  113   height:   24)
# header: 93%	(left_x:  855   top_y:  456   width:  303   height:  122)
# answer: 80%	(left_x:  919   top_y:  151   width:  206   height:   30)
# other: 88%	(left_x:  951   top_y: 2163   width:  281   height:   87)
# question: 85%	(left_x:  956   top_y: 2239   width:  158   height:   24)
# answer: 29%	(left_x:  978   top_y: 2163   width:  270   height:   83)
# answer: 87%	(left_x:  994   top_y:   52   width:   82   height:   27)
# question: 96%	(left_x: 1035   top_y:  253   width:  154   height:   28)
# answer: 97%	(left_x: 1036   top_y:  302   width:  126   height:   27)
# question: 98%	(left_x: 1285   top_y:  251   width:  135   height:   32)
# question: 39%	(left_x: 1312   top_y:  767   width:  102   height:   40)
# answer: 59%	(left_x: 1314   top_y:  767   width:  101   height:   40)
# answer: 48%	(left_x: 1320   top_y: 1529   width:   92   height:   27)
# answer: 92%	(left_x: 1323   top_y: 1204   width:   88   height:   27)
# answer: 70%	(left_x: 1324   top_y: 1457   width:   85   height:   44)
# answer: 92%	(left_x: 1329   top_y: 1229   width:   82   height:   28)
# answer: 98%	(left_x: 1340   top_y:  302   width:   44   height:   29)
# answer: 86%	(left_x: 1343   top_y:  106   width:  109   height:   24)
# answer: 95%	(left_x: 1359   top_y:  152   width:  168   height:   29)
# answer: 98%	(left_x: 1428   top_y:   54   width:   54   height:   26)
# question: 95%	(left_x: 1500   top_y:  254   width:   79   height:   26)
# answer: 98%	(left_x: 1501   top_y:  303   width:   40   height:   25)
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/07.jpg: Predicted in 80.629000 milli-seconds.
# question: 81%	(left_x:   54   top_y: 1024   width:  172   height:   31)
# question: 87%	(left_x:   54   top_y:  977   width:  132   height:   30)
# question: 89%	(left_x:   56   top_y:  886   width:  129   height:   30)
# question: 94%	(left_x:   59   top_y:  933   width:  120   height:   30)
# question: 97%	(left_x:   60   top_y:  842   width:  129   height:   29)
# question: 76%	(left_x:   61   top_y:  752   width:  120   height:   27)
# question: 91%	(left_x:   62   top_y:  797   width:  145   height:   28)
# answer: 89%	(left_x:   77   top_y:  617   width:  135   height:   32)
# answer: 77%	(left_x:   86   top_y: 2033   width:  118   height:   31)
# answer: 73%	(left_x:   91   top_y: 2181   width:  117   height:   30)
# question: 80%	(left_x:  101   top_y:  568   width:   89   height:   30)
# answer: 96%	(left_x:  112   top_y: 2080   width:   80   height:   36)
# question: 93%	(left_x:  120   top_y:  659   width:  165   height:   34)
# question: 93%	(left_x:  131   top_y: 2128   width:  195   height:   32)
# answer: 36%	(left_x:  140   top_y:  213   width:  396   height:  193)
# question: 96%	(left_x:  247   top_y: 2036   width:  128   height:   29)
# question: 62%	(left_x:  280   top_y:  569   width:   79   height:   29)
# answer: 60%	(left_x:  281   top_y:  571   width:   78   height:   29)
# answer: 60%	(left_x:  326   top_y: 2179   width:   73   height:   33)
# other: 41%	(left_x:  326   top_y: 2179   width:   73   height:   33)
# question: 82%	(left_x:  348   top_y:  702   width:  315   height:   31)
# question: 74%	(left_x:  361   top_y: 1020   width:  276   height:   30)
# question: 56%	(left_x:  367   top_y:  791   width:  409   height:   33)
# question: 84%	(left_x:  369   top_y:  973   width:  407   height:   31)
# question: 85%	(left_x:  369   top_y:  836   width:  411   height:   31)
# question: 84%	(left_x:  380   top_y:  926   width:  411   height:   33)
# question: 58%	(left_x:  387   top_y:  881   width:  411   height:   31)
# question: 96%	(left_x:  410   top_y: 2035   width:  116   height:   29)
# question: 88%	(left_x:  441   top_y:  569   width:  105   height:   29)
# answer: 96%	(left_x:  444   top_y: 2081   width:   56   height:   32)
# question: 97%	(left_x:  590   top_y:  658   width:  171   height:   30)
# question: 95%	(left_x:  590   top_y: 2036   width:  131   height:   28)
# question: 96%	(left_x:  612   top_y:  569   width:  104   height:   29)
# answer: 95%	(left_x:  615   top_y: 2081   width:   86   height:   32)
# question: 94%	(left_x:  787   top_y: 2034   width:  104   height:   29)
# answer: 96%	(left_x:  810   top_y: 2079   width:   55   height:   30)
# answer: 63%	(left_x:  828   top_y:  249   width:  488   height:  123)
# other: 37%	(left_x:  834   top_y:  253   width:  481   height:  126)
# answer: 94%	(left_x:  904   top_y:  565   width:  216   height:   32)
# question: 70%	(left_x:  933   top_y: 2035   width:   68   height:   29)
# answer: 90%	(left_x:  936   top_y: 2081   width:   55   height:   32)
# answer: 95%	(left_x:  946   top_y:  611   width:  137   height:   34)
# question: 58%	(left_x: 1006   top_y:  658   width:  125   height:   33)
# question: 97%	(left_x: 1014   top_y:  473   width:  140   height:   31)
# question: 92%	(left_x: 1026   top_y: 2034   width:  126   height:   29)
# answer: 88%	(left_x: 1045   top_y: 2081   width:   69   height:   31)
# answer: 98%	(left_x: 1061   top_y:  520   width:   50   height:   32)
# question: 37%	(left_x: 1094   top_y:  748   width:   41   height:   28)
# other: 41%	(left_x: 1106   top_y:  885   width:   28   height:   27)
# other: 26%	(left_x: 1109   top_y:  932   width:   24   height:   25)
# answer: 66%	(left_x: 1117   top_y:  795   width:   17   height:   28)
# other: 30%	(left_x: 1117   top_y:  795   width:   17   height:   28)
# answer: 74%	(left_x: 1119   top_y:  978   width:   12   height:   25)
# other: 34%	(left_x: 1120   top_y:  841   width:   14   height:   26)
# answer: 47%	(left_x: 1121   top_y: 1024   width:   11   height:   27)
# question: 74%	(left_x: 1171   top_y: 2128   width:  247   height:   32)
# question: 86%	(left_x: 1172   top_y:  653   width:   96   height:   36)
# question: 79%	(left_x: 1182   top_y: 2034   width:  126   height:   29)
# question: 98%	(left_x: 1194   top_y:  470   width:  237   height:   31)
# answer: 95%	(left_x: 1212   top_y: 2080   width:   57   height:   32)
# ...
# answer: 90%	(left_x:  399   top_y:  966   width:   14   height:   27)
# answer: 59%	(left_x:  400   top_y: 1007   width:   13   height:   29)
# answer: 75%	(left_x:  401   top_y:  897   width:   13   height:   26)
# answer: 96%	(left_x:  438   top_y: 1877   width:   20   height:   27)
# answer: 89%	(left_x:  481   top_y:  961   width:  598   height:   76)
# answer: 86%	(left_x:  498   top_y:  892   width:  583   height:   38)
# answer: 31%	(left_x:  506   top_y:  765   width:  533   height:   89)
# answer: 71%	(left_x:  529   top_y:  808   width:  411   height:   65)
# answer: 96%	(left_x:  546   top_y: 2155   width:  120   height:   44)
# question: 97%	(left_x:  560   top_y: 1826   width:  178   height:   18)
# answer: 97%	(left_x:  670   top_y: 1874   width:   87   height:   30)
# answer: 78%	(left_x:  683   top_y:  692   width:  207   height:   32)
# question: 65%	(left_x:  698   top_y:  580   width:   75   height:   27)
# answer: 60%	(left_x:  714   top_y: 1924   width:  284   height:   27)
# header: 26%	(left_x:  714   top_y: 1924   width:  284   height:   27)
# answer: 91%	(left_x:  740   top_y: 2082   width:  225   height:   22)
# answer: 96%	(left_x:  778   top_y:  508   width:  185   height:   39)
# answer: 97%	(left_x:  852   top_y: 1874   width:   61   height:   29)
# question: 96%	(left_x:  874   top_y:  470   width:   99   height:   24)
# answer: 57%	(left_x:  892   top_y:  356   width:  232   height:   30)
# question: 90%	(left_x:  894   top_y: 1823   width:   48   height:   22)
# answer: 33%	(left_x:  896   top_y:  147   width:  421   height:  209)
# answer: 91%	(left_x:  908   top_y:  111   width:  103   height:   34)
# answer: 97%	(left_x:  959   top_y: 1873   width:   68   height:   30)
# question: 92%	(left_x: 1073   top_y: 1824   width:  156   height:   22)
# question: 97%	(left_x: 1111   top_y:  692   width:  159   height:   33)
# question: 96%	(left_x: 1145   top_y:  759   width:   72   height:   32)
# answer: 98%	(left_x: 1162   top_y: 1875   width:   71   height:   29)
# other: 86%	(left_x: 1189   top_y:  804   width:   85   height:   33)
# question: 26%	(left_x: 1207   top_y:  998   width:   68   height:   35)
# question: 90%	(left_x: 1217   top_y:  890   width:   58   height:   36)
# answer: 56%	(left_x: 1310   top_y:  694   width:   63   height:   28)
# question: 44%	(left_x: 1312   top_y:  694   width:   65   height:   28)
# question: 64%	(left_x: 1322   top_y:  469   width:   97   height:   21)
# answer: 98%	(left_x: 1360   top_y:  505   width:   92   height:   36)
# answer: 87%	(left_x: 1374   top_y:  573   width:   84   height:   27)
# answer: 55%	(left_x: 1396   top_y: 1819   width:   96   height:   26)
# question: 25%	(left_x: 1396   top_y: 1819   width:   96   height:   26)
# answer: 90%	(left_x: 1414   top_y:  611   width:  186   height:   38)
# question: 29%	(left_x: 1414   top_y:  608   width:  190   height:   43)
# answer: 97%	(left_x: 1434   top_y: 1870   width:   93   height:   35)
# question: 95%	(left_x: 1442   top_y:  692   width:  140   height:   29)
# other: 31%	(left_x: 1484   top_y:  803   width:   87   height:   35)
# answer: 42%	(left_x: 1487   top_y:  803   width:   86   height:   36)
# answer: 75%	(left_x: 1496   top_y:  889   width:   76   height:  138)
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/06.jpg: Predicted in 80.555000 milli-seconds.
# header: 43%	(left_x:   14   top_y: 1987   width:   22   height:  151)
# answer: 43%	(left_x:   36   top_y: 1752   width:  705   height:   29)
# question: 82%	(left_x:   40   top_y: 1866   width:  165   height:   23)
# question: 65%	(left_x:   42   top_y: 1967   width:  198   height:   24)
# answer: 94%	(left_x:   42   top_y: 2062   width:  134   height:   22)
# answer: 28%	(left_x:   43   top_y: 1866   width:  164   height:   22)
# answer: 43%	(left_x:   47   top_y: 1966   width:  196   height:   25)
# other: 57%	(left_x:   69   top_y: 1752   width:  687   height:   29)
# answer: 92%	(left_x:   79   top_y: 1903   width:   57   height:   21)
# answer: 98%	(left_x:   81   top_y: 2003   width:  148   height:   22)
# question: 59%	(left_x:   83   top_y: 1660   width:  228   height:   25)
# other: 67%	(left_x:   87   top_y:  692   width:  111   height:   29)
# question: 91%	(left_x:  169   top_y:  639   width:  106   height:   27)
# answer: 61%	(left_x:  216   top_y:  378   width:  355   height:  117)
# question: 51%	(left_x:  238   top_y:  362   width:  405   height:   28)
# question: 83%	(left_x:  371   top_y: 1664   width:  276   height:   24)
# other: 92%	(left_x:  434   top_y:  695   width:  376   height:   27)
# answer: 97%	(left_x:  483   top_y: 1702   width:   69   height:   25)
# other: 51%	(left_x:  527   top_y:  641   width:  178   height:   25)
# other: 84%	(left_x:  636   top_y:   66   width:  408   height:   81)
# question: 73%	(left_x:  734   top_y: 1663   width:  193   height:   23)
# answer: 35%	(left_x:  777   top_y: 2246   width:   90   height:   21)
# answer: 97%	(left_x:  828   top_y: 1702   width:   67   height:   25)
# other: 85%	(left_x:  972   top_y:  202   width:  644   height:   73)
# header: 47%	(left_x:  984   top_y:  311   width:  120   height:   28)
# question: 36%	(left_x: 1008   top_y: 1666   width:   72   height:   20)
# answer: 99%	(left_x: 1021   top_y:  398   width:  120   height:   29)
# answer: 97%	(left_x: 1024   top_y: 1702   width:   31   height:   25)
# question: 84%	(left_x: 1048   top_y:  360   width:   79   height:   22)
# question: 91%	(left_x: 1053   top_y:  534   width:  117   height:   23)
# question: 85%	(left_x: 1066   top_y:  643   width:   95   height:   25)
# question: 83%	(left_x: 1100   top_y: 1919   width:  174   height:   26)
# question: 73%	(left_x: 1108   top_y:  494   width:   61   height:   23)
# answer: 64%	(left_x: 1126   top_y:  698   width:   73   height:   26)
# answer: 55%	(left_x: 1132   top_y:  697   width:  141   height:   27)
# answer: 98%	(left_x: 1144   top_y: 1968   width:  124   height:   28)
# answer: 93%	(left_x: 1186   top_y: 1703   width:   70   height:   26)
# answer: 82%	(left_x: 1227   top_y:  698   width:   43   height:   26)
# answer: 96%	(left_x: 1260   top_y:  400   width:   65   height:   26)
# answer: 76%	(left_x: 1329   top_y: 1703   width:   44   height:   27)
# answer: 53%	(left_x: 1341   top_y: 1794   width:  225   height:   30)
# question: 32%	(left_x: 1341   top_y: 1794   width:  225   height:   30)
# question: 79%	(left_x: 1364   top_y:  533   width:  113   height:   25)
# answer: 93%	(left_x: 1393   top_y: 1919   width:  117   height:   25)
# question: 74%	(left_x: 1408   top_y:  493   width:   81   height:   22)
# question: 68%	(left_x: 1419   top_y:  638   width:  121   height:   30)
# question: 73%	(left_x: 1420   top_y:  399   width:  148   height:   25)
# question: 65%	(left_x: 1437   top_y:  358   width:  129   height:   23)
# answer: 88%	(left_x: 1464   top_y: 1835   width:  118   height:   27)
# answer: 73%	(left_x: 1483   top_y:  692   width:  111   height:   33)
# answer: 98%	(left_x: 1491   top_y: 1969   width:   83   height:   30)
# answer: 97%	(left_x: 1505   top_y: 1703   width:   54   height:   26)
# other: 53%	(left_x: 1518   top_y: 1597   width:   72   height:   32)
# answer: 51%	(left_x: 1518   top_y: 1597   width:   72   height:   32)
# other: 83%	(left_x: 1604   top_y: 1356   width:   29   height:  188)
# other: 70%	(left_x: 1607   top_y: 1583   width:   25   height:  180)
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/03.jpg: Predicted in 80.565000 milli-seconds.
# other: 28%	(left_x:   44   top_y: 2102   width:  641   height:   61)
# other: 34%	(left_x:   71   top_y: 1046   width:  286   height:   38)
# question: 95%	(left_x:   71   top_y:  728   width:   43   height:   22)
# question: 72%	(left_x:   72   top_y:  764   width:   40   height:   20)
# answer: 60%	(left_x:   72   top_y:  666   width:  101   height:   25)
# question: 97%	(left_x:   73   top_y:  594   width:   57   height:   31)
# answer: 93%	(left_x:   82   top_y:  402   width:  307   height:   36)
# answer: 83%	(left_x:   88   top_y:  492   width:  535   height:   72)
# answer: 32%	(left_x:   92   top_y:  434   width:  437   height:   37)
# question: 60%	(left_x:  109   top_y: 2209   width:  129   height:   20)
# other: 53%	(left_x:  148   top_y:  152   width:  413   height:  115)
# answer: 89%	(left_x:  156   top_y:  590   width:  528   height:   40)
# answer: 84%	(left_x:  179   top_y:  756   width:  198   height:   31)
# question: 35%	(left_x:  180   top_y:  733   width:  125   height:   23)
# answer: 30%	(left_x:  227   top_y:  433   width:  229   height:   33)
# answer: 59%	(left_x:  247   top_y:  239   width:  299   height:   31)
# question: 89%	(left_x:  522   top_y:  729   width:  187   height:   48)
# other: 27%	(left_x:  645   top_y:  164   width:  370   height:   95)
# answer: 89%	(left_x:  647   top_y:  162   width:  364   height:   99)
# answer: 86%	(left_x:  736   top_y:  410   width:  513   height:  145)
# answer: 73%	(left_x:  833   top_y:  240   width:  175   height:   24)
# other: 29%	(left_x: 1021   top_y:  664   width:  227   height:   27)
# answer: 52%	(left_x: 1022   top_y:  664   width:  229   height:   27)
# answer: 86%	(left_x: 1106   top_y:  860   width:  115   height:   22)
# question: 53%	(left_x: 1106   top_y:  827   width:   65   height:   21)
# answer: 40%	(left_x: 1106   top_y:  827   width:   65   height:   21)
# answer: 94%	(left_x: 1108   top_y:  889   width:  172   height:   25)
# answer: 58%	(left_x: 1109   top_y:  921   width:  126   height:   22)
# answer: 87%	(left_x: 1112   top_y:  954   width:  253   height:   27)
# answer: 64%	(left_x: 1112   top_y:  986   width:  152   height:   22)
# question: 37%	(left_x: 1118   top_y:  954   width:  246   height:   28)
# other: 91%	(left_x: 1126   top_y:   87   width:  329   height:  189)
# answer: 98%	(left_x: 1228   top_y:  762   width:   18   height:   21)
# answer: 97%	(left_x: 1230   top_y:  729   width:   16   height:   22)
# answer: 30%	(left_x: 1271   top_y: 2226   width:   92   height:   20)
# answer: 94%	(left_x: 1302   top_y:  728   width:   78   height:   25)
# question: 87%	(left_x: 1302   top_y:  665   width:   79   height:   22)
# answer: 98%	(left_x: 1303   top_y:  761   width:   77   height:   23)
# question: 91%	(left_x: 1365   top_y: 2242   width:  137   height:   19)
# question: 82%	(left_x: 1374   top_y: 2228   width:  133   height:   18)
# question: 90%	(left_x: 1429   top_y:  663   width:  152   height:   26)
# question: 86%	(left_x: 1437   top_y:  728   width:   75   height:   53)
# question: 90%	(left_x: 1438   top_y:  823   width:  132   height:   24)
# answer: 78%	(left_x: 1439   top_y:  983   width:  128   height:   25)
# question: 27%	(left_x: 1440   top_y:  755   width:  148   height:   27)
# answer: 61%	(left_x: 1442   top_y:  953   width:  146   height:   26)
# question: 30%	(left_x: 1445   top_y:  856   width:  139   height:   24)
# Enter Image Path:  Detection layer: 168 - type = 28
#  Detection layer: 185 - type = 28
#  Detection layer: 202 - type = 28
# FacturasYOLO/18.jpg: Predicted in 80.619000 milli-seconds.
# other: 63%	(left_x:   62   top_y: 1020   width:   24   height:  321)
# answer: 97%	(left_x:  111   top_y:  379   width:   84   height:   31)
# question: 52%	(left_x:  112   top_y: 1802   width:  186   height:   31)
# answer: 74%	(left_x:  119   top_y: 1337   width:  534   height:  107)
# question: 98%	(left_x:  121   top_y:  330   width:  149   height:   32)
# question: 35%	(left_x:  131   top_y: 1143   width:  561   height:   43)
# answer: 86%	(left_x:  133   top_y:  780   width:  335   height:   36)
# question: 35%	(left_x:  135   top_y:  841   width:  646   height:   43)
# other: 43%	(left_x:  136   top_y:   26   width:  134   height:  145)
# question: 97%	(left_x:  138   top_y: 1216   width:  314   height:   34)
# other: 45%	(left_x:  139   top_y: 1481   width:  308   height:   35)
# question: 35%	(left_x:  139   top_y: 1481   width:  308   height:   35)
# question: 96%	(left_x:  141   top_y: 1015   width:  306   height:   39)
# answer: 84%	(left_x:  145   top_y:  842   width:  693   height:   41)
# answer: 45%	(left_x:  147   top_y: 1076   width:  691   height:   46)
# answer: 66%	(left_x:  148   top_y: 1143   width:  585   height:   45)
# answer: 88%	(left_x:  150   top_y:  711   width:  583   height:   42)
# question: 87%	(left_x:  151   top_y: 1275   width:  666   height:   43)
# answer: 88%	(left_x:  152   top_y:  914   width:  411   height:   75)
# question: 63%	(left_x:  155   top_y: 1075   width:  640   height:   47)
# answer: 81%	(left_x:  157   top_y:  644   width:  627   height:   42)
# answer: 93%	(left_x:  174   top_y: 1971   width:  326   height:   34)
# other: 62%	(left_x:  212   top_y:  219   width:  569   height:   59)
# other: 41%	(left_x:  280   top_y:  200   width:  409   height:   41)
# question: 33%	(left_x:  280   top_y:  200   width:  409   height:   41)
# answer: 98%	(left_x:  300   top_y:  379   width:  118   height:   33)
# header: 52%	(left_x:  339   top_y:   64   width:  412   height:   66)
# question: 95%	(left_x:  376   top_y:  332   width:   78   height:   30)
# answer: 96%	(left_x:  425   top_y:  544   width:  231   height:   38)
# question: 94%	(left_x:  558   top_y:  329   width:   97   height:   33)
# answer: 98%	(left_x:  566   top_y:  378   width:   39   height:   34)
# header: 60%	(left_x:  583   top_y: 1807   width:  190   height:   29)
# question: 94%	(left_x:  706   top_y:  328   width:   67   height:   32)
# answer: 95%	(left_x:  813   top_y: 1805   width:   25   height:   30)
# other: 47%	(left_x:  886   top_y:  248   width:  591   height:  158)
# question: 90%	(left_x:  904   top_y: 1976   width:  157   height:   25)
# answer: 97%	(left_x:  908   top_y: 1805   width:   62   height:   29)
# header: 55%	(left_x:  944   top_y:   54   width:  505   height:  120)
# other: 74%	(left_x:  947   top_y:   57   width:  496   height:  118)
# other: 37%	(left_x:  972   top_y: 1583   width:  142   height:   34)
# answer: 44%	(left_x:  994   top_y:   68   width:  495   height:  107)
# question: 96%	(left_x: 1004   top_y:  547   width:  123   height:   32)
# answer: 38%	(left_x: 1047   top_y:  912   width:   75   height:   40)
# answer: 86%	(left_x: 1050   top_y: 1808   width:   24   height:   27)
# answer: 29%	(left_x: 1058   top_y:  713   width:   67   height:   44)
# answer: 93%	(left_x: 1058   top_y: 1148   width:   64   height:   41)
# answer: 92%	(left_x: 1059   top_y: 1350   width:   61   height:   34)
# answer: 86%	(left_x: 1060   top_y: 1383   width:   62   height:   35)
# answer: 87%	(left_x: 1061   top_y: 1417   width:   59   height:   32)
# other: 94%	(left_x: 1121   top_y: 1805   width:  123   height:   32)
# answer: 68%	(left_x: 1171   top_y: 1978   width:   87   height:  125)
# question: 94%	(left_x: 1178   top_y:  547   width:   93   height:   31)
# answer: 91%	(left_x: 1197   top_y: 1353   width:  142   height:   90)
# answer: 66%	(left_x: 1199   top_y:  950   width:  142   height:   36)
# answer: 96%	(left_x: 1201   top_y: 1146   width:  140   height:   43)
# answer: 80%	(left_x: 1202   top_y:  711   width:  142   height:   45)
# answer: 89%	(left_x: 1208   top_y:  909   width:  124   height:   44)
# answer: 27%	(left_x: 1259   top_y: 1583   width:   64   height:   36)
# other: 76%	(left_x: 1259   top_y: 1582   width:   63   height:   37)
# question: 35%	(left_x: 1298   top_y: 1804   width:  212   height:   31)
# answer: 42%	(left_x: 1301   top_y: 1804   width:  212   height:   31)
# question: 90%	(left_x: 1306   top_y:  546   width:   50   height:   31)
# question: 75%	(left_x: 1418   top_y:  547   width:   71   height:   29)
# answer: 95%	(left_x: 1437   top_y: 1150   width:   86   height:   40)
# answer: 78%	(left_x: 1437   top_y: 1410   width:   82   height:   39)
# answer: 91%	(left_x: 1437   top_y: 1383   width:   81   height:   37)
# answer: 93%	(left_x: 1438   top_y: 1351   width:   76   height:   34)
# answer: 96%	(left_x: 1439   top_y:  915   width:   82   height:   36)
# answer: 76%	(left_x: 1439   top_y:  715   width:   85   height:   38)
# answer: 91%	(left_x: 1441   top_y:  949   width:   82   height:   37)
# Enter Image Path:

# %%
resultado=json.loads(open('result.json').read())

# %%
# !unzip Facturas.zip

# %%
# %%capture
pip install transformers

# %%
from transformers import BertForSequenceClassification,BertTokenizer, Trainer

# %%
# %%capture
# !wget https://www.dropbox.com/s/rez0qxprg2mgke5/bert.zip?dl=0 -O bert.zip
# !unzip bert

# %%
# !unzip Facturas.zip

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='macro')
    acc = accuracy_score(labels, preds)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }

# %%
model = BertForSequenceClassification.from_pretrained('bert')
tokenizer = BertTokenizer.from_pretrained('bert')
trainer = Trainer(model,compute_metrics=compute_metrics)

# %%
# %%capture
# !sudo apt install tesseract-ocr

# %%
# %%capture
pip install pytesseract

# %%
from pytesseract import Output
import pytesseract
import argparse

# %%
def ocr(l,img):
  C=[]
  T=[]
  for x in l:
    image=img[x[1]:x[3],x[0]:x[2]]
    c=[]
    t=[]

    #Imagen con borde +2
    shape=image.shape
    w=shape[1]
    h=shape[0]
    base_size=h+4,w+4,3
    base=np.zeros(base_size,dtype=np.uint8)
    cv2.rectangle(base,(0,0),(w+4,h+4),(255,255,255),30)
    base[2:h+2,2:w+2]=image

    #OCR
    results = pytesseract.image_to_data(base, output_type=Output.DICT)
    c.append(float(media(results['conf'])))
    t.append(' '.join(results['text']))


    c1=[]
    t1=[]
    #Imagen con borde +3
    base_size=h+6,w+6,3
    base1=np.zeros(base_size,dtype=np.uint8)
    cv2.rectangle(base1,(0,0),(w+6,h+6),(255,255,255),30)
    base1[3:h+3,3:w+3]=image

    #OCR
    results = pytesseract.image_to_data(base1, output_type=Output.DICT)
    c1.append(float(media(results['conf'])))
    t1.append(' '.join(results['text']))

    # Ya tenemos todos los resultados almacenados, ahora buscamos al mejor
    max_c=(max(c))
    index=c.index(max_c)
    x=t[index]

    max_c1=(max(c1))
    index1=c1.index(max_c1)
    y=t1[index1]
    if max_c>max_c1:
      C.append(max_c)
      if x.replace(' ','')!='':
        T.append(x)

      else:
        T.append(y)

    else:
       C.append(max_c1)
       if y.replace(' ','')!='':
         T.append(y)
  
       else:
         T.append(x)
 
  return (C,T)

# %%
def media(lista):
  i,sum=0,0
  for x in lista:
    if x!='-1':
      i+=1
      sum=x+sum
  if i==0:
    return sum
  return "{0:.2f}".format(sum/i)

# %%
class Dataset():
    def __init__(self, txt):
        self.txt= txt
        self.encodings = tokenizer(txt, truncation=True, padding=True)

    def __iter__(self):
        for x in self.txt:
          yield x
    def __len__(self):
      return len(self.txt)

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        return item

    def __len__(self):
        return len(self.txt)

# %%
def abrirImagen(path):
  return cv2.imread(str(path))

# %%
def mostrarImagen(image,h=20,w=15):
  if len(image.shape)==3:
    img2 = image[:,:,::-1]
    plt.figure(figsize=(h,w))
    plt.imshow(img2)
    plt.show()
  else:
    img2 = image
    plt.figure(figsize=(h,w))
    plt.imshow(img2,cmap='gray')
    plt.show()

# %%
def listaCont(path):
  img=abrirImagen(path)
  gray=cv2.cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  gray= cv2.GaussianBlur(gray, (5,5), 0)
  (H,W)=gray.shape
  coef1=H//75
  coef2=W//150
  rectKernel=cv2.getStructuringElement(cv2.MORPH_RECT,(coef1,coef2))
  sqKernel=cv2.getStructuringElement(cv2.MORPH_RECT,(coef1,coef1))
  blackhat= cv2.morphologyEx(gray,cv2.MORPH_BLACKHAT,rectKernel)
  grad= cv2.Sobel(blackhat,ddepth=cv2.CV_32F,dx=1,dy=0,ksize=-1)
  grad=np.absolute(grad)
  (minVal, maxVal)=(np.min(grad),np.max(grad))
  grad= (grad-minVal)/(maxVal-minVal)
  grad= (grad*255).astype("uint8")
  grad=cv2.morphologyEx(grad,cv2.MORPH_CLOSE,rectKernel)
  lineas = cv2.erode(grad,kernel = np.ones((40,1)))
  final=grad-lineas
  thresh=cv2.threshold(final, 0, 255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]
  cnts= cv2.findContours(thresh.copy(),cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
  cnts=imutils.grab_contours(cnts)
  clone=img.copy()
  l=[]
  for c in cnts:
      area = cv2.contourArea(c)
      (x, y, w, h) = cv2.boundingRect(c)
      if area>50 and x+w> 0.1*img.shape[1] and x<0.9*img.shape[1] and y<0.93*img.shape[0] and h<0.5*img.shape[0] and w>0.5*h:
        l=l+[[x,y,x + w, y + h]]
  return l,img

# %%
def abrirImagen(path):
  return cv2.imread(str(path))

# %%
def mostrarImagen(image,h=20,w=15):
  if len(image.shape)==3:
    img2 = image[:,:,::-1]
    plt.figure(figsize=(h,w))
    plt.imshow(img2)
    plt.show()
  else:
    img2 = image
    plt.figure(figsize=(h,w))
    plt.imshow(img2,cmap='gray')
    plt.show()

# %% [markdown]
# ### Ground truth

# %%
os.rename('input', 'input_1')

# %%
# %mkdir 'input'
# %mkdir 'input/ground-truth'
# %mkdir 'input/detection-results'

# %%
path='Facturas'
for file in [xml for xml in os.listdir(path) if xml[-1]=='l']:
  txt=open('input/ground-truth/'+file[:-4]+'.txt','w')
  path_file=path+'/'+file
  objeto=ET.parse(path_file)
  objeto = objeto.getroot()
  for bbox in objeto.findall('object'):
    label=bbox.find('name').text
    coords = bbox.find('bndbox')
    xmin,ymin,xmax,ymax = coords.find('xmin').text,coords.find('ymin').text,coords.find('xmax').text,coords.find('ymax').text
    txt.write(label + ' ' + xmin + ' ' + ymin + ' '+ xmax + ' '+ ymax +'\n')
  txt.close()

# %% [markdown]
# ### Sin traductor

# %% [markdown]
# #### Predicciones

# %%
for res in resultado:
  txt=open('input/detection-results/'+Path(res['filename']).stem+'.txt','w')
  img=cv2.imread(res['filename'])
  height,width,_=img.shape
  conf=[]
  l=[]
  for objeto in res['objects']:
    conf.append(objeto['confidence'])
    coords=objeto['relative_coordinates']
    x,y,h,w=coords['center_x'],coords['center_y'],coords['height'],coords['width']
    l.append(unconvert(width, height, x, y, w, h))
  dic={str(l[i]):str(conf[i]) for i in range(0,len(l))}
  l=non_max_suppression_fast(np.array(l))
  test_conf,test_text=ocr(l,img)
  test_dataset = Dataset(test_text)
  prediction=trainer.predict(test_dataset)
  output=prediction[0].argmax(-1)
  dic_1={0:'question', 1:'answer', 2:'header', 3:'other'}
  output=[dic_1[x] for x in output]
  f=Path(res['filename'])
  txt=open('input/detection-results/'+f.stem+'.txt','w')
  for i in range(0,len(l)):
    logit=output[i]
    x, y, z, w=l[i]
    conf=float(dic[str(list(l[i]))])
    conf1=test_conf[i]
    txt.write(logit + ' ' +str(int((conf+conf1)/2)) + ' '+ str(x) + ' ' + str(y) + ' '+ str(z) + ' '+ str(w) +'\n')
  txt.close()
# Out:
# ***** Running Prediction *****
#   Num examples = 137
#   Batch size = 8
#     <div>
#
#       <progress value='214' max='18' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18/18 10:33]
#     </div>
# ***** Running Prediction *****
#   Num examples = 20
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 64
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 56
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 52
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 83
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 68
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 61
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 65
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 86
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 37
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 69
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 55
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 48
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 50
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 20
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 74
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 64
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 55
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 97
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 39
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 43
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 68
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 57
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 49
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 40
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 61
#   Batch size = 8

# %% [markdown]
# #### Resultados

# %%
mAP()
# Out:
# 22.89% = answer AP
# 0.00% = header AP
# 4.49% = other AP
# 23.04% = question AP
# mAP = 12.61%

# %%
mostrarImagen(abrirImagen('output/ground-truth-info.png'),7,5)

# %%
mostrarImagen(abrirImagen('output/detection-results-info.png'),7,5)

# %%
precision=292/741+73/656+241/275
precision=precision/4
precision
# Out:
# 0.3454265506102797

# %%
recall=292/(292+433)+73/(73+412)+241/(167+241)
recall=recall/4
recall
# Out:
# 0.2859900897792462

# %%
f1=2*precision*recall/(precision+recall)
f1
# Out:
# 0.3129108860996308

# %%
mostrarImagen(abrirImagen('output/lamr.png'),7,5)

# %%
mostrarImagen(abrirImagen('output/mAP.png'),7,5)

# %% [markdown]
# ### Traductor

# %%
# %%capture
# !pip3 install googletrans==3.1.0a0

# %%
from googletrans import Translator, constants
from pprint import pprint

# %%
translator = Translator()

# %% [markdown]
# #### Predicciones

# %%
for res in resultado:
  txt=open('input/detection-results/'+Path(res['filename']).stem+'.txt','w')
  img=cv2.imread(res['filename'])
  height,width,_=img.shape
  conf=[]
  l=[]
  for objeto in res['objects']:
    conf.append(objeto['confidence'])
    coords=objeto['relative_coordinates']
    x,y,h,w=coords['center_x'],coords['center_y'],coords['height'],coords['width']
    l.append(unconvert(width, height, x, y, w, h))
  dic={str(l[i]):str(conf[i]) for i in range(0,len(l))}
  l=non_max_suppression_fast(np.array(l))
  test_conf,test_text=ocr(l,img)
  for i in range(0,len(test_text)):
    test_text[i]=' '.join(test_text[i].split())
    if test_text[i]!='':
      test_text[i] = translator.translate(test_text[i], src='es', dest="en").text
  test_dataset = Dataset(test_text)
  prediction=trainer.predict(test_dataset)
  output=prediction[0].argmax(-1)
  dic_1={0:'question', 1:'answer', 2:'header', 3:'other'}
  output=[dic_1[x] for x in output]
  f=Path(res['filename'])
  txt=open('input/detection-results/'+f.stem+'.txt','w')
  for i in range(0,len(l)):
    logit=output[i]
    x, y, z, w=l[i]
    conf=float(dic[str(list(l[i]))])
    conf1=test_conf[i]
    txt.write(logit + ' ' +str(int((conf+conf1)/2)) + ' '+ str(x) + ' ' + str(y) + ' '+ str(z) + ' '+ str(w) +'\n')
  txt.close()
# Out:
# ***** Running Prediction *****
#   Num examples = 137
#   Batch size = 8
#     <div>
#
#       <progress value='428' max='18' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18/18 40:49]
#     </div>
# ***** Running Prediction *****
#   Num examples = 20
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 64
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 56
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 52
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 83
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 68
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 61
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 65
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 86
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 37
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 69
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 55
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 48
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 50
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 20
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 74
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 64
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 55
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 97
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 39
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 43
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 68
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 57
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 49
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 40
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 61
#   Batch size = 8

# %% [markdown]
# #### Resultados

# %%
mAP()
# Out:
# 22.81% = answer AP
# 0.95% = header AP
# 4.82% = other AP
# 22.77% = question AP
# mAP = 12.84%

# %%
mostrarImagen(abrirImagen('output/ground-truth-info.png'),7,5)

# %%
mostrarImagen(abrirImagen('output/detection-results-info.png'),7,5)

# %%
precision=291/741+74/656+240/275
precision=precision/4
precision
# Out:
# 0.3445611753458352

# %%
recall=291/(292+436)+74/(74+400)+240/(169+240)
recall=recall/4
recall
# Out:
# 0.2856601210499651

# %%
f1=2*precision*recall/(precision+recall)
f1
# Out:
# 0.3123581752038852

# %%
mostrarImagen(abrirImagen('output/lamr.png'),7,5)

# %%
mostrarImagen(abrirImagen('output/mAP.png'),7,5)

# %% [markdown]
# ###Corrector

# %%
# %%capture
# !pip install autocorrect
from autocorrect import Speller
spell = Speller(lang='es',only_replacements=True)

# %% [markdown]
# #### Predicciones

# %%
for res in resultado:
  txt=open('input/detection-results/'+Path(res['filename']).stem+'.txt','w')
  img=cv2.imread(res['filename'])
  height,width,_=img.shape
  conf=[]
  l=[]
  for objeto in res['objects']:
    conf.append(objeto['confidence'])
    coords=objeto['relative_coordinates']
    x,y,h,w=coords['center_x'],coords['center_y'],coords['height'],coords['width']
    l.append(unconvert(width, height, x, y, w, h))
  dic={str(l[i]):str(conf[i]) for i in range(0,len(l))}
  l=non_max_suppression_fast(np.array(l))
  test_conf,test_text=ocr(l,img)
  for i in range(0,len(test_text)):
    test_text[i]=' '.join(test_text[i].split())
    if test_text[i]!='':
      test_text[i]=translator.translate(spell(test_text[i].lower()), src="es",dest="en").text
  test_dataset = Dataset(test_text)
  prediction=trainer.predict(test_dataset)
  output=prediction[0].argmax(-1)
  dic_1={0:'question', 1:'answer', 2:'header', 3:'other'}
  output=[dic_1[x] for x in output]
  f=Path(res['filename'])
  txt=open('input/detection-results/'+f.stem+'.txt','w')
  for i in range(0,len(l)):
    logit=output[i]
    x, y, z, w=l[i]
    conf=float(dic[str(list(l[i]))])
    conf1=test_conf[i]
    txt.write(logit + ' ' +str(int((conf+conf1)/2)) + ' '+ str(x) + ' ' + str(y) + ' '+ str(z) + ' '+ str(w) +'\n')
  txt.close()
spell = Speller(lang='es',only_replacements=True)
# Out:
# ***** Running Prediction *****
#   Num examples = 137
#   Batch size = 8
#     <div>
#
#       <progress value='642' max='18' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18/18 1:08:49]
#     </div>
# ***** Running Prediction *****
#   Num examples = 20
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 64
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 56
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 52
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 83
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 68
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 61
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 65
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 86
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 37
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 69
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 55
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 48
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 50
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 20
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 74
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 64
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 55
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 97
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 39
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 43
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 68
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 57
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 49
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 40
#   Batch size = 8
# ***** Running Prediction *****
#   Num examples = 61
#   Batch size = 8

# %% [markdown]
# #### Resultados

# %%
mAP()
# Out:
# 22.57% = answer AP
# 0.00% = header AP
# 4.41% = other AP
# 22.78% = question AP
# mAP = 12.44%

# %%
mostrarImagen(abrirImagen('output/ground-truth-info.png'),7,5)

# %%
mostrarImagen(abrirImagen('output/detection-results-info.png'),7,5)

# %%
precision=290/741+73/656+242/275
precision=precision/4
precision
# Out:
# 0.34566087768671205

# %%
recall=290/(290+424)+73/(73+417)+242/(171+242)
recall=recall/4
recall
# Out:
# 0.28527461832190504

# %%
f1=2*precision*recall/(precision+recall)
f1
# Out:
# 0.31257799117247553

# %%
mostrarImagen(abrirImagen('output/lamr.png'),7,5)

# %%
mostrarImagen(abrirImagen('output/mAP.png'),7,5)

# %% [markdown]
# ### Predicción

# %%
input/detection-results/01.txt

# %%
f=Path('Facturas/01.jpg')
img=abrirImagen(f)
clone=img.copy()
txt_pred=open('input/detection-results/01.txt')
linea_pred=txt_pred.readline() 
while linea_pred!='':
  logit,conf,x1,y1,z1,w1=linea_pred.split()
  linea_pred=txt_pred.readline()
  cv2.rectangle(clone, (int(x1), int(y1)), (int(z1),int(w1)), (0, 0, 255), 2)
  cv2.putText(clone, f'{logit}', (int(x1),int(y1)-5), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)
mostrarImagen(clone,30,20)

# %%
cv2.imwrite('yoloBERT.png',clone)
# Out:
# True
